# %%
import pandas as pd
import os

# %%
overwrite = False #overwrite files

# %% [markdown]
# Licitaciones

# %%
base_path = os.path.join('..','..', 'raw_data', 'Licitaciones')
for year in os.listdir(base_path):
    df_year = pd.DataFrame()
    year_folder_path = os.path.join(base_path, year)
    destination_path = os.path.join('..', '..','interm_data', 'yearly_data', 'Licitaciones', f'lic-{year}.csv')
    if not os.path.isdir(destination_path) or overwrite:
        for file in os.listdir(year_folder_path):
            df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
            df_year = pd.concat([df_year, df])
        df_year.to_csv(destination_path)
# Out:
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,94,97,101,102) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,73,87,94,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101,102) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (63,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,59,63,64,65,73,87,94,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,59,63,64,73,87,94,97,101,102) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,94,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (63,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (87,97,101,102) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (63,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (87) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,94,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,94,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,94,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,94,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (63,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,94,97,101,102) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,94,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,54,63,64,73,87,94,97,101,102) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,94,97,101,102) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,94,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,73,87,94,97,101,102) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,94,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,94,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,59,63,64,65,87,97,101,102) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (63,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (87,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,73,87,94,97,101,102) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,94,97,99,100,101,102) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,94,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,59,63,64,65,73,87,94,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,94,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,65,73,87,94,97,100,101,102) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,94,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,94,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101,102) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,59,63,64,65,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/1629358218.py:8: DtypeWarning: Columns (27,52,63,64,87,97,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')

# %% [markdown]
# Ordenes de Compra

# %%
base_path = os.path.join('..', '..', 'raw_data', 'OrdenesCompra')
for year in os.listdir(base_path):
    df_year = pd.DataFrame()
    year_folder_path = os.path.join(base_path, year)
    destination_path = os.path.join('..', '..','interm_data', 'yearly_data', 'OrdenesCompra', f'oc-{year}.csv')
    if not os.path.isdir(destination_path) or overwrite:
        for file in os.listdir(year_folder_path):
            df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
            df_year = pd.concat([df_year, df])
        df_year.to_csv(destination_path)
# Out:
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,30,31,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,30,31,69,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (20,21,30,31,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,30,31,53,69,72,73,74,76) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,53,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,53,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,53,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,30,31,53,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,53,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,53,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,53,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,30,31,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,32,52,53,57,69,72,73,74,76) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,30,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,54,69,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (21,31,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,69,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,69,73,74,75) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
# /var/folders/0c/zyxv4tr515b0drdhsbj6qwhh0000gn/T/ipykernel_38275/513882516.py:8: DtypeWarning: Columns (22,32,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(year_folder_path, file), sep=';', encoding='latin-1')
