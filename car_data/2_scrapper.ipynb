# %%
# Install required libraries
# !pip3 install requests
# !pip3 install beautifulsoup4
# !pip3 install pandas
# !pip3 install fuzzywuzzy
# !pip3 install python-Levenshtein

# Import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from urllib.parse import quote
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from difflib import get_close_matches
# Out:
# Requirement already satisfied: requests in c:\users\lucas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lucas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lucas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lucas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lucas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (2024.2.2)
# [notice] A new release of pip is available: 24.1.2 -> 24.3.1
# [notice] To update, run: C:\Users\lucas\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: beautifulsoup4 in c:\users\lucas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lucas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from beautifulsoup4) (2.5)
# [notice] A new release of pip is available: 24.1.2 -> 24.3.1
# [notice] To update, run: C:\Users\lucas\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\lucas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lucas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lucas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lucas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\lucas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\lucas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.1.2 -> 24.3.1
# [notice] To update, run: C:\Users\lucas\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: fuzzywuzzy in c:\users\lucas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.18.0)
# [notice] A new release of pip is available: 24.1.2 -> 24.3.1
# [notice] To update, run: C:\Users\lucas\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: python-Levenshtein in c:\users\lucas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.21.1)
# Requirement already satisfied: Levenshtein==0.21.1 in c:\users\lucas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-Levenshtein) (0.21.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=2.3.0 in c:\users\lucas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Levenshtein==0.21.1->python-Levenshtein) (3.2.0)
# [notice] A new release of pip is available: 24.1.2 -> 24.3.1
# [notice] To update, run: C:\Users\lucas\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('csvs/parsed_output.csv')
# Display the first few rows of the DataFrame
df.head()
# Out:
#      marca tipo producto           Model Name  Engine Drive Transmission  Year
# 0  changan     camioneta  hunter 1.9l comfort     NaN   NaN          NaN   NaN
# 1  changan     camioneta  hunter 1.9l comfort     NaN   4X4          NaN   NaN
# 2  changan     camioneta    hunter 1.9l elite     NaN   4X4          NaN   NaN
# 3  changan     camioneta   hunter 1.9l luxury     NaN   NaN          NaN   NaN
# 4  changan     camioneta   hunter 1.9l luxury     NaN   4X4          NaN   NaN

# %%
import re
import time
import requests

# Define a helper function to handle retries
def make_request_with_retry(url, retries=10, delay=2):
    for attempt in range(retries):
        try:
            response = requests.get(url)
            response.raise_for_status()
            return response
        except requests.exceptions.HTTPError as err:
            if response.status_code == 500:
                if attempt < retries - 1:
                    print(f"Server error (500) encountered at {url}. Waiting {delay} second(s) before retrying...")
                    time.sleep(delay)
                    continue
                else:
                    print(f"Failed to access {url} after {retries} attempts: {err}")
                    return None
            else:
                print(f"Failed to access {url}: {err}")
                return None
        except Exception as e:
            print(f"An error occurred while accessing {url}: {e}")
            return None

def normalize_string(s):
    s = s.lower()
    s = re.sub(r'[^\w\s]', '', s)
    s = re.sub(r'\s+', ' ', s)
    return s.strip()

def find_base_model_and_version(model_name):
    descriptors = ['advance', '3', 'row', 'e-power', 'exclusive', 'sense', 'le', 'xle', 'limited',
                   'luxury', 'pro', 'elite', 'glx', 'at', 'mt', '4x2', '4x4', 'awd', '2wd', 'dct',
                   'cvt', 'td', 'tdi', 'tdci', 's', 'se', 'lt', 'ltz', 'ls', 'premium', 'plus',
                   'xt', 'xtronic', 'sunroof', 'diesel', 'gasolina', 'elegance', 'hibrido', 'hev',
                   'hybrid', 'comfort', 'deluxe', 'gt', 'sport', 'xl', 'xlt', 'xse', 'p4x']
    words = normalize_string(model_name).split()
    base_model_words = [word for word in words if word not in descriptors]
    base_model_name = ' '.join(base_model_words)
    version_words = [word for word in words if word in descriptors]
    version_name = ' '.join(version_words)
    return base_model_name.strip(), version_name.strip()

def get_best_match(query, choices, cutoff=0.6):
    matches = get_close_matches(query, choices, n=1, cutoff=cutoff)
    if matches:
        return matches[0]
    else:
        # Attempt substring matching
        for choice in choices:
            if query in choice or choice in query:
                return choice
    return None

# %% [markdown]
# #### Guardamos el nombre de las marcas

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('csvs/parsed_output.csv')

# Extract the unique 'marca's
unique_marcas = df['marca'].drop_duplicates()

# Create a new DataFrame with the unique 'MARCA's
unique_marcas_df = pd.DataFrame(unique_marcas, columns=['macra'])

# Save the unique 'MARCA's to a new CSV file
unique_marcas_df.to_csv('unique_marcas.csv', index=False)

# %%
# Leer el archivo unique_marcas.csv
marcas_df = pd.read_csv('csvs/unique_marca_modelo_by_tipo_producto.csv')
marcas_df = marcas_df[['marca']].drop_duplicates()

# Lista para almacenar los datos
models_data = []

# Iterar sobre cada marca
for index, row in marcas_df.iterrows():
    manufacturer = str(row['marca']).lower()
    print(f"Procesando marca: {manufacturer}")
    
    # Construir la URL
    base_url = 'https://www.autocosmos.cl/catalogo/vigente/'
    manufacturer_normalized = normalize_string(manufacturer).replace(' ', '-')
    manufacturer_url = base_url + manufacturer_normalized
    
    # Realizar la solicitud HTTP con reintentos
    response = make_request_with_retry(manufacturer_url)
    if response is None:
        continue  # Saltar a la siguiente iteración si la solicitud falló
    
    # Analizar la página de la marca
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Encontrar la sección de modelos
    models_section = soup.find('section', class_='section m-brand')
    if models_section:
        model_links = models_section.find_all('a', href=True)
    else:
        print(f"No se encontraron modelos para {manufacturer}")
        continue
    
    # Extraer nombres de modelos y URLs
    for link in model_links:
        model_name = link.get('title', '').strip()
        model_href = link['href']
        # Construir la URL completa del modelo
        full_model_url = 'https://www.autocosmos.cl' + model_href
        
        # Almacenar los datos
        models_data.append({
            'MARCA': manufacturer.title(),
            'Model Name': model_name,
            'Model URL': full_model_url
        })

# Convertir la lista a un DataFrame
models_df = pd.DataFrame(models_data)

# Guardar en un archivo CSV
models_df.to_csv('csvs/models_by_marcas.csv', index=False)

# Mostrar una muestra de los datos
print(models_df.head())
# Out:
# Procesando marca: changan
# Procesando marca: chevrolet
# Procesando marca: dfsk
# Procesando marca: dongfeng
# Procesando marca: fiat
# Procesando marca: ford
# Procesando marca: foton
# Procesando marca: great wall
# Procesando marca: honda
# Procesando marca: jac
# Procesando marca: jmc
# Procesando marca: karry
# Procesando marca: kia
# Procesando marca: mahindra
# Procesando marca: maxus
# Procesando marca: mazda
# Procesando marca: mitsubishi
# Procesando marca: nissan
# Procesando marca: peugeot
# Procesando marca: ram
# Procesando marca: renault
# Procesando marca: ssangyong
# Procesando marca: suzuki
# Procesando marca: toyota
# Procesando marca: volkswagen
# Procesando marca: zna
# Procesando marca: baic
# Procesando marca: byd
# Procesando marca: chery
# Procesando marca: citroen
# Procesando marca: hyundai
# Procesando marca: mg
# Procesando marca: exeed
# Procesando marca: gac
# Procesando marca: haval
# Procesando marca: jeep
# Procesando marca: jetour
# Procesando marca: kaiyi
# Procesando marca: opel
# Procesando marca: subaru
# Procesando marca: farizon
# Failed to access https://www.autocosmos.cl/catalogo/vigente/farizon: 404 Client Error: Not Found for url: https://www.autocosmos.cl/catalogo/vigente/farizon
# Procesando marca: kyc
#      MARCA                                         Model Name  \
# 0  Changan  Changan Alsvin nuevos, precios del catálogo y ...
# 1  Changan  Changan CS15 nuevos, precios del catálogo y co...
# 2  Changan  Changan CS35 Plus  nuevos, precios del catálog...
# 3  Changan  Changan CS55 nuevos, precios del catálogo y co...
# 4  Changan  Changan CS55 Plus nuevos, precios del catálogo...
#
#                                            Model URL
# 0  https://www.autocosmos.cl/catalogo/vigente/cha...
# 1  https://www.autocosmos.cl/catalogo/vigente/cha...
# 2  https://www.autocosmos.cl/catalogo/vigente/cha...
# 3  https://www.autocosmos.cl/catalogo/vigente/cha...
# 4  https://www.autocosmos.cl/catalogo/vigente/cha...

# %%
df = pd.read_csv('csvs/models_by_marcas.csv')

# Function to clean the Model Name
def clean_model_name(row):
    marca = normalize_string(row['MARCA'].strip())
    model_name = row['Model Name'].strip()
    model_name_normalized = normalize_string(model_name)
    
    # Remove the manufacturer name from the model name
    pattern_marca = re.compile(r'\b' + re.escape(marca) + r'\b', re.IGNORECASE)
    model_name_cleaned = pattern_marca.sub('', model_name_normalized).strip()
    
    # Remove the phrase 'nuevos, precios del catálogo y cotizaciones.'
    phrase_to_remove = 'nuevos, precios del catalogo y cotizaciones.'
    model_name_cleaned = model_name_cleaned.replace(phrase_to_remove, '').strip()
    
    pattern_marca_original = re.compile(r'\b' + re.escape(row['MARCA']) + r'\b', re.IGNORECASE)
    model_name_original_cleaned = pattern_marca_original.sub('', row['Model Name']).strip()
    # Then remove the phrase (case-insensitive)
    pattern_phrase = re.compile(re.escape('nuevos, precios del catálogo y cotizaciones.'), re.IGNORECASE)
    model_name_original_cleaned = pattern_phrase.sub('', model_name_original_cleaned).strip()
    
    return model_name_original_cleaned

# Apply the cleaning function to the 'Model Name' column
df['Model Name'] = df.apply(clean_model_name, axis=1)

# Save the cleaned DataFrame to a new CSV
df.to_csv('models_by_marcas_cleaned.csv', index=False)

# %%
import pandas as pd
import unicodedata
import re
from fuzzywuzzy import fuzz

# Load CSV files
df1 = pd.read_csv('csvs/models_by_marcas_cleaned.csv')
df2 = pd.read_csv('csvs/parsed_output.csv')

# Standardize column names to lowercase
df1.columns = df1.columns.str.lower().str.strip()
df2.columns = df2.columns.str.lower().str.strip()

# Ensure correct data types and fill missing values
columns_to_normalize = ['marca', 'model name']
for col in columns_to_normalize:
    df1[col] = df1[col].astype(str).fillna('')
    df2[col] = df2[col].astype(str).fillna('')

# Function to normalize strings
def normalize_string(s):
    s = str(s).lower()
    s = ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )
    s = re.sub(r'[^\w\s]', '', s)  # Remove punctuation
    s = re.sub(r'\s+', ' ', s).strip()  # Remove extra spaces
    return s

# Normalize 'model name' and 'marca'
for df in [df1, df2]:
    df['model name simplified'] = df['model name'].apply(normalize_string)
    df['marca simplified'] = df['marca'].apply(normalize_string)

# Function to match model names
def match_model(row):
    marca = row['marca simplified']
    model_name = row['model name simplified']
    df1_marca = df1[df1['marca simplified'] == marca]
    if df1_marca.empty:
        return None

    # Try exact match first
    exact_matches = df1_marca[df1_marca['model name simplified'] == model_name]
    if not exact_matches.empty:
        return exact_matches.iloc[0]['model url']

    # Try substring match
    substring_matches = df1_marca[df1_marca['model name simplified'].apply(lambda x: x in model_name or model_name in x)]
    if not substring_matches.empty:
        return substring_matches.iloc[0]['model url']

    # Try fuzzy matching
    df1_marca['score'] = df1_marca['model name simplified'].apply(lambda x: fuzz.token_set_ratio(model_name, x))
    best_match = df1_marca.loc[df1_marca['score'].idxmax()]
    if best_match['score'] >= 80:  # Adjusted threshold
        return best_match['model url']
    else:
        return None
    
def match_model_2(row):
    marca = row['marca simplified']
    model_name = row['model name simplified']
    
    # Filter df1 by the same brand
    df1_marca = df1[df1['marca simplified'] == marca]
    if df1_marca.empty:
        return None

    # Compute fuzzy match scores for all models in the filtered df1
    df1_marca['score'] = df1_marca['model name simplified'].apply(lambda x: fuzz.token_set_ratio(model_name, x))
    
    # Select the top-scoring match
    best_match = df1_marca.loc[df1_marca['score'].idxmax()]
    return best_match['model url']


# Apply the matching function to df2
# df2['model url'] = df2.apply(match_model, axis=1)

# Save the updated df2
# df2.to_csv('csvs/parsed_output_with_urls.csv', index=False)

# Apply the matching function to df2
df2['model url'] = df2.apply(match_model_2, axis=1)

# Save the updated df2
df2.to_csv('csvs/parsed_output_with_urls_2.csv', index=False)

# Print the unmatched models
unmatched = df2[df2['model url'].isnull()]
print(unmatched)
# Out:
#         marca tipo producto model name  engine drive transmission    year  \
# 1532  farizon        furgon        v6e     NaN   NaN           AT  2024.0
#
#      model name simplified marca simplified model url
# 1532                   v6e          farizon      None

# %%
import pandas as pd

# Read the CSV file with Model URLs
df = pd.read_csv('csvs/parsed_output_with_urls_2.csv')

# Ensure 'Model URL' column is of string type and fill NaNs
df['model url'] = df['model url'].astype(str).fillna('')

# Drop empty URLs and get unique URLs
unique_urls = df['model url'][df['model url'] != ''].unique()

# Create a DataFrame from the unique URLs
df_unique_urls = pd.DataFrame(unique_urls, columns=['model url'])

# Save the unique URLs to a new CSV file
df_unique_urls.to_csv('csvs/unique_model_urls.csv', index=False)

print("Unique Model URLs have been saved to 'unique_model_urls.csv'.")
# Out:
# Unique Model URLs have been saved to 'unique_model_urls.csv'.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import re

# Read the unique URLs
df_urls = pd.read_csv('csvs/unique_model_urls.csv')

# Initialize a list to hold scraped data
scraped_data = []

max_retries = 10  # Maximum number of retries for 500 errors

for index, row in df_urls.iterrows():
    url = row['model url']
    print(f"Scraping URL: {url}")
    
    attempt = 0
    while attempt < max_retries:
        try:
            response = requests.get(url, timeout=None)
            if response.status_code == 500:
                print(f"Received 500 error on {url}, retrying... ({attempt + 1}/{max_retries})")
                attempt += 1
                time.sleep(1)  # Sleep before retrying
                continue
            else:
                response.raise_for_status()
                break  # Successful response, exit retry loop
        except requests.exceptions.RequestException as e:
            print(f"An error occurred for {url}: {e}")
            break  # Break on any request exception other than 500 error
    else:
        # This else executes if the loop completes without a break (after max retries)
        print(f"Failed to retrieve {url} after {max_retries} attempts.")
        continue

    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the table containing the versions
    version_table = soup.find('table', class_='table')
    if not version_table:
        print(f"No version table found at {url}")
        continue
    
    # Find all rows in the table body
    tbody = version_table.find('tbody')
    if not tbody:
        print(f"No table body found at {url}")
        continue

    rows = tbody.find_all('tr', itemprop='offers')
    versions = []
    for row in rows:
        # Find the meta tag with itemprop="name"
        meta_name = row.find('meta', itemprop='name')
        a_tag = row.find('a', itemprop='url')
        href = a_tag.get('href', '') if a_tag else ''
        if meta_name:
            version_name = meta_name.get('content', '')
            version_name = re.sub(r'\s*\(\d{4}\)\s*', '', version_name)
            full_url = "https://www.autocosmos.cl" + href
            versions.append([version_name, full_url])
    
    scraped_data.append({
        'model url': url,
        'versions': versions
    })
    
    time.sleep(3)

# Save the scraped data to a CSV
df_scraped = pd.DataFrame(scraped_data)

# Convert 'Versions' from list of lists to a string
def versions_to_string(versions_list):
    return '; '.join([f"{v[0]}: {v[1]}" for v in versions_list])

df_scraped['versions'] = df_scraped['versions'].apply(versions_to_string)

df_scraped.to_csv('csvs/model_versions.csv', index=False)

print("Scraping completed. Data saved to 'model_versions.csv'.")
# Out:
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/changan/hunter
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/changan/md201-pick-up
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/changan/md201-cargo-box
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/changan/x7-plus
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/changan/ms201-pick-up
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/colorado
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/montana
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/silverado
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/dfsk/d1
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/dongfeng/aeolus-gs-cross
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/fiat/ducato
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ford/maverick
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ford/ranger
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/foton/g7
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/great-wall/poer
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/great-wall/wingle-7-gasolina
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/honda/pilot
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jac/t6-diesel
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jac/t8
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jac/x200
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jmc/grand-avenue
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jmc/vigus-ev
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jmc/vigus-plus
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jmc/vigus-work
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jmc/vigus-pro
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/karry/q52
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kia/frontier
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mahindra/pik-up
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/maxus/g-10-cargo
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/maxus/deliver-9-cargo
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/maxus/edeliver-3
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/maxus/deliver-9-chasis
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/maxus/t60
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/maxus/t90
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mazda/bt-50
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mitsubishi/l200-dakar
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mitsubishi/l-200
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/nissan/navara
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/peugeot/boxer
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/peugeot/landtrek
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ram/v700-rapid
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ram/v700-city
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ram/rampage
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ram/700
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ram/1000
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/renault/oroch
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ssangyong/musso
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/suzuki/carry
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/hilux
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/fortuner
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/volkswagen/saveiro-cross
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/volkswagen/jetta-gli
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/volkswagen/saveiro
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/zna/df6
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/baic/eu5
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/byd/han-ev
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/byd/song-plus-dm-i
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/byd/seal
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/changan/alsvin
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chery/tiggo-3-pro
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/onix
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/sail
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/citroen/c-elysee
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/citroen/c3-bluehdi
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/fiat/mobi
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/fiat/fastback
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/honda/city
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/honda/civic
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/hyundai/grand-i10-sedan
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/hyundai/grand-i10
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/hyundai/palisade
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kia/ev6
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kia/soluto
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mazda/2
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mazda/3
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mazda/6
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mg/3
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mg/5
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mg/6
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mg/gt
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/nissan/leaf
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/nissan/sentra
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/nissan/versa
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/peugeot/3008-hybrid4
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/peugeot/partner
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/peugeot/e-partner
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/renault/kwid-e-tech
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/renault/koleos
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/suzuki/dzire
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/c-hr
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/corolla-cross
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/rush
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/yaris
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/volkswagen/virtus
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/baic/bj40-plus
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/baic/x35
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/baic/x55
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/byd/song-plus
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/byd/yuan-plus-ev
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/changan/cs15
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/changan/cs35-plus
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/changan/cs55
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/changan/star-truck-plus
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chery/tiggo-8
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chery/tiggo-2-pro-max
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/blazer
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/bolt
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/captiva-xl
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/groove
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/suburban
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/tahoe
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/traverse
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/onix-rs
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/tracker
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/citroen/berlingo
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/citroen/c5-aircross
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/dfsk/500-active
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/dfsk/560
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/dfsk/600
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/exeed/lx
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/exeed/txl
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/fiat/pulse
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ford/explorer-st
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ford/bronco-sport
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ford/f-150-raptor
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ford/transit-chasis
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ford/transit-custom
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ford/escape
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ford/expedition
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ford/explorer
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ford/territory
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/gac/emkoo
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/gac/emzoom
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/gac/gs3-power
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/gac/gs4-power
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/gac/gs8
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/haval/h6
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/haval/jolion
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/honda/cr-v
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/honda/hr-v
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/honda/wr-v
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/hyundai/creta
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/hyundai/ioniq-5
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/hyundai/kona
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/hyundai/santa-fe
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/hyundai/tucson
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/hyundai/venue
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jac/js2
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jac/js3
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jac/js4
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jac/js6
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jac/js8
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jac/sunray-pasajeros
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jac/refine-cargo-ev
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jeep/compass
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jeep/commander
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jeep/grand-cherokee
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jeep/grand-cherokee-l
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jeep/renegade
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jeep/wrangler
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jetour/dashing
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jetour/x70
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jetour/x90-plus
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kaiyi/x3
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kaiyi/x3-pro
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kia/carens
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kia/niro-hibrido
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kia/ev9
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kia/seltos
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kia/sonet
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kia/sorento
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kia/sportage
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mahindra/xuv-300
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/maxus/d60
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/maxus/d90
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/maxus/euniq-6
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/maxus/g90
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mazda/cx-3
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mazda/cx-30
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mazda/cx-5
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mazda/cx-9
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mg/hs
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mg/marvel-r
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mg/zs
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mg/one
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mg/rx5
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mg/zx
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mitsubishi/asx
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mitsubishi/eclipse-cross
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mitsubishi/montero-sport
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mitsubishi/outlander
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mitsubishi/xpander
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/nissan/kicks
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/nissan/pathfinder
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/nissan/qashqai
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/nissan/x-trail
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/opel/crossland
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/opel/grandland
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/opel/mokka
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/peugeot/traveller
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/peugeot/rifter
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/renault/arkana
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/renault/duster
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ssangyong/korando
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ssangyong/rexton
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ssangyong/tivoli
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ssangyong/torres
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/subaru/crosstrek
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/suzuki/jimny
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/suzuki/s-cross
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/suzuki/grand-vitara
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/suzuki/xl7
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/4runner
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/land-cruiser-prado
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/raize
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/rav4--hibrido
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/rav4
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/volkswagen/t-cross
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/volkswagen/tiguan
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/citroen/jumper
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/citroen/spacetourer
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ford/transit-bus
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/hyundai/staria-furgon
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/hyundai/santa-fe-hibrida
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/hyundai/staria
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jac/refine-cargo
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/maxus/g-10-ejecutiva
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/maxus/mifa-9
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/maxus/t90-ev
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/nissan/x-trail-e-power
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/hiace-pasajeros
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/hiace-furgon
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/yaris-gr
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/changan/m201-furgon
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/n400-max
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/citroen/jumpy
# Scraping URL: nan
# An error occurred for nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ford/transit-furgon
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kyc/gran-mamut-cargo-box
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/maxus/edeliver-9
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/opel/combo
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/peugeot/expert
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ram/v1000
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/fiat/500e
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/opel/corsa
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/peugeot/308
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/renault/kwid
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/suzuki/alto
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/suzuki/baleno
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/suzuki/s-presso
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/suzuki/swift
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/fortuner-gr-s
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/hilux-gr-s
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/yaris-cross
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/volkswagen/polo
# Scraping completed. Data saved to 'model_versions.csv'.

# %%
import pandas as pd
import re
from fuzzywuzzy import fuzz

# Read the CSV files
df_parsed = pd.read_csv('csvs/parsed_output_with_urls_2.csv')
df_versions = pd.read_csv('csvs/model_versions.csv')

# Function to parse the 'Versions' column
def parse_versions_string(versions_str):
    version_list = []
    if pd.isna(versions_str) or versions_str.strip() == '':
        return version_list
    versions = versions_str.split(';')
    for v in versions:
        v = v.strip()
        if not v:
            continue
        if ':' in v:
            name, url = v.split(':', 1)
            version_list.append([name.strip(), url.strip()])
        else:
            version_list.append([v.strip(), ''])
    return version_list

# Apply the parsing function to 'Versions' column
df_versions['versions'] = df_versions['versions'].apply(parse_versions_string)

# Function to simplify strings
def simplify_string(s):
    s = str(s).lower()
    s = re.sub(r'[^a-z0-9\s]', '', s)  # Remove special characters
    s = re.sub(r'\s+', ' ', s)  # Replace multiple spaces with single space
    s = s.strip()
    return s

# Simplify relevant columns in df_parsed
df_parsed['model name simplified'] = df_parsed['model name simplified'].apply(simplify_string)
df_parsed['engine simplified'] = df_parsed['engine'].apply(lambda x: simplify_string(x))
df_parsed['drive simplified'] = df_parsed['drive'].apply(lambda x: simplify_string(x))
df_parsed['transmission simplified'] = df_parsed['transmission'].apply(lambda x: simplify_string(x))

# Function to extract attributes from version name
def extract_attributes(version_name):
    version_name = version_name.lower()
    # Engine extraction
    engine_match = re.search(r'(\d+\.\d+|\d+)(l|t)?', version_name)
    engine = engine_match.group(1) if engine_match else ''
    # Drive extraction
    drive_match = re.search(r'(4x2|4x4|awd|fwd|rwd)', version_name)
    drive = drive_match.group(1) if drive_match else ''
    # Transmission extraction
    transmission_match = re.search(r'\b(mt|at|manual|aut|automatic)\b', version_name)
    transmission = transmission_match.group(1) if transmission_match else ''
    simplified_name = simplify_string(version_name)
    return simplified_name, engine, drive, transmission

# Initialize a list to hold the matched data
matched_data = []

for index, row in df_parsed.iterrows():
    model_url = row['model url']
    model_name_simplified = row['model name simplified']
    engine_simplified = row['engine simplified']
    drive_simplified = row['drive simplified']
    transmission_simplified = row['transmission simplified']

    # Get the versions corresponding to this model URL
    versions_row = df_versions[df_versions['model url'] == model_url]
    if versions_row.empty:
        matched_version = None
    else:
        versions_list = versions_row.iloc[0]['versions']
        best_score = -1  # Initialize to -1 to handle zero score cases
        best_match = None

        # If there is only one version, match it directly
        if len(versions_list) == 1:
            version = versions_list[0]
            version_name, version_url = version
            matched_version = {
                'Version URL': version_url,
            }
        else:
            for version in versions_list:
                version_name, version_url = version
                # Extract attributes
                version_name_simplified, v_engine, v_drive, v_transmission = extract_attributes(version_name)

                # Calculate matching score
                name_score = fuzz.token_sort_ratio(model_name_simplified, version_name_simplified)
                engine_score = fuzz.partial_ratio(engine_simplified, v_engine) if engine_simplified and v_engine else 0
                drive_score = 100 if drive_simplified == v_drive and drive_simplified else 0
                transmission_score = 100 if transmission_simplified == v_transmission and transmission_simplified else 0

                total_score = name_score + engine_score + drive_score + transmission_score

                if total_score > best_score:
                    best_score = total_score
                    best_match = {
                        'Version URL': version_url,
                    }

            matched_version = best_match

    # Ensure that all keys are present even if no match is found
    if not matched_version:
        matched_version = {
            'Version URL': None,
        }

    # Append matched version to the row
    matched_data.append({
        **row.to_dict(),
        **matched_version
    })

# Create a DataFrame from the matched data
df_matched = pd.DataFrame(matched_data)

# Remove duplicates based on 'Model Name', 'Engine', 'Drive', 'Transmission'
df_matched = df_matched.drop_duplicates(subset=['model name', 'engine', 'drive', 'transmission'])

# Save the matched data to a new CSV
df_matched.to_csv('csvs/matched_versions.csv', index=False)

print("Matching completed. Data saved to 'matched_versions.csv'.")
# Out:
# Matching completed. Data saved to 'matched_versions.csv'.

# %% [markdown]
# ### Correr esta celda para obtener el csv final "scraped_data.csv"

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import numpy as np

# Read the matched_versions.csv file
df_matched = pd.read_csv('csvs/matched_versions.csv')

# Initialize a list to hold the output data
output_data = []

for index, row in df_matched.iterrows():
    # Extract necessary fields and handle 'nan' values
    marca = str(row['marca']) if not pd.isna(row['marca']) else ''
    model_name = str(row['model name']) if not pd.isna(row['model name']) else ''
    engine = str(row['engine']) if not pd.isna(row['engine']) else ''
    drive = str(row['drive']) if not pd.isna(row['drive']) else ''
    transmission = str(row['transmission']) if not pd.isna(row['transmission']) else ''
    year = str(row['year']) if not pd.isna(row['year']) else ''
    version_url = str(row['Version URL']) if not pd.isna(row['Version URL']) else ''

    # Create the MODEL column and remove any 'nan' substrings
    model = ' '.join([marca, model_name, engine, drive, transmission, year])
    model = model.replace('nan', '').strip()

    # Remove any extra spaces
    model = ' '.join(model.split())

    # Print progress
    print(f"Processing model: {model}")

    # Check if version_url is valid
    if not version_url or pd.isna(version_url) or version_url.lower() == 'nan':
        print(f"Skipping {model} due to invalid Version URL")
        continue  # Skip to next row

    # Initialize retry parameters
    retries = 0
    max_retries = 20
    success = False

    while retries < max_retries and not success:
        try:
            response = requests.get(version_url)
            if response.status_code == 200:
                success = True
                html_content = response.content
            elif response.status_code == 500:
                retries += 1
                time.sleep(1)  # Wait for 1 second before retrying
                continue
            else:
                # Handle other HTTP errors
                print(f"Error fetching {version_url}: HTTP {response.status_code}")
                break
        except requests.exceptions.RequestException as e:
            print(f"Request exception for {version_url}: {e}")
            break

    if not success:
        print(f"Failed to fetch {version_url} after {retries} retries.")
        continue  # Skip to next row

    # Parse the HTML content with BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Initialize a dictionary to hold the attributes
    attributes = {}

    # Scrape 'Especificaciones técnicas' section
    especificaciones_section = soup.find('section', {'id': 'especificaciones'})
    if especificaciones_section:
        # Extract all tables within this section
        tables = especificaciones_section.find_all('table', {'class': 'ficha'})
        for table in tables:
            # Get the caption (category)
            caption_tag = table.find('caption')
            category = caption_tag.get_text(strip=True) if caption_tag else 'Unknown'

            # For each row in the table
            rows = table.find_all('tr')
            for row_tr in rows:
                cols = row_tr.find_all('td')
                if len(cols) == 2:
                    attr_name = cols[0].get_text(strip=True)
                    attr_value = cols[1].get_text(strip=True)
                    # Prefix the attribute name with the category to avoid duplicates
                    key = f"{category} - {attr_name}"
                    attributes[key] = attr_value
    else:
        print(f"No 'Especificaciones técnicas' section found in {version_url}")
        # We can continue to scrape 'Equipamiento' even if 'Especificaciones técnicas' is missing

    # Scrape 'Equipamiento' section
    equipamiento_section = soup.find('section', {'id': 'equipamiento'})
    if equipamiento_section:
        # Extract all tables within this section
        tables = equipamiento_section.find_all('table', {'class': 'ficha'})
        for table in tables:
            # Get the caption (category)
            caption_tag = table.find('caption')
            category = caption_tag.get_text(strip=True) if caption_tag else 'Unknown'

            # For each row in the table
            rows = table.find_all('tr')
            for row_tr in rows:
                cols = row_tr.find_all('td')
                if len(cols) == 2:
                    attr_name = cols[0].get_text(strip=True)
                    attr_value = cols[1].get_text(strip=True)
                    # Prefix the attribute name with the category to avoid duplicates
                    key = f"{category} - {attr_name}"
                    attributes[key] = attr_value
    else:
        print(f"No 'Equipamiento' section found in {version_url}")

    # Create a dictionary for this row
    data_row = {
        'model': model,
        'marca': marca,
        'model name': model_name,
        'engine': engine,
        'drive': drive,
        'transmission': transmission,
        'year': year,
        'version url': version_url
    }
    data_row.update(attributes)

    # Replace 'nan' with empty string in data_row values
    data_row = {k: ('' if v == 'nan' else v) for k, v in data_row.items()}

    # Append to output_data
    output_data.append(data_row)

# Create a DataFrame from the output data
df_output = pd.DataFrame(output_data)

# Drop columns that are entirely empty
df_output.dropna(axis=1, how='all', inplace=True)

# Replace NaN values with empty strings
df_output.fillna('', inplace=True)

# Save to a new CSV file
df_output.to_csv('csvs/scraped_data.csv', index=False)

print("Data scraping completed. Results saved to 'scraped_data.csv'.")
# Out:
# Processing model: changan hunter 1.9l comfort
# Processing model: changan hunter 1.9l comfort 4X4
# Processing model: changan hunter 1.9l elite 4X4
# Processing model: changan hunter 1.9l luxury
# Processing model: changan hunter 1.9l luxury 4X4
# Processing model: changan hunter comfort 2.0t 4X2 MT 2024.0
# Processing model: changan hunter comfort 2.0t 4X4 MT 2024.0
# Processing model: changan hunter elite sport 2.0t 4X4 MT 2024.0
# Processing model: changan hunter luxury 2.0t 4X2 MT 2024.0
# Processing model: changan md 301 ac esp MT 2024.0
# Processing model: changan md201 1.2l pick up
# Processing model: changan md201 1.2l pick up ac
# Processing model: changan md201 1.5l xl
# Processing model: changan md201 1.5l xl ac
# Processing model: changan md201 MT 2024.0
# Processing model: changan md201 xl 1.5l MT 2024.0
# Processing model: changan ms 201 MT 2024.0
# Processing model: changan ms 301 plus ac esp 2024.0
# Processing model: changan ms201 1.2l pick-up
# Processing model: changan ms201 1.2l pick-up plus
# Processing model: chevrolet colorado 2.8l high country aut 4X4
# Processing model: chevrolet colorado 2.8l ltz 4X4
# Processing model: chevrolet colorado 2.8l ltz aut 4X4
# Processing model: chevrolet colorado hc 2.8td 4WD AT
# Processing model: chevrolet colorado hc 2.8td l 4WD AT
# Processing model: chevrolet colorado high country 4X4 AT 2024.0
# Processing model: chevrolet colorado ls 4X2 MT 2024.0
# Processing model: chevrolet colorado lt 4X4 AT 2024.0
# Processing model: chevrolet colorado lt 4X4 MT 2024.0
# Processing model: chevrolet colorado lt 2.8td m 4WD AT
# Processing model: chevrolet colorado lt 2.8td m 4WD MT
# Processing model: chevrolet colorado ltz 4X4 AT 2024.0
# Processing model: chevrolet colorado ltz 2.8td 4WD AT
# Processing model: chevrolet colorado ltz 2.8td l 4WD AT
# Processing model: chevrolet colorado z71 4X4 AT 2024.0
# Processing model: chevrolet montana t lt 1.2 MT 2024.0
# Processing model: chevrolet montana t ltz 1.2 AT 2024.0
# Processing model: chevrolet montana t premier 1.2 AT 2024.0
# Processing model: chevrolet montana t premier 1.2 MT 2024.0
# Processing model: chevrolet montana t rs 1.2 AT 2024.0
# Processing model: chevrolet silverado 3.0l diesel ltz 4X4
# Processing model: chevrolet silverado 5.3l lt trailboss 4X4
# Processing model: chevrolet silverado 5.3l ltz 4X4
# Processing model: chevrolet silverado cc lt tb 5.3l
# Processing model: chevrolet silverado cc lt tb 5.3l l
# Processing model: chevrolet silverado cc ltz 3.0td
# Processing model: chevrolet silverado cc ltz 5.3l
# Processing model: chevrolet silverado cc ltz 5.3l l
# Processing model: chevrolet silverado hc td 3.0 4X4 AT 2024.0
# Processing model: chevrolet silverado lt trail boss z71 5.3l v8 4X4 AT 2024.0
# Processing model: chevrolet silverado zr2 6.2l v8 4X4 AT 2024.0
# Processing model: dfsk d1 confort 4X2 MT 2024.0
# Processing model: dfsk d1 luxury 4X4 AT 2024.0
# Processing model: dfsk d1 luxury 4X4 MT 2024.0
# Processing model: dongfeng df 212 cs MT 2024.0
# Processing model: fiat ram 700 slt dc 1.4 MT
# Processing model: ford maverick lariat fx4 hev AT 2024.0
# Processing model: ford maverick xlt 2.0 4X2 AT 2024.0
# Processing model: ford ranger 2.2l tdci xl 4X2
# Processing model: ford ranger 2.2l tdci xl 4X4
# Processing model: ford ranger 2.5l xlt 4X2
# Processing model: ford ranger 3.2l tdci ltd aut 4X4
# Processing model: ford ranger 3.2l tdci xls 4X4
# Processing model: ford ranger 3.2l tdci xlt 4X2
# Processing model: ford ranger 3.2l tdci xlt 4X4
# Processing model: ford ranger 3.2l tdci xlt aut 4X4
# Processing model: ford ranger dsl limited 3.0 4X4 AT 2024.0
# Processing model: ford ranger dsl limited 3.2l 4X4 AT
# Processing model: ford ranger dsl xl 2.0 4X2 MT 2024.0
# Processing model: ford ranger dsl xl 2.0 4X4 MT 2024.0
# Processing model: ford ranger dsl xl 2.2l 4X2
# Processing model: ford ranger dsl xl 2.2l 4X4
# Processing model: ford ranger dsl xls 2.0 4X2 MT 2024.0
# Processing model: ford ranger dsl xls 2.0 4X4 MT 2024.0
# Processing model: ford ranger dsl xls 3.2l 4X4
# Processing model: ford ranger dsl xlt 2.0 4X2 AT 2024.0
# Processing model: ford ranger dsl xlt 2.0 4X4 AT 2024.0
# Processing model: ford ranger dsl xlt 2.0 4X4 MT 2024.0
# Processing model: ford ranger dsl xlt 3.2l 4X2
# Processing model: ford ranger dsl xlt 3.2l 4X4
# Processing model: ford ranger dsl xlt 3.2l 4X4 AT
# Processing model: ford ranger gas limited 2.5l cng
# Processing model: ford ranger gas xlt 2.5l cng
# Processing model: foton g7 lite 4X4 2024.0
# Processing model: foton g7 ultimate 4X2 2024.0
# Processing model: foton g7 ultimate 4X4 2024.0
# Processing model: great wall poer 2.0l deluxe 4X2
# Processing model: great wall poer 2.0l deluxe 4X4
# Processing model: great wall poer 2.0l deluxe plus aut 4X4
# Processing model: great wall poer 2.0l elite 4X2
# Processing model: great wall poer 2.0l elite 4X4
# Processing model: great wall poer 2.0l elite plus aut 4X4
# Processing model: great wall poer deluxe 4X2 2024.0
# Processing model: great wall poer elite 4X2 2024.0
# Processing model: great wall poer elite pant 4X2 2024.0
# Processing model: great wall poer deluxe 4X4 2024.0
# Processing model: great wall poer elite 4X4 2024.0
# Processing model: great wall poer elite pant 4X4 2024.0
# Processing model: great wall poer plus elite 4X2 2024.0
# Processing model: great wall poer plus deluxe 4X4 2024.0
# Processing model: great wall poer plus elite 4X4 2024.0
# Processing model: great wall wingle 7 elite 4X2 2024.0
# Processing model: great wall wingle 7 elite plus 4X4 2024.0
# Processing model: great wall wingle5 2.2l elite gasolina
# Processing model: great wall wingle7 2.0l deluxe 4X4
# Processing model: great wall wingle7 2.0l elite 4X2
# Processing model: great wall wingle7 2.0l elite 4X4
# Processing model: honda ridgeline rtl sensing 3.5 4X4 AT
# Processing model: jac t6 2.0l comfort 4X2
# Processing model: jac t6 2.0l comfort diesel 4X2
# Processing model: jac t8 2.0l advance 4X2
# Processing model: jac t8 2.0l advance 4X4
# Processing model: jac t8 2.0l comfort 4X2
# Processing model: jac t8 2.0l comfort 4X4
# Processing model: jac t8 ce comfort 2.0t 4X2 MT 2024.0
# Processing model: jac t8 ce comfort 2.0t 4X4 MT 2024.0
# Processing model: jac t8 pro advance 4X4 MT 2024.0
# Processing model: jac t8 pro luxury 4X2 MT 2024.0
# Processing model: jac t8 pro luxury 4X4 MT 2024.0
# Processing model: jac t8 xe advance 2.0t 4X2 MT 2024.0
# Processing model: jac t8 xe advance 2.0t 4X4 MT 2024.0
# Processing model: jac x200 2.0l chasis comfort
# Processing model: jac x200 2.0l chasis luxury
# Processing model: jac x200 2.0l pickup comfort
# Processing model: jac x200 2.0l pickup dc
# Processing model: jac x200 2.0l pickup luxury
# Processing model: jmc grand avenue 4X2 AT 2024.0
# Processing model: jmc grand avenue 4X2 MT 2024.0
# Processing model: jmc grand avenue 4X4 AT 2024.0
# Processing model: jmc grand avenue 4X4 MT 2024.0
# Processing model: jmc vigus ev AT 2024.0
# Processing model: jmc vigus new plus 4X2 MT 2024.0
# Processing model: jmc vigus new plus 4X4 MT 2024.0
# Processing model: jmc vigus new work 4X2 MT 2024.0
# Processing model: jmc vigus new work 4X4 MT 2024.0
# Processing model: jmc vigus pro 4X2 AT 2024.0
# Processing model: jmc vigus pro 4X4 AT 2024.0
# Processing model: karry q52 cd 1.6l MT 2024.0
# Processing model: kia frontier c/c lx 2.5l av ab MT 2024.0
# Processing model: kia frontier c/c lx 2.5l av MT 2024.0
# Processing model: kia frontier d/c lx 2.5l av ab MT 2024.0
# Processing model: kia frontier p/up lx 2.5l av ab MT 2024.0
# Processing model: mahindra pik up 2.2l dc full 4X2
# Processing model: mahindra pik up 2.2l dc work 4X4
# Processing model: maxus c35
# Processing model: maxus c35 carroceria plana
# Processing model: maxus c35 l
# Processing model: maxus c35 l carroceria plana
# Processing model: maxus new v80 fl chasis cabina
# Processing model: maxus new v80 fl chasis carroceria carga general
# Processing model: maxus new v80 fl chassis carroceria plana
# Processing model: maxus t60 2.8l dx 4X2
# Processing model: maxus t60 2.8l dx cs 4X2
# Processing model: maxus t60 2.8l dx 4X4
# Processing model: maxus t60 2.8l dx cs 4X4
# Processing model: maxus t60 2.8l gl 4X2
# Processing model: maxus t60 2.8l gl aut 4X2
# Processing model: maxus t60 2.8l gl 4X4
# Processing model: maxus t60 2.8l glx aut 4X4
# Processing model: maxus t60 ancap e6 4X4 MT 2024.0
# Processing model: maxus t60 dx 4X2 MT 2024.0
# Processing model: maxus t60 dx d20 4X4
# Processing model: maxus t60 dx e6 4X2 MT 2024.0
# Processing model: maxus t60 dx e6 4X4 MT 2024.0
# Processing model: maxus t60 e6 gl 4X2 AT 2024.0
# Processing model: maxus t60 e6 gl 4X2 MT 2024.0
# Processing model: maxus t60 e6 gl 4X4 MT 2024.0
# Processing model: maxus t60 e6 glx 4X4 AT 2024.0
# Processing model: maxus t60 gl d20 4X4
# Processing model: maxus t60 glx d20 4X4
# Processing model: maxus t60 sc dx e6 4X2 MT 2024.0
# Processing model: maxus t60 sc dx e6 4X4 MT 2024.0
# Processing model: maxus t90 e6 4X4 AT 2024.0
# Processing model: maxus t90 e6 4X4 MT 2024.0
# Processing model: maxus t90 ev 4X2 AT 2024.0
# Processing model: mazda bt-50 core 4X4 AT 2024.0
# Processing model: mazda bt-50 core 4X4 MT 2024.0
# Processing model: mazda bt-50 high 4X4 AT 2024.0
# Processing model: mazda bt-50 high plus 4X4 AT 2024.0
# Processing model: mitsubishi l 200 dc td dakar crs 4X4 AT
# Processing model: mitsubishi l 200 dc td dakar crs hp 4X4 AT
# Processing model: mitsubishi l 200 dc td dakar crs 4X4 MT
# Processing model: mitsubishi l 200 dc td dakar crs hp 4X4 MT
# Processing model: mitsubishi l-200 -d/c td dakar crs 4X2 AT
# Processing model: mitsubishi l-200 -d/c td dakar crs hp 4X2 AT
# Processing model: mitsubishi l-200 -d/c td dakar crs 4X2 MT
# Processing model: mitsubishi l-200 -d/c td dakar crs hp 4X2 MT
# Processing model: mitsubishi l-200 -d/c td katana cr 4X2
# Processing model: mitsubishi l-200 -d/c td katana crm 4X2
# Processing model: mitsubishi l-200 -d/c td katana crt 4X2
# Processing model: mitsubishi l-200 -d/c td work cr 4X2
# Processing model: mitsubishi l-200 2.4l dakar crs 4X4 AT
# Processing model: mitsubishi l-200 2.4l dakar crs 4X4 MT
# Processing model: mitsubishi l-200 2.4l dakar hp 4X4 AT
# Processing model: mitsubishi l-200 2.4l dakar hp 4X4 MT
# Processing model: mitsubishi l-200 2.4l katana cr 4X2
# Processing model: mitsubishi l-200 2.4l katana crm 4X4
# Processing model: mitsubishi l-200 2.4l katana crt 4X4
# Processing model: mitsubishi l-200 2.4l katana crt sc 4X4
# Processing model: mitsubishi l-200 2.4l work cr 4X2
# Processing model: mitsubishi l-200 2.4l work cr sc 4X2
# Processing model: mitsubishi l200 katana cr 4X2
# Processing model: mitsubishi l200 work cr 4X2
# Processing model: mitsubishi l200 katana crm 4X4
# Processing model: mitsubishi l200 katana crt 4X4
# Processing model: mitsubishi l200 d/c td dakar crs 4X4 MT 2024.0
# Processing model: mitsubishi l200 d/c td katana cr 4X2 MT 2024.0
# Processing model: mitsubishi l200 d/c td katana crt 4X4 MT 2024.0
# Processing model: mitsubishi l200 d/c td work cr 4X2 MT 2024.0
# Processing model: mitsubishi l200 dakar AT
# Processing model: mitsubishi l200 dakar hp AT
# Processing model: mitsubishi l200 dakar high power AT
# Processing model: mitsubishi l200 dakar high power MT
# Processing model: mitsubishi l200 dakar MT
# Processing model: mitsubishi l200 dakar hp MT
# Processing model: mitsubishi l200 katana crt sc 4X4
# Processing model: mitsubishi l200 work cr sc 4X2
# Processing model: nissan navara cd le 4X4 AT
# Processing model: nissan navara cd pro4x 4X4
# Processing model: nissan navara cd le 4X4
# Processing model: nissan navara cd se 4X2
# Processing model: nissan navara cd se 4X4
# Processing model: nissan navara cd xe 4X2
# Processing model: nissan navara cd xe 4X4
# Processing model: nissan navara cs s 4X4
# Processing model: nissan navara dc p4x 2024.0
# Processing model: nissan navara dc platinum 2.3d 4X4 AT 2024.0
# Processing model: nissan navara dc platinum 2.3d 4X4 MT 2024.0
# Processing model: nissan navara dc se 2.3d 4X2 MT 2024.0
# Processing model: nissan navara dc se 2.3d 4X4 MT 2024.0
# Processing model: nissan navara dc xe 2.3d 4X2 MT 2024.0
# Processing model: nissan navara dc xe 2.3d 4X4 AT 2024.0
# Processing model: nissan navara dc xe 2.3d 4X4 MT 2024.0
# Processing model: nissan navara np300 2.3d dc se
# Processing model: nissan navara np300 2.3l le dc 4X4
# Processing model: nissan navara np300 2.3l le dc audio 4X4
# Processing model: nissan navara np300 2.3l le dc aut 4X4
# Processing model: nissan navara np300 2.3l le dc aut audio 4X4
# Processing model: nissan navara np300 2.3l le dc aut – audio 4X4
# Processing model: nissan navara np300 2.3l le dc 4X4 MT
# Processing model: nissan navara np300 2.3l le dc mt- audio 4X4
# Processing model: nissan navara np300 2.3l s sc 4X4
# Processing model: nissan navara np300 2.3l se dc 4X2
# Processing model: nissan navara np300 2.3l se dc 4X4
# Processing model: nissan navara np300 2.3l xe dc 4X2
# Processing model: nissan navara np300 2.3l xe dc audio 4X2
# Processing model: nissan navara np300 2.3l xe dc 4X4
# Processing model: nissan navara np300 2.3l xe dc audio 4X4
# Processing model: nissan np300 navara d23 dc le 2.3d 4WD AT
# Processing model: nissan np300 navara d23 dc le 2.3d - audio 4WD AT
# Processing model: nissan np300 navara d23 dc le 2.3d 4WD MT
# Processing model: nissan np300 navara d23 dc le 2.3d - audio 4WD MT
# Processing model: nissan np300 navara d23 dc se 2.3d MT
# Processing model: nissan np300 navara d23 dc se 2.3d 4WD MT
# Processing model: nissan np300 navara d23 dc xe 2.3d MT
# Processing model: nissan np300 navara d23 dc xe 2.3d - radio MT
# Processing model: nissan np300 navara d23 dc xe 2.3d 4WD MT
# Processing model: nissan np300 navara d23 dc xe 2.3d - radio 4WD MT
# Processing model: nissan np300 navara d23 sc s 2.3d 4WD MT
# Processing model: nissan np300 navara dc xe 2.5 MT
# Processing model: nissan np300 navara sc s 2.3d MT
# Processing model: nissan np300 navara sc s 2.3d 4WD MT
# Processing model: peugeot boxer cabina l3 bluehdi 160
# Processing model: peugeot boxer doble cabina l4 bluehdi 160
# Processing model: peugeot landtrek action4 bluehdi 180 4X4 AT 2024.0
# Processing model: peugeot landtrek active bluehdi 180 4X2 MT 2024.0
# Processing model: peugeot landtrek active bluehdi 180 4X4 AT 2024.0
# Processing model: peugeot landtrek active bluehdi 180 4X4 MT 2024.0
# Processing model: ram big horn at6 lx 1.8 1000.0
# Processing model: ram bighorn lx 1.8 AT 2024.0
# Processing model: ram bighorn night edition 1.8 AT 2024.0
# Processing model: ram laramie 2.0 4X4 AT 1000.0
# Processing model: ram rebel 2.0 4X4 AT 2024.0
# Processing model: ram big horn 1500.0
# Processing model: ram big horn 3.6l e torque 1500.0
# Processing model: ram crew cab bighorn 3.6l AT 2024.0
# Processing model: ram crew cab limited 5.7l AT 2024.0
# Processing model: ram crew cab rebel 5.7l AT 2024.0
# Processing model: ram laramie sport 1500.0
# Processing model: ram limited 1500.0
# Processing model: ram big horn crew cab diesel 6.7 2500.0
# Processing model: ram 700 bighorn cd 1.3 AT 2024.0
# Processing model: ram 700 bighorn cd 1.3l MT 2024.0
# Processing model: ram 700 laramie cd 1.3 AT 2024.0
# Processing model: ram 700 laramie cd 1.3l MT 2024.0
# Processing model: ram 700 longhorn cd 1.3 AT 2024.0
# Processing model: ram 700 slt cs 1.3l MT 2024.0
# Processing model: ram 700 slt dc 1.3l MT 2024.0
# Processing model: ram new ram crew cab big horn 3.6l e-torque 1500.0
# Processing model: ram new ram crew cab laramie 5.7l 1500.0
# Processing model: ram new ram crew cab laramie sport 5.7l 1500.0
# Processing model: ram new ram crew cab limited 5.7l 1500.0
# Processing model: ram ram 100 big horn lx
# Processing model: ram ram 100 laramie diesel 4X4
# Processing model: ram ram big horn 1000.0
# Processing model: ram ram quad cab 3.6l 4X4 1500.0
# Processing model: ram ram 700 big horn
# Processing model: ram ram 700 laramie
# Processing model: ram ram 700 slt cs
# Processing model: ram ram 700 slt dc
# Processing model: ram rampage bighorn 2.0l AT 2024.0
# Processing model: ram rampage laramie 2.0l AT 2024.0
# Processing model: ram rampage r/t 2.0l AT 2024.0
# Processing model: renault oroch 1.6l zen
# Processing model: renault oroch 1.6l zen kit outsider
# Processing model: renault oroch 2.0l intens 4X4
# Processing model: renault oroch intens turbo 1.3 4X2 AT 2024.0
# Processing model: renault oroch intens turbo kit 1.3 4X2 AT 2024.0
# Processing model: renault oroch intens turbo kitmt 1.3 4X4 2024.0
# Processing model: renault oroch intens turbo 1.3 4X4 MT 2024.0
# Processing model: renault oroch zen 1.6l 4X2 MT 2024.0
# Processing model: ssangyong all new musso full qs723 4WD AT
# Processing model: ssangyong all new musso qs722 4WD AT
# Processing model: ssangyong musso 2,2 deluxe 4X4 AT
# Processing model: ssangyong musso deluxe full 2.2l 4X4 AT
# Processing model: ssangyong musso full 2.2l 4X4 AT
# Processing model: ssangyong musso full 2.2l 4X4 MT
# Processing model: ssangyong musso deluxe diesel 2.2l
# Processing model: ssangyong musso full diesel 2.2l
# Processing model: ssangyong musso glx 2.2td 4X4 MT 2024.0
# Processing model: ssangyong musso grand diesel 2.2l AT
# Processing model: ssangyong musso grand full diesel 2.2l
# Processing model: ssangyong musso grand full diesel 2.2l AT
# Processing model: ssangyong musso grand full diesel 2.2l MT
# Processing model: ssangyong musso grand full diesel 2.2l sc MT
# Processing model: ssangyong musso grand full diesel 2.2l 4X4
# Processing model: ssangyong musso grand full diesel 2.2l 4X4 MT
# Processing model: ssangyong musso grand glx 2.2td 4X2 AT 2024.0
# Processing model: ssangyong musso grand glx 2.2td 4X2 MT 2024.0
# Processing model: ssangyong musso grand glx 2.2td 4X4 MT 2024.0
# Processing model: ssangyong musso grand limited 2.2td 4X4 AT 2024.0
# Processing model: ssangyong musso grand limited plus 2.2td 4X4 AT 2024.0
# Processing model: ssangyong musso grand lx 2.2td 4X2 MT 2024.0
# Processing model: ssangyong musso grand lx 2.2td 4X4 MT 2024.0
# Processing model: ssangyong musso limited 2.2td 4X4 AT 2024.0
# Processing model: ssangyong musso limited plus 2.2td 4X4 AT 2024.0
# Processing model: ssangyong musso xdi 2.2l 4X4
# Processing model: suzuki carry pick up
# Processing model: toyota dx 2.4 4X2 MT
# Processing model: toyota hilux sr 2.4 4X2 MT
# Processing model: toyota hilux dx cabina simple 2.4 4X4
# Processing model: toyota hilux dx 2.4 4X4 MT
# Processing model: toyota hilux sr 2.4 4X4 MT
# Processing model: toyota hilux 2.4l dx cd 4X2
# Processing model: toyota hilux 2.4l dx cd 4X4
# Processing model: toyota hilux 2.4l dx cs 4X4
# Processing model: toyota hilux 2.4l sr cd 4X2
# Processing model: toyota hilux 2.4l sr cd 4X4
# Processing model: toyota hilux dx gasolina 2.7 4X2 MT
# Processing model: toyota hilux sr gasolina 2.7 4X2 MT
# Processing model: toyota hilux 2.7l dx gasolina cd 4X2
# Processing model: toyota hilux 2.7l sr gasolina cd 4X2
# Processing model: toyota hilux srv 2.8 4X4 AT
# Processing model: toyota hilux sr 2.8 4X4 MT
# Processing model: toyota hilux sr r 2.8 4X4 MT
# Processing model: toyota hilux 2.8l sr cd 4X4
# Processing model: toyota hilux 2.8l srv cd aut 4X4
# Processing model: toyota hilux dx 2.4 4X2 MT 2024.0
# Processing model: toyota hilux dx 2.8 4X4 MT 2024.0
# Processing model: toyota hilux dx cs 2.8 4X4 MT 2024.0
# Processing model: toyota hilux dx dc 2.4 4X2 MT 2024.0
# Processing model: toyota hilux dx dc 2.4 4X4 MT 2024.0
# Processing model: toyota hilux sr 2.7 4X2 MT 2024.0
# Processing model: toyota hilux sr dc 2.4 4X2 MT 2024.0
# Processing model: toyota hilux sr dc 2.4 4X4 MT 2024.0
# Processing model: toyota tundra sr5 4X4
# Processing model: volkswagen amarok 2.0l comfortline 4motion
# Processing model: volkswagen amarok 2.0l comfortline 4motion aut
# Processing model: volkswagen amarok 2.0l comfortline 4X2
# Processing model: volkswagen amarok 2.0l highline 4motion aut
# Processing model: volkswagen amarok 2.0l trendline 4motion
# Processing model: volkswagen amarok 2.0l trendline 4X2
# Processing model: volkswagen amarok 3.0l v6
# Processing model: volkswagen nueva amarok comfortline 4motion
# Processing model: volkswagen nueva amarok comfortline 4motion AT
# Processing model: volkswagen nueva amarok comfortline 4X2
# Processing model: volkswagen nueva amarok highline 4motion AT
# Processing model: volkswagen nueva amarok trendline 4motion
# Processing model: volkswagen nueva amarok trendline 4X2
# Processing model: volkswagen nueva amarok v6 4X4 AT
# Processing model: volkswagen nueva saveiro cross
# Processing model: volkswagen saveiro 1.6l cabina simple
# Processing model: volkswagen saveiro 1.6l doble cabina comfortline
# Processing model: volkswagen saveiro cross 1.6l
# Processing model: zna r6 AT 2024.0
# Processing model: baic eu5 ev 2024.0
# Processing model: byd han ev 2024.0
# Processing model: byd qin plus dm 2024.0
# Processing model: byd seal ev 2024.0
# Processing model: changan alsvin 1.4l comfort
# Processing model: changan alsvin 1.4l luxury
# Processing model: changan alsvin comfort 2024.0
# Processing model: changan alsvin elite AT 2024.0
# Processing model: changan alsvin luxury 2024.0
# Processing model: chery arrizo 3 1.5l gls
# Processing model: chery arrizo 3 1.5l gls sc
# Processing model: chery arrizo 3 1.5l glx
# Processing model: chery arrizo 3 gls MT
# Processing model: chery arrizo 3 glx MT
# Processing model: chevrolet onix lt r 1.0 2024.0
# Processing model: chevrolet onix ltz p2 1.0 2024.0
# Processing model: chevrolet onix premier r 1.0 2024.0
# Processing model: chevrolet onix ls p 1.2 2024.0
# Processing model: chevrolet onix ii ls nb 1.2 MT
# Processing model: chevrolet onix ii lt 1.0t nb MT
# Processing model: chevrolet onix ii pr 1.0t nb AT
# Processing model: chevrolet onix ll ls nb 1.2 MT
# Processing model: chevrolet onix ll lt t nb 1.0 MT
# Processing model: chevrolet onix ll pr 1.0t nb AT
# Processing model: chevrolet onix sedan 1.0l lt
# Processing model: chevrolet onix sedan 1.2l ls
# Processing model: chevrolet sail 1.5l ls abs nb
# Processing model: chevrolet sail 1.5l ls nb
# Processing model: chevrolet sail 1.5l lt nb
# Processing model: chevrolet sail 1.5l lt nb smart
# Processing model: chevrolet sail nb ls abs l 1.5
# Processing model: chevrolet sail nb lt l smart 1.5
# Processing model: chevrolet sail nb 1.5l lt 2024.0
# Processing model: chevrolet sail nb 1.5l ltz 2024.0
# Processing model: chevrolet sail nb 1.5l ltz CVT 2024.0
# Processing model: citroen hdi 100 bvm6 c-elysee feel pack 1.5 2024.0
# Processing model: citroen c4 bluehdi 130 s&s feel pack 1.5 EAT8 2024.0
# Processing model: citroen c4 bluehdi 130 s&s shine 1.5 EAT8 2024.0
# Processing model: citroen new c-elysee 1.2l puretech 82 bvm feel
# Processing model: citroen new c-elysee 1.6l hdi 92 bvm feel
# Processing model: citroen new c-elysee 1.6l hdi 92 bvm shine
# Processing model: fiat argo drive 1.3
# Processing model: fiat argo trekking 1.3
# Processing model: honda city ex 1.5 AT
# Processing model: honda city ex 1.5 MT
# Processing model: honda city lx 1.5 AT
# Processing model: honda city lx 1.5 MT
# Processing model: honda civic sedan ex 2.0 CVT
# Processing model: honda civic sedan exl t 1.5
# Processing model: hyundai accent bn7i design 1.5 2024.0
# Processing model: hyundai accent bn7i plus 1.5 2024.0
# Processing model: hyundai grand i10 ai3 design fl 1.2 2024.0
# Processing model: hyundai grand i10 ai3 plus fl 1.2 2024.0
# Processing model: hyundai verna 1.4l plus
# Processing model: kia ev6 ev gt-line 77.4kwh AWD 2024.0
# Processing model: kia soluto ex 1.4l g srf full 5MT 2024.0
# Processing model: kia soluto lx 1.4l g ll 5MT 2024.0
# Processing model: mazda 2 1.5l s ipm
# Processing model: mazda 2 1.5l v aut ipm
# Processing model: mazda 2 1.5l v ipm
# Processing model: mazda 3 2.0l s
# Processing model: mazda 3 2.0l v
# Processing model: mazda 3 2.0l v aut
# Processing model: mazda 3 2.5l gtx aut
# Processing model: mazda 6 2.0l v
# Processing model: mazda 6 2.5l gtx turbo aut
# Processing model: mazda 6 sdn v cuero 2.5 6AT
# Processing model: mg 3 com AT 2024.0
# Processing model: mg 5 1.5l com CVT 2024.0
# Processing model: mg 5 1.5l dlx CVT 2024.0
# Processing model: mg 5 1.5l com MT 2024.0
# Processing model: mg 5 1.5l dlx MT 2024.0
# Processing model: mg 6 1.5t com MT 2024.0
# Processing model: mg 6 1.5t dlx MT 2024.0
# Processing model: mg gt 1.5l com 2WD CVT 2024.0
# Processing model: mg gt 1.5l com 2WD MT 2024.0
# Processing model: mg gt 1.5t dlx DCT 2024.0
# Processing model: nissan leaf
# Processing model: nissan new sentra 2.0l advance
# Processing model: nissan new sentra 2.0l advance aut
# Processing model: nissan new sentra 2.0l advance CVT
# Processing model: nissan new sentra 2.0l advance MT
# Processing model: nissan new sentra 2.0l exclusive aut
# Processing model: nissan new sentra 2.0l exclusive CVT
# Processing model: nissan new sentra 2.0l sense
# Processing model: nissan new sentra 2.0l sense MT
# Processing model: nissan new versa 1.6l advance aut
# Processing model: nissan new versa 1.6l advance CVT
# Processing model: nissan new versa 1.6l advance MT
# Processing model: nissan new versa 1.6l exclusive aut
# Processing model: nissan new versa 1.6l exclusive CVT
# Processing model: nissan new versa 1.6l sense aut
# Processing model: nissan new versa 1.6l sense CVT
# Processing model: nissan new versa 1.6l sense radio touch CVT
# Processing model: nissan new versa 1.6l sense MT
# Processing model: nissan new versa 1.6l sense radio touch MT
# Processing model: nissan new versa advance CVT
# Processing model: nissan new versa advance MT
# Processing model: nissan new versa exclusive CVT
# Processing model: nissan new versa sense 1.6
# Processing model: nissan new versa sense 1.6 CVT
# Processing model: nissan new versa sense CVT
# Processing model: nissan new versa sense MT
# Processing model: nissan sentra 1.8l advance
# Processing model: nissan sentra 1.8l advance aut
# Processing model: nissan sentra 1.8l exclusive aut
# Processing model: nissan sentra 1.8l sense
# Processing model: nissan sentra 2.0l advance
# Processing model: nissan sentra 2.0l advance aut
# Processing model: nissan sentra 2.0l advance MT
# Processing model: nissan sentra 2.0l exclusive aut
# Processing model: nissan sentra 2.0l sense
# Processing model: nissan sentra 2.0l sense MT
# Processing model: nissan sentra advance CVT 2024.0
# Processing model: nissan sentra advance MT 2024.0
# Processing model: nissan sentra exclusive CVT 2024.0
# Processing model: nissan sentra sense MT 2024.0
# Processing model: nissan versa 1.6l advance
# Processing model: nissan versa 1.6l advance aut
# Processing model: nissan versa 1.6l advance MT
# Processing model: nissan versa 1.6l drive MT
# Processing model: nissan versa 1.6l exclusive aut
# Processing model: nissan versa 1.6l sense
# Processing model: nissan versa 1.6l sense aut
# Processing model: nissan versa 1.6l sense MT
# Processing model: nissan versa advance (radio touch) AT
# Processing model: nissan versa advance CVT 2024.0
# Processing model: nissan versa advance (radio touch) MT
# Processing model: nissan versa advance MT 2024.0
# Processing model: nissan versa exclusive CVT 2024.0
# Processing model: nissan versa sense AT
# Processing model: nissan versa sense CVT 2024.0
# Processing model: nissan versa sense MT
# Processing model: nissan versa v -drive MT
# Processing model: nissan versa v-drive MT
# Processing model: peugeot 301 1.6l active hdi 92hp
# Processing model: peugeot 301 1.6l active pack 92hp hdi
# Processing model: peugeot 301 1.6l allure hdi 92hp
# Processing model: peugeot 301 1.6l vti active 115hp
# Processing model: peugeot 301 1.6l vti active pack 115hp aut
# Processing model: peugeot 301 active hdi 92
# Processing model: peugeot 301 active pack hdi 92
# Processing model: peugeot 301 active pack vti 115
# Processing model: peugeot 301 active pack vti 115 EAT6
# Processing model: peugeot 301 allure hdi 92
# Processing model: renault symbol intens tech
# Processing model: renault symbol zen
# Processing model: suzuki dzire 1.2l gl
# Processing model: suzuki dzire 1.2l gl sport
# Processing model: suzuki dzire 1.2l gl sport aut
# Processing model: suzuki dzire 1.2l glx
# Processing model: suzuki dzire 1.2l glx aut
# Processing model: toyota camry hv
# Processing model: toyota corolla 1,6 xli MT
# Processing model: toyota corolla hev 1.8
# Processing model: toyota corolla 1.8l xei aut
# Processing model: toyota corolla 2.0 CVT
# Processing model: toyota corolla xei 2.0 CVT
# Processing model: toyota corolla seg hev 1.8 CVT
# Processing model: toyota corolla seg hev 1.8 2024.0
# Processing model: toyota corolla xei 2.0 6MT
# Processing model: toyota corolla xei 2.0 MT
# Processing model: toyota corolla xli 1.6 6MT
# Processing model: toyota prius
# Processing model: toyota yaris i 1.5 2024.0
# Processing model: toyota yaris 1.5l gli
# Processing model: toyota yaris 1.5l gli aut
# Processing model: toyota yaris 1.5l lei aut
# Processing model: toyota yaris 1.5l xli
# Processing model: toyota yaris sedan gli e CVT
# Processing model: toyota yaris sedan gli e MT
# Processing model: toyota yaris sedan lei h CVT
# Processing model: toyota yaris sedan lei MT
# Processing model: toyota yaris sedan xli c MT
# Processing model: volkswagen virtus 1.6l comfortline
# Processing model: volkswagen virtus 1.6l comfortline aut
# Processing model: volkswagen virtus 1.6l trendline
# Processing model: volkswagen voyage 1.6l comfortline
# Processing model: volkswagen voyage 1.6l highline
# Processing model: volkswagen voyage 1.6l trendline
# Processing model: baic bj40p diesel premium 4X4 2024.0
# Processing model: baic bj40p gasolina elite 4X2 2024.0
# Processing model: baic bj40p gasolina luxury 4X4 2024.0
# Processing model: baic x35 1.5t luxury CVT 2024.0
# Processing model: baic x35 1.5t comfort MT 2024.0
# Processing model: baic x35 1.5t elite MT 2024.0
# Processing model: baic x55 e6 1.5t comfort MT 2024.0
# Processing model: baic x55 e6 1.5t elite MT 2024.0
# Processing model: baic x55 plus comfort 2024.0
# Processing model: baic x55 plus elite 2024.0
# Processing model: baic x55 plus luxury 2024.0
# Processing model: byd song plus dm gl AT 2024.0
# Processing model: byd song plus dm gs AT 2024.0
# Processing model: byd yuan plus ev gl AT 2024.0
# Processing model: byd yuan plus ev gs AT 2024.0
# Processing model: changan cs15 1.5l comfort
# Processing model: changan cs15 1.5l comfort connect
# Processing model: changan cs15 1.5l comfort MT 2024.0
# Processing model: changan cs15 1.5l elite
# Processing model: changan cs15 1.5l elite AT 2024.0
# Processing model: changan cs15 1.5l elite aut
# Processing model: changan cs15 1.5l elite MT 2024.0
# Processing model: changan cs15 1.5l luxury
# Processing model: changan cs15 1.5l luxury MT 2024.0
# Processing model: changan cs35 1.4l plus elite AT 2024.0
# Processing model: changan cs35 1.4l plus lux AT 2024.0
# Processing model: changan cs35 1.6l plus comfort MT 2024.0
# Processing model: changan cs35 1.6l plus luxury MT 2024.0
# Processing model: changan cs35 plus 1.4l elite
# Processing model: changan cs35 plus 1.4l luxury
# Processing model: changan cs35 plus 1.6l comfort
# Processing model: changan cs35 plus 1.6l luxury
# Processing model: changan cs55 1.5l comfort
# Processing model: changan cs55 1.5l comfort MT 2024.0
# Processing model: changan cs55 1.5l elite aut
# Processing model: changan cs55 1.5l luxury
# Processing model: changan cs55 1.5l luxury AT 2024.0
# Processing model: changan cs55 1.5l luxury MT 2024.0
# Processing model: changan cs55 1.5l plus elite AT 2024.0
# Processing model: changan cs55 1.5l plus luxury AT 2024.0
# Processing model: changan cx70 1.5l elite plus turbo aut
# Processing model: changan cx70 1.5l elite turbo
# Processing model: changan cx70 1.5l elite turbo aut
# Processing model: changan cx70 1.6l comfort
# Processing model: changan cx70 1.6l luxury
# Processing model: changan cx70 1.6l luxury connect
# Processing model: chery k60 1.5l gl
# Processing model: chery k60 1.5l gls
# Processing model: chery tiggo 2 1.0l pro glx AT 2024.0
# Processing model: chery tiggo 2 1.0l pro glx MT 2024.0
# Processing model: chery tiggo 2 1.5l gl MT
# Processing model: chery tiggo 2 1.5l gls AT 2024.0
# Processing model: chery tiggo 2 1.5l gls MT
# Processing model: chery tiggo 2 1.5l glx MT
# Processing model: chery tiggo 2 1.5l l
# Processing model: chery tiggo 2 1.5l pro gls AT 2024.0
# Processing model: chery tiggo 2 1.5l pro gls MT 2024.0
# Processing model: chery tiggo 2 gl MT
# Processing model: chery tiggo 2 gls MT
# Processing model: chery tiggo 2 glx MT
# Processing model: chery tiggo 2 l MT
# Processing model: chery tiggo 3 1.5l gl MT
# Processing model: chery tiggo 3 1.5l gls
# Processing model: chery tiggo 3 1.5l gls MT
# Processing model: chery tiggo 3 1.5l pro gls AT 2024.0
# Processing model: chery tiggo 3 1.5l pro glx AT 2024.0
# Processing model: chery tiggo 3 1.5l pro glx MT 2024.0
# Processing model: chery tiggo 3 gls MT
# Processing model: chery tiggo 7 1.5l pro gls AT 2024.0
# Processing model: chery tiggo 7 1.5l pro glx AT 2024.0
# Processing model: chery tiggo 8 1.5l gls MT 2024.0
# Processing model: chery tiggo 8 1.5l glx AT 2024.0
# Processing model: chery tiggo 8 1.6l pro glx AT 2024.0
# Processing model: chery tiggo 8 1.6l pro max glx AT 2024.0
# Processing model: chery tiggo 8 2.0l pro max glx AWD AT 2024.0
# Processing model: chevrolet blazer 3.6l rs AWD
# Processing model: chevrolet blazer 3.6l rs AWD AT 2024.0
# Processing model: chevrolet blazer rs 3.6l l AWD AT
# Processing model: chevrolet bolt euv AT 2024.0
# Processing model: chevrolet captiva 1.5l lt
# Processing model: chevrolet captiva 1.5l lt aut
# Processing model: chevrolet captiva 1.5l ltz p AT 2024.0
# Processing model: chevrolet captiva 1.5l ltz p MT 2024.0
# Processing model: chevrolet captiva 1.5l premier
# Processing model: chevrolet captiva 1.5l premier aut
# Processing model: chevrolet captiva 1.5l premier p AT 2024.0
# Processing model: chevrolet captiva 1.5l premier p MT 2024.0
# Processing model: chevrolet captiva lt 1.5t 2WD MT
# Processing model: chevrolet captiva lt 1.5t l 2WD MT
# Processing model: chevrolet captiva lt 1.5t CVT
# Processing model: chevrolet captiva premier 1.5t 2WD MT
# Processing model: chevrolet captiva premier 1.5t l 2WD MT
# Processing model: chevrolet captiva premier 1.5t CVT
# Processing model: chevrolet groove 1.5l ltz r MT 2024.0
# Processing model: chevrolet groove 1.5l premier r MT 2024.0
# Processing model: chevrolet groove lt MT
# Processing model: chevrolet groove premier MT
# Processing model: chevrolet new suburban 5.3l 4X4
# Processing model: chevrolet new tahoe 5.3l 4X4
# Processing model: chevrolet new trailblazer premier 2.8d 4WD AT
# Processing model: chevrolet spin 1.8l activ 7p AT 2024.0
# Processing model: chevrolet spin 1.8l premier 7p MT 2024.0
# Processing model: chevrolet spin ii 1.8l activ AT
# Processing model: chevrolet spin ii 1.8l premier AT
# Processing model: chevrolet spin ii 1.8l premier MT
# Processing model: chevrolet suburban 5.3 4X4
# Processing model: chevrolet suburban 5.3l lt 4X4
# Processing model: chevrolet suburban z71 5.3l p 4WD AT 2024.0
# Processing model: chevrolet tahoe 5.3 4X4
# Processing model: chevrolet tahoe 5.3l lt 4X4
# Processing model: chevrolet tahoe 5.3l premier 4X4
# Processing model: chevrolet tahoe z71 5.3l p 4WD AT 2024.0
# Processing model: chevrolet tracker t premier 1.2 AT
# Processing model: chevrolet tracker 1.2l ls r MT 2024.0
# Processing model: chevrolet tracker 1.2l ltz p MT 2024.0
# Processing model: chevrolet tracker 1.2l ltz r AT 2024.0
# Processing model: chevrolet tracker 1.2l premier p3 AT 2024.0
# Processing model: chevrolet tracker 1.2l premier p4 AT 2024.0
# Processing model: chevrolet tracker 1.2l rs r AT 2024.0
# Processing model: chevrolet tracker 1.2t ls MT
# Processing model: chevrolet tracker 1.2t ltz AT
# Processing model: chevrolet tracker 1.2t ltz MT
# Processing model: chevrolet tracker premier 1.2t AT
# Processing model: chevrolet trailblazer 2.8l ltz aut 4X4
# Processing model: chevrolet trailblazer premier 2.8d l AWD AT
# Processing model: chevrolet traverse 3.6l lt
# Processing model: chevrolet traverse 3.6l lt 4X4
# Processing model: chevrolet traverse 3.6l lt AWD
# Processing model: chevrolet traverse 3.6l lt AWD AT 2024.0
# Processing model: chevrolet traverse 3.6l lt l AWD
# Processing model: chevrolet traverse 3.6l lt FWD
# Processing model: chevrolet traverse 3.6l lt l FWD
# Processing model: chevrolet traverse 3.6l premier 4X4
# Processing model: chevrolet traverse 3.6l premier AWD
# Processing model: chevrolet traverse 3.6l premier AWD AT 2024.0
# Processing model: chevrolet traverse 3.6l premier l AWD
# Processing model: chevrolet traverse 3.6l rs AWD AT 2024.0
# Processing model: citroen berlingo multispace m bluehdi 100 bvm 5 p 1.6
# Processing model: citroen berlingo multispace xl bluehdi 130 7 p 1.5 EAT8
# Processing model: citroen berlingo multispace xl bluehdi 100 bvm 7 p 1.6
# Processing model: citroen c3 aircross puretech 110 s&s feel 1.2 EAT6
# Processing model: citroen c3 aircross puretech 110 s&s live 1.2 EAT6
# Processing model: citroen c3 aircross puretech 110 s&s shine 1.2 EAT6
# Processing model: citroen c3 aircross bluehdi 100 s&s bvm6 feel 1.5
# Processing model: citroen c3 aircross bluehdi 100 s&s bvm6 live 1.5
# Processing model: citroen c3 aircross bluehdi 100 s&s bvm6 origins 1.5
# Processing model: citroen c3 aircross bluehdi 100 s&s bvm6 shine 1.5
# Processing model: citroen c5 aircross bluehdi 130 s&s aut feel 1.5
# Processing model: citroen c5 aircross bluehdi 130 s&s aut live 1.5
# Processing model: citroen c5 aircross 1.5l bluehdi 130 s&s feel AT 2024.0
# Processing model: citroen c5 aircross 1.5l bluehdi 130 s&s feel pack AT 2024.0
# Processing model: citroen c5 aircross 1.5l bluehdi 130 s&s shine AT 2024.0
# Processing model: citroen c5 aircross hybrid 225 shine AT 2024.0
# Processing model: citroen new c5 aircross bluehdi 130 s&s bvm6 live 1.5
# Processing model: citroen new c5 aircross bluehdi 130 s&s feel 1.5 EAT8
# Processing model: citroen new c5 aircross bluehdi 130 s&s live 1.5 EAT8
# Processing model: citroen new c5 aircross puretech 165 feel 1.6 EAT6
# Processing model: citroen new c5 aircross puretech 165 live 1.6 EAT6
# Processing model: citroen new c5 aircross bluehdi 180 s&s feel 2.0 EAT8
# Processing model: citroen new c5 aircross bluehdi 180 s&s shine 2.0 EAT8
# Processing model: citroen new c5 aircross bluehdi 180 s&s shine pack 2.0 EAT8
# Processing model: dfsk suv 500 comfort 1.5 2024.0
# Processing model: dfsk suv 500 luxury 1.5 2024.0
# Processing model: dfsk suv 500 luxury 1.5 CVT 2024.0
# Processing model: dfsk suv 560 comfort 1.8 2R 2024.0
# Processing model: dfsk suv 560 1.8l comfort 2024.0
# Processing model: dfsk suv 600 comfort 1.5t AT 2024.0
# Processing model: dfsk suv 600 comfort 1.5t MT 2024.0
# Processing model: dfsk suv 600 luxury 1.5t AT 2024.0
# Processing model: exeed lx 1.5t advanced AT 2024.0
# Processing model: exeed lx 1.5t unlimited AT 2024.0
# Processing model: exeed lx 1.5t unlimited AWD AT 2024.0
# Processing model: exeed txl 2.0t unlimited AT 2024.0
# Processing model: exeed txl 2.0t unlimited AWD AT 2024.0
# Processing model: fiat fastback audace 1.0l AT 2024.0
# Processing model: fiat fastback drive 1.0l AT 2024.0
# Processing model: fiat fastback impetus 1.0l AT 2024.0
# Processing model: fiat pulse drive 1.3l AT 2024.0
# Processing model: fiat pulse drive 1.3l MT 2024.0
# Processing model: fiat pulse impetus 1.0l AT 2024.0
# Processing model: fiat qubo dynamic 1,4
# Processing model: fiat qubo dynamic 1.4
# Processing model: ford ecosport 1.5l freestyle
# Processing model: ford ecosport 1.5l se
# Processing model: ford ecosport 1.5l se aut
# Processing model: ford ecosport 1.5l se titanium
# Processing model: ford ecosport 2.0l se titanium aut
# Processing model: ford ecosport 2.0l storm aut 4X4
# Processing model: ford ecosport freestyle 1.5l
# Processing model: ford ecosport freestyle 1.5l MT
# Processing model: ford ecosport se 1.5l AT
# Processing model: ford ecosport se 1.5l MT
# Processing model: ford ecosport storm 2.0 4X4 AT
# Processing model: ford ecosport titanium 1.5l MT
# Processing model: ford ecosport titanium 2.0l AT
# Processing model: ford edge 2.0l se
# Processing model: ford edge 2.0l sel
# Processing model: ford edge 2.0l sel 4X4
# Processing model: ford edge 2.7l st v6 4X4
# Processing model: ford edge se ecoboost 2.0l
# Processing model: ford edge sel ecoboost 2.0l
# Processing model: ford edge sel ecoboost 2.0l AWD
# Processing model: ford edge st ecoboost 2.7l
# Processing model: ford escape platinum 2.0l ecoboost AWD AT 2024.0
# Processing model: ford escape platinum 2.5l hev AWD AT 2024.0
# Processing model: ford escape st line 2.5l fhev AT 2024.0
# Processing model: ford expedition 3.5l limited
# Processing model: ford expedition 3.5l xlt 4X2
# Processing model: ford explorer 2.3l limited ecoboost 4X4
# Processing model: ford explorer xlt 4X4
# Processing model: ford territory titanium plus 1.5l 4X2
# Processing model: ford territory trend 1.5 4X2
# Processing model: ford territory trend 1.5l 4X2 AT 2024.0
# Processing model: gac emkoo 1.5t gdi ge AT 2024.0
# Processing model: gac emkoo 1.5t gdi gl AT 2024.0
# Processing model: gac emzoom 1.5t gb AT 2024.0
# Processing model: gac emzoom 1.5t gl AT 2024.0
# Processing model: gac emzoom 1.5t gl r-style AT 2024.0
# Processing model: gac gs3 power 1.5t gb AT 2024.0
# Processing model: gac gs3 power 1.5t gs AT 2024.0
# Processing model: gac gs3 power 1.5t gb MT 2024.0
# Processing model: gac gs3 power 1.5t gs MT 2024.0
# Processing model: gac gs4 power 1.5t gb AT 2024.0
# Processing model: gac gs4 power 1.5t ge AT 2024.0
# Processing model: gac gs4 power 1.5t gl AT 2024.0
# Processing model: gac gs4 power 1.5t gb MT 2024.0
# Processing model: gac gs8 2.0t gl 2WD AT 2024.0
# Processing model: gac gs8 2.0t gt 2WD AT 2024.0
# Processing model: gac gs8 2.0t gt 4WD AT 2024.0
# Processing model: gac gs8 2.0t gx 4WD AT 2024.0
# Processing model: haval h6 2.0l active
# Processing model: haval h6 2.0l deluxe
# Processing model: haval h6 2.0l deluxe AWD
# Processing model: haval h6 2.0l elite
# Processing model: haval h6 active 2WD AT 2024.0
# Processing model: haval h6 deluxe 2WD AT 2024.0
# Processing model: haval h6 deluxe AWD AT 2024.0
# Processing model: haval h6 elite 2WD AT 2024.0
# Processing model: haval h6 gt deluxe AWD AT 2024.0
# Processing model: haval h6 gt elite 2WD AT 2024.0
# Processing model: haval h6 hibrida deluxe 2WD AT 2024.0
# Processing model: haval h6 hidrida elite 2WD AT 2024.0
# Processing model: haval jolion 1.5l active
# Processing model: haval jolion 1.5l deluxe aut
# Processing model: haval jolion 1.5l elite
# Processing model: haval jolion 1.5l elite aut
# Processing model: haval jolion active MT 2024.0
# Processing model: haval jolion deluxe AT 2024.0
# Processing model: haval jolion elite AT 2024.0
# Processing model: haval jolion elite MT 2024.0
# Processing model: haval jolion hibrido deluxe 2WD AT 2024.0
# Processing model: haval jolion hibrido elite 2WD AT 2024.0
# Processing model: honda new cr-v ex 2.4 4X2 CVT
# Processing model: honda new cr-v exl-t turbo 1.5 4X2 CVT
# Processing model: honda new cr-v touring turbo 1.5 4X4 CVT
# Processing model: honda new hr-v ex 1.8 CVT
# Processing model: honda new hr-v exl 1.8 4X2 CVT
# Processing model: honda new hr-v exl 1.8 4X4 CVT
# Processing model: honda new hr-v lx 1.8 CVT
# Processing model: honda new pilot elite 3.5 4X4 AT
# Processing model: honda new pilot ex 3.5 4X2 AT
# Processing model: honda new pilot touring 3.5 4X4 AT
# Processing model: honda wr-v ex 1.5 CVT
# Processing model: honda wr-v ex 1.5 MT
# Processing model: honda wr-v exl 1.5 CVT
# Processing model: honda wr-v lx 1.5 CVT
# Processing model: honda wr-v lx smart 1.5 CVT
# Processing model: honda wr-v lx 1.5 MT
# Processing model: honda wr-v lx smart 1.5 MT
# Processing model: hyundai creta grand su2i value 2.0 AT 2024.0
# Processing model: hyundai creta grand su2i plus 2.0 MT 2024.0
# Processing model: hyundai creta su2id design 1.5 CVT 2024.0
# Processing model: hyundai creta su2id plus 1.5 CVT 2024.0
# Processing model: hyundai creta su2id premium 1.5 CVT 2024.0
# Processing model: hyundai creta su2id go 1.5 MT 2024.0
# Processing model: hyundai creta su2id design 1.5 MT 2024.0
# Processing model: hyundai creta su2id plus 1.5 MT 2024.0
# Processing model: hyundai ioniq 5 ne ev limited AWD AT 2024.0
# Processing model: hyundai ioniq 5 ne ev limited AT 2024.0
# Processing model: hyundai ioniq 5 ne ev premium AT 2024.0
# Processing model: hyundai kona os ev premium AT 2024.0
# Processing model: hyundai palisade lx2 premium fl 3.5 AWD AT 2024.0
# Processing model: hyundai santa fe mx5 gdi design 2.5 AT 2024.0
# Processing model: hyundai santa fe mx5 gdi plus 2.5 AT 2024.0
# Processing model: hyundai santa fe mx5 2.5t gdi calligraphy AT 2024.0
# Processing model: hyundai santa fe mx5 2.5t gdi limited AT 2024.0
# Processing model: hyundai santa fe tm value fl 2.5 AT 2024.0
# Processing model: hyundai tucson nx4 limited 1.6 4WD AT 2024.0
# Processing model: hyundai tucson nx4 plus 1.6 AT 2024.0
# Processing model: hyundai tucson nx4 hev limited 1.6 AT 2024.0
# Processing model: hyundai tucson nx4 hev value 1.6 AT 2024.0
# Processing model: hyundai tucson nx4 plus 2.0 4WD AT 2024.0
# Processing model: hyundai tucson nx4 plus 2.0 AT 2024.0
# Processing model: hyundai tucson nx4 value 2.0 AT 2024.0
# Processing model: hyundai tucson nx4 plus 2.0 MT 2024.0
# Processing model: hyundai venue qx value 1.6 AT 2024.0
# Processing model: hyundai venue qx plus 1.6 MT 2024.0
# Processing model: hyundai venue qx value 1.6 MT 2024.0
# Processing model: jac js2 1.5l comfort
# Processing model: jac js2 1.5l comfort aut
# Processing model: jac js2 1.5l comfort bicolor
# Processing model: jac js2 1.5l comfort smart
# Processing model: jac js2 1.5l luxury
# Processing model: jac js2 1.5l luxury aut
# Processing model: jac js2 1.5l luxury bicolor
# Processing model: jac js2 comfort MT 2024.0
# Processing model: jac js2 luxury AT 2024.0
# Processing model: jac js2 luxury MT 2024.0
# Processing model: jac js3 1.6l advance
# Processing model: jac js3 1.6l advance aut
# Processing model: jac js3 1.6l comfort
# Processing model: jac js3 1.6l luxury
# Processing model: jac js3 1.6l luxury aut
# Processing model: jac js3 se luxury 1.6 MT 2024.0
# Processing model: jac js3 xe advance 1.6 AT 2024.0
# Processing model: jac js3 xe advance 1.6 MT 2024.0
# Processing model: jac js3 xe luxury 1.6 AT 2024.0
# Processing model: jac js4 1.5l advance aut
# Processing model: jac js4 1.5l advance bicolor aut
# Processing model: jac js4 1.5l luxury
# Processing model: jac js4 1.5l luxury aut
# Processing model: jac js4 1.5l luxury bicolor
# Processing model: jac js4 1.5l luxury bicolor aut
# Processing model: jac js4 1.6l comfort
# Processing model: jac js4 1.6l comfort bicolor
# Processing model: jac js4 advance 1.5t AT 2024.0
# Processing model: jac js4 advance bicolor 1.5t AT 2024.0
# Processing model: jac js4 comfort 1.6 MT 2024.0
# Processing model: jac js4 comfort bicolor 1.6 MT 2024.0
# Processing model: jac js4 luxury 1.5t AT 2024.0
# Processing model: jac js4 luxury 1.5t MT 2024.0
# Processing model: jac js4 luxury bicolor 1.5t AT 2024.0
# Processing model: jac js4 luxury bicolor 1.5t MT 2024.0
# Processing model: jac js6 advance AT 2024.0
# Processing model: jac js6 comfort AT 2024.0
# Processing model: jac js6 luxury AT 2024.0
# Processing model: jac js8 advance xe AT 2024.0
# Processing model: jac js8 comfort ce MT 2024.0
# Processing model: jac js8 luxury se AT 2024.0
# Processing model: jac js8 luxury se MT 2024.0
# Processing model: jac s3 1.6l advance
# Processing model: jac s3 1.6l comfort
# Processing model: jac s3 1.6l comfort smart
# Processing model: jac s3 1.6l comfort smart aut
# Processing model: jac s3 1.6l luxury
# Processing model: jeep all new compass sport 4X2
# Processing model: jeep all new compass sport 4X2 AT
# Processing model: jeep commander limited 1.3 4X2 AT 2024.0
# Processing model: jeep commander limited 2.0 4X4 AT 2024.0
# Processing model: jeep commander limited g 2.0 4X4 AT 2024.0
# Processing model: jeep commander overland 1.3 4X2 AT 2024.0
# Processing model: jeep commander overland g 2.0 4X4 AT 2024.0
# Processing model: jeep compass 2.4l sport
# Processing model: jeep compass 2.4l sport aut
# Processing model: jeep compass 2.4l sport lx
# Processing model: jeep compass limited 4X2 AT 2024.0
# Processing model: jeep compass longitude 4X2 AT 2024.0
# Processing model: jeep compass sport 4X2 AT 2024.0
# Processing model: jeep gran cherokee laredo 3.6l v6 4X4
# Processing model: jeep gran cherokee limited 3.6l 4X4
# Processing model: jeep gran cherokee srt8 6.4l
# Processing model: jeep grand cherokee 3.0l limited td aut 4X4
# Processing model: jeep grand cherokee 3.6l laredo aut 4X2
# Processing model: jeep grand cherokee 3.6l laredo aut 4X4
# Processing model: jeep grand cherokee 3.6l limited lx aut 4X4
# Processing model: jeep grand cherokee 3.6l limited x aut 4X4
# Processing model: jeep grand cherokee 6.4l srt8 aut 4X4
# Processing model: jeep grand cherokee l summit 3.6l 3row AT 2024.0
# Processing model: jeep grand cherokee laredo 3.6l 4X2
# Processing model: jeep grand cherokee limited 3,0l td 4X4
# ...
# Processing model: fiat ducato minibus 16 + 1 l3h2 doble aa class a
# Processing model: fiat ducato minibus 16 + 1 l3h2 ejecutivo doble aa
# Processing model: fiat ducato minibus 16+1 ejecutivo l3 h2 doble aa
# Processing model: fiat ducato minibus 16+1 l3 h2 aa
# Processing model: fiat ducato minibus 16+1 l3 h2 doble aa
# Processing model: ford transit 2.2l minibus 17+1 pas
# Processing model: hyundai solati h350 pasajeros
# Processing model: hyundai solati h350 pasajeros / rampa hidraulica
# Processing model: hyundai solati h350 pasajeros escolar
# Processing model: hyundai solati h350 pasajeros escolar / rampa hidraulica
# Processing model: hyundai solati pasajeros
# Processing model: hyundai staria mb cedi 11p 2.2 2024.0
# Processing model: hyundai staria mb crdi 9p luxury 2.2 4WD 2024.0
# Processing model: hyundai staria mb crdi 9p 2.2 2024.0
# Processing model: hyundai staria us4 mb crdi 9p 2.2 AT
# Processing model: jac refine 1.9l executive 10pas
# Processing model: jac refine 1.9l executive 8pas
# Processing model: jac sunray 1.9l green jet 11+1 pas
# Processing model: jac sunray 13+1 MT 2024.0
# Processing model: jac sunray 14+1 MT 2024.0
# Processing model: jac sunray 16+1 MT 2024.0
# Processing model: jac sunray 17+1 MT 2024.0
# Processing model: jac sunray 2.0l green jet 21+1 pas escolar
# Processing model: jac sunray 2.7l green jet 13+1 pas
# Processing model: jac sunray 2.7l green jet 14+1 pas
# Processing model: jac sunray 2.7l green jet 16+1 pas
# Processing model: jac sunray 2.7l green jet 17+1 pas
# Processing model: jac sunray 2.7l green jet 27+1 pas escolar
# Processing model: maxus ev80 minibus 15+1
# Processing model: maxus g10 6+1
# Processing model: maxus g10 6+1 ejecutiva
# Processing model: maxus g10 9+1
# Processing model: maxus g10 escolar 18+1
# Processing model: maxus g10 minibus 6+1
# Processing model: maxus g10 minibus 6+1 e6 2024.0
# Processing model: maxus g10 minibus 9+1
# Processing model: maxus g10 minibus 9+1 e6 2024.0
# Processing model: maxus g10 van escolar e5
# Processing model: maxus g90 minibus elite 6+1 2024.0
# Processing model: maxus g90 minibus luxury 6+1 2024.0
# Processing model: maxus mifa 9 90 kwh luxury 2024.0
# Processing model: maxus new v80 fl minibus 12+1 e5
# Processing model: maxus new v80 fl minibus 12+1 e5 dlx
# Processing model: maxus new v80 fl minibus 15+1 e5 dlx
# Processing model: maxus new v80 fl van escolar e5
# Processing model: maxus v80 12+1
# Processing model: maxus v80 15+1
# Processing model: maxus v90 escolar
# Processing model: maxus v90 minibus 15+1 a3
# Processing model: maxus v90 minibus 15+1 a4 AT
# Processing model: maxus v90 minibus 15+1 dr AT
# Processing model: maxus v90 minibus 16+1 a4 dr
# Processing model: maxus v90 minibus techo alto 15+1 a4
# Processing model: maxus v90 minibus techo medio 15+1 a3
# Processing model: nissan nv350 2.5l
# Processing model: nissan nv350 2.5l bus wide s long 15 pas
# Processing model: nissan nv350 2.5l escolar 24pas
# Processing model: nissan nv350 2.5l pasajeros 15
# Processing model: nissan nv350 2.5l turismo confort
# Processing model: nissan nv350 2.5l wide s-long cargo
# Processing model: nissan nv350 2.5l wide s-long MT
# Processing model: nissan nv350 2.5l wide s-long school bus MT
# Processing model: nissan nv350 wide s-long bus 2.5d MT
# Processing model: nissan nv350 wide s-long bus 2.5d (school bus) MT
# Processing model: nissan nv350 wide s-long bus 2.5l MT
# Processing model: nissan nv350 wide s-long bus 2.5l (school bus) MT
# Processing model: peugeot boxer escolar l2h2 25p bluehdi 160
# Processing model: peugeot traveller active l3 8p bluehdi 150 mt6 2.0
# Processing model: peugeot traveller active l3 8p bluehdi 180 2.0 EAT8
# Processing model: peugeot traveller business l3 8p bluehdi 180 EAT8 2024.0
# Processing model: peugeot traveller business l3 9p bluehdi 145 2024.0
# Processing model: peugeot traveller business l3 9p bluehdi 150
# Processing model: toyota hiace pasajeros 2.8l l1h1 11pas
# Processing model: toyota hiace pasajeros 2.8l l2h2 9pas
# Processing model: toyota hiace turismo l1h1 gl
# Processing model: toyota hiace turismo l1h1 MT 2024.0
# Processing model: toyota hiace turismo l2h2 gl
# Processing model: toyota turismo l1h1 gl
# Processing model: toyota turismo l2h2 gl
# Processing model: changan m 201 cargo 2024.0
# Processing model: changan m 201 cargo ac 2024.0
# Processing model: changan m201 1.2l furgon
# Processing model: changan m201 1.2l furgon ac
# Processing model: changan md201 1.2l cargo box
# Processing model: changan md201 1.2l cargo box ac
# Processing model: chevrolet n 400 max l ac p 1.5 MT 2024.0
# Processing model: chevrolet n 400 max l p 1.5 MT 2024.0
# Processing model: chevrolet n400 max 1.5l
# Processing model: chevrolet n400 max 1.5l ac
# Processing model: chevrolet n400 max ii 1.5l MT
# Processing model: chevrolet n400 max ii 1.5l ac MT
# Processing model: chevrolet n400 max ll l 1.5 MT
# Processing model: chevrolet n400 max ll l ac 1.5 MT
# Processing model: citroen berlingo cargo hdi 92 bvm5 m 1.6 2024.0
# Processing model: citroen berlingo cargo hdi 92 bvm5 xl 1.6 2024.0
# Processing model: citroen jumper cargo l2h2 bluehdi 165 s&s bvm6 2024.0
# Processing model: citroen jumper cargo l3h2 bluehdi 165 s&s bvm6 2024.0
# Processing model: citroen jumper cargo l4h2 bluehdi 165 s&s bvm6 2024.0
# Processing model: citroen jumper l1h1 bluehdi 163 s&s bvm6
# Processing model: citroen jumper l2h2 bluehdi 163 s&s bvm6
# Processing model: citroen jumper l2h2 bluehdi 163 s&s bvm6 escolar
# Processing model: citroen jumper l3 chasis cabina bluehdi 163 s&s bvm6
# Processing model: citroen jumper l3h2 bluehdi 163 s&s bvm6
# Processing model: citroen jumper l4h2 bluehdi 163 s&s bvm6
# Processing model: citroen jumpy cargo bluehdi 150 s&s bvm6 xl 2024.0
# Processing model: citroen new berlingo m hdi 92 bvm 1.6
# Processing model: citroen new berlingo xl hdi 92 bvm 1.6
# Processing model: citroen new jumpy comfort xl hdi 150 bvm6
# Processing model: citroen new jumpy comfort xl hdi 150 bvm6 escolar
# Processing model: farizon v6e AT 2024.0
# Skipping farizon v6e AT 2024.0 due to invalid Version URL
# Processing model: fiat ducato 2.3l maxi cargo l1h1
# Processing model: fiat ducato 2.3l maxi cargo l1h1 aa 8mt3
# Processing model: fiat ducato 2.3l maxi cargo l2h2
# Processing model: fiat ducato 2.3l maxi cargo l2h2 aa mt3 11.5
# Processing model: fiat ducato 2.3l maxi cargo l3h2
# Processing model: fiat ducato 2.3l maxi cargo l3h2 aa 13 mt3
# Processing model: fiat ducato 2.3l maxi cargo l3h2 aa 17 mt3
# Processing model: fiat ducato 2.3l maxi cargo l3h2 ac
# Processing model: fiat ducato maxi cargo l1 h1
# Processing model: fiat ducato maxi cargo l1 h1 aa(8mt3)
# Processing model: fiat ducato maxi cargo l1 h1 MT 2024.0
# Processing model: fiat ducato maxi cargo l2 h2
# Processing model: fiat ducato maxi cargo l2 h2 aa (11,5mt3)
# Processing model: fiat ducato maxi cargo l3 h2
# Processing model: fiat ducato maxi cargo l3 h2 aa (13mt3)
# Processing model: fiat ducato maxi cargo l4 h3
# Processing model: fiat ducato maxi cargo l4 h3 aa (17mt3)
# Processing model: ford transit 2.2l tdci techo alto
# Processing model: ford transit furgon largo-techo alto
# Processing model: hyundai h-350 furgon solati cargo van
# Processing model: hyundai h-350 furgon solati cargo van / carga refrigerada
# Processing model: hyundai h-350 furgon solati cargo van / carga refrigerada /plataforma
# Processing model: jac refine 1.9l furgon
# Processing model: jac sunray cargo
# Processing model: kyc v3 cargo van MT 2024.0
# Processing model: kyc v5 cargo van MT 2024.0
# Processing model: maxus deliver 9 cargo l2h2 2024.0
# Processing model: maxus edeliver 9 l2h2 2024.0
# Processing model: maxus edeliver 9 l3h2 2024.0
# Processing model: maxus ev30 cargo van
# Processing model: maxus ev80 cargo van
# Processing model: maxus g-10 1.9l cargo
# Processing model: maxus g10 cargo
# Processing model: maxus new v80 fl cargo van 11,5 m3 e5
# Processing model: maxus v90 12m3 l3h3
# Processing model: maxus v90 13m3 l3h3
# Processing model: nissan nv350 2.5l cargo wide s-long
# Processing model: nissan nv350 wide s-long cargo 2.5d MT
# Processing model: nissan nv350 wide s-long cargo 2.5l MT
# Processing model: opel combo td 1.5 MT 2024.0
# Processing model: opel combo 1.6l hdi l1
# Processing model: opel movano cargo van l2h2 MT 2024.0
# Processing model: opel vivaro td 2.0
# Processing model: opel vivaro td 2.0 MT 2024.0
# Processing model: peugeot boxer 2.0l furgon l2h2
# Processing model: peugeot boxer 2.0l furgon l3h2
# Processing model: peugeot boxer 2.0l furgon l4h2
# Processing model: peugeot boxer furgon d/c l4h2 bluehdi 165 2024.0
# Processing model: peugeot boxer furgon l2h2 bluehdi 160
# Processing model: peugeot boxer furgon l2h2 bluehdi 165 MT 2024.0
# Processing model: peugeot boxer furgon l3h2 bluehdi 160
# Processing model: peugeot boxer furgon l3h2 bluehdi 165 MT 2024.0
# Processing model: peugeot boxer furgon l4h2 bluehdi 160
# Processing model: peugeot boxer furgon l4h2 bluehdi 165 MT 2024.0
# Processing model: peugeot expert l3 bluehdi 145 MT 2024.0
# Processing model: peugeot expert l3 hdi 150
# Processing model: peugeot partner 1.6l l1
# Processing model: peugeot partner 1.6l l2
# Processing model: peugeot partner l1 bluehdi 100 MT 2024.0
# Processing model: peugeot partner l1 ev AT 2024.0
# Processing model: peugeot partner l1 hdi 90
# Processing model: peugeot partner l2 bluehdi 100 MT 2024.0
# Processing model: peugeot partner l2 hdi 90
# Processing model: peugeot traveller active l3 8p bluehdi 180 AT 2024.0
# Processing model: peugeot traveller business l3 9p bluehdi 145 MT 2024.0
# Processing model: ram ram v700 city multijet 16v euro v 1.3
# Processing model: ram ram v700 city evo 8v euro vi 1.4
# Processing model: ram ram v700 city diesel
# Processing model: ram ram v700 city gasolina
# Processing model: ram ram van 700 rapid 1,4l st (3,1mts3)
# Processing model: ram ram van 700 rapid 1,4l st aa (3,1mts3)
# Processing model: ram v 700 city 1.3l 2024.0
# Processing model: ram v1000 100o cargo xl 1.6l 5mt3
# Processing model: ram v1000 cargo corto 1.3l mt3 3.4
# Processing model: ram v1000 cargo largo 1.3l mt3 3.8
# Processing model: ram v1000 corto
# Processing model: ram v1000 corto 1.3l 2024.0
# Processing model: ram v1000 largo
# Processing model: ram v1000 xl
# Processing model: ram v700 city 1.4l
# Processing model: ram v700 city diesel
# Processing model: ram v700 rapid 1.4l 2024.0
# Processing model: ram v700 rapid 1.4l st
# Processing model: ram v700 rapid 1.4l st aa
# Processing model: ram van cargo corto 1000.0
# Processing model: ram van cargo corto 1,3l (3,4mts3) 1000.0
# Processing model: ram van cargo l 1000.0
# Processing model: ram van cargo large 1,3l (3,8mts3) 1000.0
# Processing model: ram van cargo xl 1000.0
# Processing model: ram van cargo xl 1,6l (5mts3) 1000.0
# Processing model: ram van 700 rapid 1,4l st
# Processing model: renault dokker 1.5l furgon ac
# Processing model: renault kangoo z.e l1
# Processing model: renault kangoo z.e l2
# Processing model: toyota hiace cargo l1h1 2024.0
# Processing model: toyota hiace furgon 2.8l l1h1
# Processing model: toyota hiace furgon 2.8l l1h1b
# Processing model: toyota hiace furgon 2.8l l2h2b
# Processing model: chery iq 1.0l gls
# Processing model: chevrolet spark gt ii activ 1.2 MT
# Processing model: chevrolet spark gt ii lt ac 1.2 MT
# Processing model: chevrolet spark gt ii lt ac full 1.2 MT
# Processing model: chevrolet spin activ 1.8l aut
# Processing model: citroen c3 1.2l puretech 110 feel aut
# Processing model: citroen c3 1.2l puretech 82 feel
# Processing model: citroen c3 1.2l puretech 82 live
# Processing model: citroen c3 1.5l bluehdi 100 s&s feel
# Processing model: citroen c3 1.5l bluehdi 100 s&s live
# Processing model: citroen c3 1.5l bluehdi 100 s&s shine
# Processing model: fiat 500 1.2l pop
# Processing model: fiat 500 1.2l pop aut
# Processing model: fiat 500 1.2l pop MT
# Processing model: fiat 500 1.4l lounge
# Processing model: fiat 500 1.4l lounge aut
# Processing model: fiat 500 lounge 1.4 AT
# Processing model: fiat 500 lounge 1.4 MT
# Processing model: fiat 500 pop 1.2 AT
# Processing model: fiat 500 pop 1.2 MT
# Processing model: fiat 500 sport 1.4
# Processing model: fiat 500 sport 1.4 AT
# Processing model: fiat 500c l pop 1.2 AT
# Processing model: fiat 500c l pop 1.2 MT
# Processing model: fiat 500c l pop 1.4 AT
# Processing model: fiat 500c l pop 1.4 MT
# Processing model: fiat argo 1.3l drive elx
# Processing model: fiat argo 1.3l drive gse
# Processing model: fiat argo drive 1,3 gse
# Processing model: fiat argo drive elx 1,3 gse
# Processing model: fiat argo trekking 1.3l trekking
# Processing model: fiat mobi 1.0l way cross plus
# Processing model: fiat qubo dynamic
# Processing model: honda civic si t 1.5 MT
# Processing model: honda civic si t sensing (new) 1.5 MT
# Processing model: mazda 3 sport 2.0l s
# Processing model: mazda 3 sport 2.0l v
# Processing model: mazda 3 sport 2.0l v aut
# Processing model: mazda 3 sport 2.5l gtx
# Processing model: mazda 3 sport 2.5l gtx aut
# Processing model: mitsubishi mirage 1.2l gl
# Processing model: mitsubishi mirage 1.2l gls
# Processing model: mitsubishi mirage 1.2l glx
# Processing model: mitsubishi mirage gl
# Processing model: mitsubishi mirage gl MT
# Processing model: mitsubishi mirage gls
# Processing model: mitsubishi mirage gls MT
# Processing model: mitsubishi mirage glx
# Processing model: mitsubishi mirage glx MT
# Processing model: opel corsa 1.2l edition
# Processing model: opel corsa 1.2t edition
# Processing model: opel corsa 1.2t edition aut
# Processing model: opel corsa edition 1.2t at8
# Processing model: opel corsa edition 1.2t mt6
# Processing model: opel corsa edition 1.5td mt6
# Processing model: opel corsa gs line 1.2t at8
# Processing model: peugeot 308 1.2l active puretech 130 hp
# Processing model: peugeot 308 1.6l allure thp 165 EAT6
# Processing model: peugeot 308 allure thp 165 EAT6
# Processing model: renault kwid 1.0l intens
# Processing model: renault kwid 1.0l life
# Processing model: renault kwid 1.0l outsider
# Processing model: suzuki alto 800 0.8l gl
# Processing model: suzuki alto 800 0.8l glx
# Processing model: suzuki alto 800 0.8l glx ac
# Processing model: suzuki baleno 1.4l gl
# Processing model: suzuki baleno 1.4l gls
# Processing model: suzuki baleno 1.4l gls aut
# Processing model: suzuki baleno 1.4l glx
# Processing model: suzuki baleno 1.4l glx aut
# Processing model: suzuki s-presso 1.0l glx ac
# Processing model: suzuki s-presso 1.0l glx adventure
# Processing model: suzuki swift 1.0l boosterjet glx
# Processing model: suzuki swift sport 1.4l
# Processing model: suzuki swift sport 1.4l aut
# Processing model: toyota aygo 5 puertas x-r5
# Processing model: toyota aygo x-cite
# Processing model: toyota aygo x-g3
# Processing model: toyota aygo x-g5
# Processing model: toyota aygo x-r3
# Processing model: toyota corolla sport 1.2l se
# Processing model: toyota corolla sport 1.2l se aut
# Processing model: toyota corolla sport s hv 1.8 CVT
# Processing model: toyota corolla sport se turbo 1.2 CVT
# Processing model: toyota corolla sport se turbo 1.2 MT
# Processing model: toyota corolla sport se hv 1.8 CVT
# Processing model: toyota corolla sport turbo 1.2l se CVT
# Processing model: toyota prius c
# Processing model: toyota prius hibrido
# Processing model: toyota yaris sport 1.5l gle AT
# Processing model: toyota yaris sport 1.5l gle MT
# Processing model: toyota yaris sport 1.5l gli
# Processing model: toyota yaris sport 1.5l gli aut
# Processing model: toyota yaris sport 1.5l sport
# Processing model: toyota yaris sport 1.5l sport aut
# Processing model: toyota yaris sport 1.5l sport MT
# Processing model: toyota yaris sport gle AT
# Processing model: toyota yaris sport gle MT
# Processing model: toyota yaris sport sport AT
# Processing model: toyota yaris sport sport MT
# Processing model: volkswagen gol 1.6l comfortline
# Processing model: volkswagen gol 1.6l highline
# Processing model: volkswagen gol 1.6l highline aut
# Processing model: volkswagen gol 1.6l trendline
# Processing model: volkswagen polo 1.6l msi comfortline
# Processing model: volkswagen polo 1.6l msi comfortline aut
# Processing model: volkswagen polo 1.6l msi highline
# Processing model: volkswagen polo 1.6l msi highline aut
# Processing model: volkswagen polo 1.6l msi trendline
# Data scraping completed. Results saved to 'scraped_data.csv'.
