# %%
# Install required libraries
# !pip3 install requests
# !pip3 install beautifulsoup4
# !pip3 install pandas
# !pip3 install fuzzywuzzy
# !pip3 install python-Levenshtein

# Import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from urllib.parse import quote
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from difflib import get_close_matches
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /Users/pablosanfrancisco/Library/Python/3.9/lib/python/site-packages (2.32.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pablosanfrancisco/Library/Python/3.9/lib/python/site-packages (from requests) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pablosanfrancisco/Library/Python/3.9/lib/python/site-packages (from requests) (2024.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pablosanfrancisco/Library/Python/3.9/lib/python/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pablosanfrancisco/Library/Python/3.9/lib/python/site-packages (from requests) (3.7)
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: beautifulsoup4 in /Users/pablosanfrancisco/Library/Python/3.9/lib/python/site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/pablosanfrancisco/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4) (2.5)
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/pablosanfrancisco/Library/Python/3.9/lib/python/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /Users/pablosanfrancisco/Library/Python/3.9/lib/python/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/pablosanfrancisco/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/pablosanfrancisco/Library/Python/3.9/lib/python/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/pablosanfrancisco/Library/Python/3.9/lib/python/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: fuzzywuzzy in /Users/pablosanfrancisco/Library/Python/3.9/lib/python/site-packages (0.18.0)
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-Levenshtein in /Users/pablosanfrancisco/Library/Python/3.9/lib/python/site-packages (0.26.0)
# Requirement already satisfied: Levenshtein==0.26.0 in /Users/pablosanfrancisco/Library/Python/3.9/lib/python/site-packages (from python-Levenshtein) (0.26.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /Users/pablosanfrancisco/Library/Python/3.9/lib/python/site-packages (from Levenshtein==0.26.0->python-Levenshtein) (3.10.1)
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('parsed_output.csv')
# Display the first few rows of the DataFrame
df.head()
# Out:
#      MARCA TIPO PRODUCTO          Model Name Engine Drive Transmission  Year
# 0  CHANGAN     CAMIONETA      HUNTER COMFORT   2.0T   4X2           MT  2024
# 1  CHANGAN     CAMIONETA      HUNTER COMFORT   2.0T   4X4           MT  2024
# 2  CHANGAN     CAMIONETA  HUNTER ELITE SPORT   2.0T   4X4           MT  2024
# 3  CHANGAN     CAMIONETA       HUNTER LUXURY   2.0T   4X2           MT  2024
# 4  CHANGAN     CAMIONETA       MD 301 AC ESP    NaN   NaN           MT  2024

# %%
import re
import time
import requests

# Define a helper function to handle retries
def make_request_with_retry(url, retries=10, delay=2):
    for attempt in range(retries):
        try:
            response = requests.get(url)
            response.raise_for_status()
            return response
        except requests.exceptions.HTTPError as err:
            if response.status_code == 500:
                if attempt < retries - 1:
                    print(f"Server error (500) encountered at {url}. Waiting {delay} second(s) before retrying...")
                    time.sleep(delay)
                    continue
                else:
                    print(f"Failed to access {url} after {retries} attempts: {err}")
                    return None
            else:
                print(f"Failed to access {url}: {err}")
                return None
        except Exception as e:
            print(f"An error occurred while accessing {url}: {e}")
            return None

def normalize_string(s):
    s = s.lower()
    s = re.sub(r'[^\w\s]', '', s)
    s = re.sub(r'\s+', ' ', s)
    return s.strip()

def find_base_model_and_version(model_name):
    descriptors = ['advance', '3', 'row', 'e-power', 'exclusive', 'sense', 'le', 'xle', 'limited',
                   'luxury', 'pro', 'elite', 'glx', 'at', 'mt', '4x2', '4x4', 'awd', '2wd', 'dct',
                   'cvt', 'td', 'tdi', 'tdci', 's', 'se', 'lt', 'ltz', 'ls', 'premium', 'plus',
                   'xt', 'xtronic', 'sunroof', 'diesel', 'gasolina', 'elegance', 'hibrido', 'hev',
                   'hybrid', 'comfort', 'deluxe', 'gt', 'sport', 'xl', 'xlt', 'xse', 'p4x']
    words = normalize_string(model_name).split()
    base_model_words = [word for word in words if word not in descriptors]
    base_model_name = ' '.join(base_model_words)
    version_words = [word for word in words if word in descriptors]
    version_name = ' '.join(version_words)
    return base_model_name.strip(), version_name.strip()

def get_best_match(query, choices, cutoff=0.6):
    matches = get_close_matches(query, choices, n=1, cutoff=cutoff)
    if matches:
        return matches[0]
    else:
        # Attempt substring matching
        for choice in choices:
            if query in choice or choice in query:
                return choice
    return None

# %% [markdown]
# #### Guardamos el nombre de las marcas

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('parsed_output.csv')

# Extract the unique 'MARCA's
unique_marcas = df['MARCA'].drop_duplicates()

# Create a new DataFrame with the unique 'MARCA's
unique_marcas_df = pd.DataFrame(unique_marcas, columns=['MARCA'])

# Save the unique 'MARCA's to a new CSV file
unique_marcas_df.to_csv('unique_marcas.csv', index=False)

# %%
# Leer el archivo unique_marcas.csv
marcas_df = pd.read_csv('unique_marcas.csv')

# Lista para almacenar los datos
models_data = []

# Iterar sobre cada marca
for index, row in marcas_df.iterrows():
    manufacturer = str(row['MARCA']).lower()
    print(f"Procesando marca: {manufacturer}")
    
    # Construir la URL
    base_url = 'https://www.autocosmos.cl/catalogo/vigente/'
    manufacturer_normalized = normalize_string(manufacturer).replace(' ', '-')
    manufacturer_url = base_url + manufacturer_normalized
    
    # Realizar la solicitud HTTP con reintentos
    response = make_request_with_retry(manufacturer_url)
    if response is None:
        continue  # Saltar a la siguiente iteración si la solicitud falló
    
    # Analizar la página de la marca
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Encontrar la sección de modelos
    models_section = soup.find('section', class_='section m-brand')
    if models_section:
        model_links = models_section.find_all('a', href=True)
    else:
        print(f"No se encontraron modelos para {manufacturer}")
        continue
    
    # Extraer nombres de modelos y URLs
    for link in model_links:
        model_name = link.get('title', '').strip()
        model_href = link['href']
        # Construir la URL completa del modelo
        full_model_url = 'https://www.autocosmos.cl' + model_href
        
        # Almacenar los datos
        models_data.append({
            'MARCA': manufacturer.title(),
            'Model Name': model_name,
            'Model URL': full_model_url
        })

# Convertir la lista a un DataFrame
models_df = pd.DataFrame(models_data)

# Guardar en un archivo CSV
models_df.to_csv('models_by_marcas.csv', index=False)

# Mostrar una muestra de los datos
print(models_df.head())
# Out:
# Procesando marca: changan
# Procesando marca: chevrolet
# Server error (500) encountered at https://www.autocosmos.cl/catalogo/vigente/chevrolet. Waiting 2 second(s) before retrying...
# Procesando marca: dfsk
# Procesando marca: dongfeng
# Procesando marca: ford
# Procesando marca: foton
# Procesando marca: great wall
# Server error (500) encountered at https://www.autocosmos.cl/catalogo/vigente/great-wall. Waiting 2 second(s) before retrying...
# Procesando marca: jac
# Procesando marca: jmc
# Procesando marca: karry
# Procesando marca: kia
# Server error (500) encountered at https://www.autocosmos.cl/catalogo/vigente/kia. Waiting 2 second(s) before retrying...
# Procesando marca: maxus
# Procesando marca: mazda
# Procesando marca: mitsubishi
# Procesando marca: nissan
# Procesando marca: peugeot
# Server error (500) encountered at https://www.autocosmos.cl/catalogo/vigente/peugeot. Waiting 2 second(s) before retrying...
# Procesando marca: ram
# Procesando marca: renault
# Procesando marca: ssangyong
# Procesando marca: toyota
# Procesando marca: zna
# Procesando marca: baic
# Procesando marca: byd
# Procesando marca: citroen
# Procesando marca: hyundai
# Procesando marca: mg
# Procesando marca: chery
# Server error (500) encountered at https://www.autocosmos.cl/catalogo/vigente/chery. Waiting 2 second(s) before retrying...
# Server error (500) encountered at https://www.autocosmos.cl/catalogo/vigente/chery. Waiting 2 second(s) before retrying...
# Procesando marca: exeed
# Procesando marca: fiat
# Procesando marca: gac
# Server error (500) encountered at https://www.autocosmos.cl/catalogo/vigente/gac. Waiting 2 second(s) before retrying...
# Procesando marca: haval
# Procesando marca: jeep
# Server error (500) encountered at https://www.autocosmos.cl/catalogo/vigente/jeep. Waiting 2 second(s) before retrying...
# Procesando marca: jetour
# Server error (500) encountered at https://www.autocosmos.cl/catalogo/vigente/jetour. Waiting 2 second(s) before retrying...
# Procesando marca: kaiyi
# Procesando marca: mahindra
# Procesando marca: opel
# Server error (500) encountered at https://www.autocosmos.cl/catalogo/vigente/opel. Waiting 2 second(s) before retrying...
# Procesando marca: subaru
#      MARCA                                         Model Name  \
# 0  Changan  Changan Alsvin nuevos, precios del catálogo y ...
# 1  Changan  Changan CS15 nuevos, precios del catálogo y co...
# 2  Changan  Changan CS35 Plus  nuevos, precios del catálog...
# 3  Changan  Changan CS55 nuevos, precios del catálogo y co...
# 4  Changan  Changan CS55 Plus nuevos, precios del catálogo...
#
#                                            Model URL
# 0  https://www.autocosmos.cl/catalogo/vigente/cha...
# 1  https://www.autocosmos.cl/catalogo/vigente/cha...
# 2  https://www.autocosmos.cl/catalogo/vigente/cha...
# 3  https://www.autocosmos.cl/catalogo/vigente/cha...
# 4  https://www.autocosmos.cl/catalogo/vigente/cha...

# %%
df = pd.read_csv('models_by_marcas.csv')

# Function to clean the Model Name
def clean_model_name(row):
    marca = normalize_string(row['MARCA'].strip())
    model_name = row['Model Name'].strip()
    model_name_normalized = normalize_string(model_name)
    
    # Remove the manufacturer name from the model name
    pattern_marca = re.compile(r'\b' + re.escape(marca) + r'\b', re.IGNORECASE)
    model_name_cleaned = pattern_marca.sub('', model_name_normalized).strip()
    
    # Remove the phrase 'nuevos, precios del catálogo y cotizaciones.'
    phrase_to_remove = 'nuevos, precios del catalogo y cotizaciones.'
    model_name_cleaned = model_name_cleaned.replace(phrase_to_remove, '').strip()
    
    pattern_marca_original = re.compile(r'\b' + re.escape(row['MARCA']) + r'\b', re.IGNORECASE)
    model_name_original_cleaned = pattern_marca_original.sub('', row['Model Name']).strip()
    # Then remove the phrase (case-insensitive)
    pattern_phrase = re.compile(re.escape('nuevos, precios del catálogo y cotizaciones.'), re.IGNORECASE)
    model_name_original_cleaned = pattern_phrase.sub('', model_name_original_cleaned).strip()
    
    return model_name_original_cleaned

# Apply the cleaning function to the 'Model Name' column
df['Model Name'] = df.apply(clean_model_name, axis=1)

# Save the cleaned DataFrame to a new CSV
df.to_csv('models_by_marcas_cleaned.csv', index=False)
# Out:
#        MARCA        Model Name  \
# 0    Changan            Alsvin
# 1    Changan              CS15
# 2    Changan         CS35 Plus
# 3    Changan              CS55
# 4    Changan         CS55 Plus
# ..       ...               ...
# 358   Subaru  Forester Híbrido
# 359   Subaru     Impreza Sport
# 360   Subaru           Outback
# 361   Subaru               WRX
# 362   Subaru    WRX Sportwagon
#
#                                              Model URL
# 0    https://www.autocosmos.cl/catalogo/vigente/cha...
# 1    https://www.autocosmos.cl/catalogo/vigente/cha...
# 2    https://www.autocosmos.cl/catalogo/vigente/cha...
# 3    https://www.autocosmos.cl/catalogo/vigente/cha...
# 4    https://www.autocosmos.cl/catalogo/vigente/cha...
# ..                                                 ...
# 358  https://www.autocosmos.cl/catalogo/vigente/sub...
# 359  https://www.autocosmos.cl/catalogo/vigente/sub...
# 360  https://www.autocosmos.cl/catalogo/vigente/sub...
# 361  https://www.autocosmos.cl/catalogo/vigente/sub...
# 362  https://www.autocosmos.cl/catalogo/vigente/sub...
#
# [363 rows x 3 columns]

# %%
import pandas as pd
import unicodedata
import re
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

df1 = pd.read_csv('models_by_marcas_cleaned.csv')  
df2 = pd.read_csv('parsed_output.csv')             

# Ensure correct data types and fill missing values
columns_to_normalize = ['MARCA', 'Model Name']
for col in columns_to_normalize:
    df1[col] = df1[col].astype(str).fillna('')
    df2[col] = df2[col].astype(str).fillna('')

# Function to normalize strings
def normalize_string(s):
    s = str(s).lower()
    s = ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )
    s = re.sub(r'[^\w\s]', '', s)  # Remove punctuation
    s = re.sub(r'\s+', ' ', s).strip()  # Remove extra spaces
    return s

# Normalize 'Model Name' and 'MARCA'
for df in [df1, df2]:
    df['Model Name Simplified'] = df['Model Name'].apply(normalize_string)
    df['Marca Simplified'] = df['MARCA'].apply(normalize_string)

# Function to match model names
def match_model(row):
    marca = row['Marca Simplified']
    model_name = row['Model Name Simplified']
    df1_marca = df1[df1['Marca Simplified'] == marca]
    if df1_marca.empty:
        return None

    # Try exact match first
    exact_matches = df1_marca[df1_marca['Model Name Simplified'] == model_name]
    if not exact_matches.empty:
        return exact_matches.iloc[0]['Model URL']

    # Try substring match
    substring_matches = df1_marca[df1_marca['Model Name Simplified'].apply(lambda x: x in model_name or model_name in x)]
    if not substring_matches.empty:
        return substring_matches.iloc[0]['Model URL']

    # Try fuzzy matching
    df1_marca['Score'] = df1_marca['Model Name Simplified'].apply(lambda x: fuzz.token_set_ratio(model_name, x))
    best_match = df1_marca.loc[df1_marca['Score'].idxmax()]
    if best_match['Score'] >= 80:  # Adjusted threshold
        return best_match['Model URL']
    else:
        return None

# Apply the matching function to df2
df2['Model URL'] = df2.apply(match_model, axis=1)

# Save the updated df2
df2.to_csv('parsed_output_with_urls.csv', index=False)

# Print the unmatched models
unmatched = df2[df2['Model URL'].isnull()]
# Out:
# Unmatched Models:
#           MARCA                             Model Name
# 4       CHANGAN                          MD 301 AC ESP
# 6       CHANGAN                               MD201 XL
# 7       CHANGAN                                 MS 201
# 8       CHANGAN                     MS 301 PLUS AC ESP
# 26     DONGFENG                              DF 212 CS
# 49   GREAT WALL                         WINGLE 7 ELITE
# 50   GREAT WALL                    WINGLE 7 ELITE PLUS
# 107         RAM                             BIGHORN LX
# 108         RAM                  BIGHORN NIGHT EDITION
# 109         RAM                                  REBEL
# 110         RAM                       CREW CAB BIGHORN
# 111         RAM                       CREW CAB LIMITED
# 112         RAM                         CREW CAB REBEL
# 151         ZNA                                     R6
# 152        BAIC                                 EU5 EV
# 166     CITROEN        HDI 100 BVM6 C-ELYSEE FEEL PACK
# 167     CITROEN           C4 BLUEHDI 130 S&S FEEL PACK
# 168     CITROEN               C4 BLUEHDI 130 S&S SHINE
# 169     HYUNDAI                     ACCENT BN7I DESIGN
# 170     HYUNDAI                       ACCENT BN7I PLUS
# 198        BAIC                   BJ40P DIESEL PREMIUM
# 199        BAIC                   BJ40P GASOLINA ELITE
# 200        BAIC                  BJ40P GASOLINA LUXURY
# 262     CITROEN       C5 AIRCROSS BLUEHDI 130 S&S FEEL
# 263     CITROEN  C5 AIRCROSS BLUEHDI 130 S&S FEEL PACK
# 264     CITROEN      C5 AIRCROSS BLUEHDI 130 S&S SHINE
# 265     CITROEN           C5 AIRCROSS HYBRID 225 SHINE
# 266        DFSK                        SUV 500 COMFORT
# 267        DFSK                         SUV 500 LUXURY
# 268        DFSK                         SUV 500 LUXURY
# 401         KIA                NIRO EV EX 64.8KWH FULL
# 402         KIA                     NIRO EV LX 64.8KWH
# 427         KIA                        SPROTAGE EX GSL
# 428         KIA                        SPROTAGE EX DSL
# 429    MAHINDRA                         XUV300 COMFORT
# 430    MAHINDRA                           XUV300 ELITE
# 431    MAHINDRA                          XUV300 LUXURY
# 438       MAXUS                              G90 ELITE
# 439       MAXUS                             G90 LUXURY
# 503     PEUGEOT             ACTIVE PACK PURETECH 130HP
# 504     PEUGEOT             ALTURE PACK PURETECH 130HP
# 505     PEUGEOT              ALTURE PACK BLUEHDI 130HP
# 506     PEUGEOT                        ELÉCTRICO 136HP
# 507     PEUGEOT             ACTIVE PACK PURETECH 130HP
# 508     PEUGEOT                   ALTURE BLUEHDI 130HP
# 509     PEUGEOT                 ALTURE PACK THP 1650HP
# 510     PEUGEOT                       GT BLUEHDI 130HP
# 511     PEUGEOT                      GT PURETECH 180HP
# 513     PEUGEOT                   ALTURE BLUEHDI 130HP
# 514     PEUGEOT                       GT BLUEHDI 130HP
# 515     PEUGEOT                        ALTURETHP 165HP
# 516     PEUGEOT                      GT PURETECH 180HP
# 517     PEUGEOT              GT BLACK PACK BLUEHDI 130
# 518     PEUGEOT             GT BLACK PACK PURETECH 180

# %%
import pandas as pd

# Read the CSV file with Model URLs
df = pd.read_csv('parsed_output_with_urls.csv')

# Ensure 'Model URL' column is of string type and fill NaNs
df['Model URL'] = df['Model URL'].astype(str).fillna('')

# Drop empty URLs and get unique URLs
unique_urls = df['Model URL'][df['Model URL'] != ''].unique()

# Create a DataFrame from the unique URLs
df_unique_urls = pd.DataFrame(unique_urls, columns=['Model URL'])

# Save the unique URLs to a new CSV file
df_unique_urls.to_csv('unique_model_urls.csv', index=False)

print("Unique Model URLs have been saved to 'unique_model_urls.csv'.")
# Out:
# Unique Model URLs have been saved to 'unique_model_urls.csv'.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import re

# Read the unique URLs
df_urls = pd.read_csv('unique_model_urls.csv')

# Initialize a list to hold scraped data
scraped_data = []

max_retries = 10  # Maximum number of retries for 500 errors

for index, row in df_urls.iterrows():
    url = row['Model URL']
    print(f"Scraping URL: {url}")
    
    attempt = 0
    while attempt < max_retries:
        try:
            response = requests.get(url, timeout=None)
            if response.status_code == 500:
                print(f"Received 500 error on {url}, retrying... ({attempt + 1}/{max_retries})")
                attempt += 1
                time.sleep(1)  # Sleep before retrying
                continue
            else:
                response.raise_for_status()
                break  # Successful response, exit retry loop
        except requests.exceptions.RequestException as e:
            print(f"An error occurred for {url}: {e}")
            break  # Break on any request exception other than 500 error
    else:
        # This else executes if the loop completes without a break (after max retries)
        print(f"Failed to retrieve {url} after {max_retries} attempts.")
        continue

    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the table containing the versions
    version_table = soup.find('table', class_='table')
    if not version_table:
        print(f"No version table found at {url}")
        continue
    
    # Find all rows in the table body
    tbody = version_table.find('tbody')
    if not tbody:
        print(f"No table body found at {url}")
        continue

    rows = tbody.find_all('tr', itemprop='offers')
    versions = []
    for row in rows:
        # Find the meta tag with itemprop="name"
        meta_name = row.find('meta', itemprop='name')
        a_tag = row.find('a', itemprop='url')
        href = a_tag.get('href', '') if a_tag else ''
        if meta_name:
            version_name = meta_name.get('content', '')
            version_name = re.sub(r'\s*\(\d{4}\)\s*', '', version_name)
            full_url = "https://www.autocosmos.cl" + href
            versions.append([version_name, full_url])
    
    scraped_data.append({
        'Model URL': url,
        'Versions': versions
    })
    
    time.sleep(3)

# Save the scraped data to a CSV
df_scraped = pd.DataFrame(scraped_data)

# Convert 'Versions' from list of lists to a string
def versions_to_string(versions_list):
    return '; '.join([f"{v[0]}: {v[1]}" for v in versions_list])

df_scraped['Versions'] = df_scraped['Versions'].apply(versions_to_string)

df_scraped.to_csv('model_versions.csv', index=False)

print("Scraping completed. Data saved to 'model_versions.csv'.")
# Out:
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/changan/hunter
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/changan/md201-cargo-box
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/colorado
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/colorado-z71
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/montana
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/silverado
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/dfsk/d1
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ford/maverick
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ford/ranger
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/foton/g7
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/great-wall/poer
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jac/t8
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jmc/grand-avenue
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jmc/vigus-ev
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/jmc/vigus-ev, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jmc/vigus-plus
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jmc/vigus-work
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jmc/vigus-pro
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/karry/q52
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kia/frontier
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/maxus/t60
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/maxus/t60, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/maxus/t90
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/maxus/t90-ev
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mazda/bt-50
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mitsubishi/l-200
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/nissan/navara
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/peugeot/landtrek
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/peugeot/landtrek, retrying... (1/10)
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/peugeot/landtrek, retrying... (2/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ram/700
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ram/rampage
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/renault/oroch
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/renault/oroch, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ssangyong/musso
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/hilux
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/toyota/hilux, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/byd/han-ev
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/byd/qin
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/byd/seal
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/byd/seal, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/changan/alsvin
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/changan/alsvin, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/onix
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/sail
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/hyundai/grand-i10
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kia/ev6
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kia/soluto
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mg/3
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/mg/3, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mg/5
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mg/6
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mg/gt
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/nissan/leaf
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/nissan/sentra
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/nissan/sentra, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/nissan/versa
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/nissan/versa, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/corolla
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/yaris
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/baic/x35
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/baic/x55
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/byd/song-plus
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/byd/yuan-plus-ev
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/changan/cs15
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/changan/cs35-plus
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/changan/cs55
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chery/tiggo-2-pro
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chery/tiggo-8
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chery/tiggo-3-pro
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chery/tiggo-7-pro
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/blazer
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/bolt
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/captiva
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/groove
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/chevrolet/groove, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/spin
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/suburban
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/chevrolet/suburban, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/tahoe
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/tracker
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/chevrolet/traverse
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/dfsk/560
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/dfsk/600
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/exeed/lx
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/exeed/txl
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/exeed/txl, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/fiat/fastback
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/fiat/pulse
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ford/escape
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ford/territory
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/ford/territory, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/gac/emkoo
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/gac/emzoom
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/gac/gs3-power
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/gac/gs4-power
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/gac/gs8
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/haval/h6
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/haval/jolion
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/hyundai/creta
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/hyundai/creta, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/hyundai/ioniq-5
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/hyundai/kona
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/hyundai/palisade
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/hyundai/santa-fe
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/hyundai/tucson
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/hyundai/venue
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jac/js2
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/jac/js2, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jac/js3
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jac/js4
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jac/js6
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jac/js8
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jeep/commander
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jeep/compass
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jeep/grand-cherokee
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/jeep/grand-cherokee, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jeep/renegade
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/jeep/renegade, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jeep/wrangler
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jetour/dashing
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jetour/x70
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jetour/x70-plus
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/jetour/x70-plus, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/jetour/x90-plus
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kaiyi/x3
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kia/carens
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kia/ev9
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kia/seltos
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kia/sonet
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kia/sorento
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/kia/sportage
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/maxus/d60
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/maxus/d90
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/maxus/euniq-6
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mg/hs
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mg/marvel-r
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mg/zs
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mg/one
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/mg/one, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mg/zx
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mitsubishi/asx
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mitsubishi/eclipse-cross
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/mitsubishi/eclipse-cross, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mitsubishi/montero-sport
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mitsubishi/outlander
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mitsubishi/xpander-cross
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/mitsubishi/xpander
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/nissan/kicks
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/nissan/pathfinder
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/nissan/qashqai
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/nissan/x-trail
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/opel/crossland
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/opel/crossland, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/opel/grandland
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/opel/mokka
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/peugeot/3008-hybrid4
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/peugeot/rifter
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ssangyong/korando
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ssangyong/rexton
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ssangyong/tivoli
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/ssangyong/torres
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/subaru/crosstrek
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/4runner
# Received 500 error on https://www.autocosmos.cl/catalogo/vigente/toyota/4runner, retrying... (1/10)
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/fortuner
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/raize
# Scraping URL: https://www.autocosmos.cl/catalogo/vigente/toyota/rav4
# Scraping completed. Data saved to 'model_versions.csv'.

# %%
import pandas as pd
import re
from fuzzywuzzy import fuzz

# Read the CSV files
df_parsed = pd.read_csv('parsed_output_with_urls.csv')
df_versions = pd.read_csv('model_versions.csv')

# Function to parse the 'Versions' column
def parse_versions_string(versions_str):
    version_list = []
    if pd.isna(versions_str) or versions_str.strip() == '':
        return version_list
    versions = versions_str.split(';')
    for v in versions:
        v = v.strip()
        if not v:
            continue
        if ':' in v:
            name, url = v.split(':', 1)
            version_list.append([name.strip(), url.strip()])
        else:
            version_list.append([v.strip(), ''])
    return version_list

# Apply the parsing function to 'Versions' column
df_versions['Versions'] = df_versions['Versions'].apply(parse_versions_string)

# Function to simplify strings
def simplify_string(s):
    s = str(s).lower()
    s = re.sub(r'[^a-z0-9\s]', '', s)  # Remove special characters
    s = re.sub(r'\s+', ' ', s)  # Replace multiple spaces with single space
    s = s.strip()
    return s

# Simplify relevant columns in df_parsed
df_parsed['Model Name Simplified'] = df_parsed['Model Name Simplified'].apply(simplify_string)
df_parsed['Engine Simplified'] = df_parsed['Engine'].apply(lambda x: simplify_string(x))
df_parsed['Drive Simplified'] = df_parsed['Drive'].apply(lambda x: simplify_string(x))
df_parsed['Transmission Simplified'] = df_parsed['Transmission'].apply(lambda x: simplify_string(x))

# Function to extract attributes from version name
def extract_attributes(version_name):
    version_name = version_name.lower()
    # Engine extraction
    engine_match = re.search(r'(\d+\.\d+|\d+)(l|t)?', version_name)
    engine = engine_match.group(1) if engine_match else ''
    # Drive extraction
    drive_match = re.search(r'(4x2|4x4|awd|fwd|rwd)', version_name)
    drive = drive_match.group(1) if drive_match else ''
    # Transmission extraction
    transmission_match = re.search(r'\b(mt|at|manual|aut|automatic)\b', version_name)
    transmission = transmission_match.group(1) if transmission_match else ''
    simplified_name = simplify_string(version_name)
    return simplified_name, engine, drive, transmission

# Initialize a list to hold the matched data
matched_data = []

for index, row in df_parsed.iterrows():
    model_url = row['Model URL']
    model_name_simplified = row['Model Name Simplified']
    engine_simplified = row['Engine Simplified']
    drive_simplified = row['Drive Simplified']
    transmission_simplified = row['Transmission Simplified']

    # Get the versions corresponding to this model URL
    versions_row = df_versions[df_versions['Model URL'] == model_url]
    if versions_row.empty:
        matched_version = None
    else:
        versions_list = versions_row.iloc[0]['Versions']
        best_score = -1  # Initialize to -1 to handle zero score cases
        best_match = None

        # If there is only one version, match it directly
        if len(versions_list) == 1:
            version = versions_list[0]
            version_name, version_url = version
            matched_version = {
                'Version URL': version_url,
            }
        else:
            for version in versions_list:
                version_name, version_url = version
                # Extract attributes
                version_name_simplified, v_engine, v_drive, v_transmission = extract_attributes(version_name)

                # Calculate matching score
                name_score = fuzz.token_sort_ratio(model_name_simplified, version_name_simplified)
                engine_score = fuzz.partial_ratio(engine_simplified, v_engine) if engine_simplified and v_engine else 0
                drive_score = 100 if drive_simplified == v_drive and drive_simplified else 0
                transmission_score = 100 if transmission_simplified == v_transmission and transmission_simplified else 0

                total_score = name_score + engine_score + drive_score + transmission_score

                if total_score > best_score:
                    best_score = total_score
                    best_match = {
                        'Version URL': version_url,
                    }

            matched_version = best_match

    # Ensure that all keys are present even if no match is found
    if not matched_version:
        matched_version = {
            'Version URL': None,
        }

    # Append matched version to the row
    matched_data.append({
        **row.to_dict(),
        **matched_version
    })

# Create a DataFrame from the matched data
df_matched = pd.DataFrame(matched_data)

# Remove duplicates based on 'Model Name', 'Engine', 'Drive', 'Transmission'
df_matched = df_matched.drop_duplicates(subset=['Model Name', 'Engine', 'Drive', 'Transmission'])

# Save the matched data to a new CSV
df_matched.to_csv('matched_versions.csv', index=False)

print("Matching completed. Data saved to 'matched_versions.csv'.")
# Out:
# Matching completed. Data saved to 'matched_versions.csv'.

# %% [markdown]
# ### Correr esta celda para obtener el csv final "scraped_data.csv"

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import numpy as np

# Read the matched_versions.csv file
df_matched = pd.read_csv('matched_versions.csv')

# Initialize a list to hold the output data
output_data = []

for index, row in df_matched.iterrows():
    # Extract necessary fields and handle 'nan' values
    marca = str(row['MARCA']) if not pd.isna(row['MARCA']) else ''
    model_name = str(row['Model Name']) if not pd.isna(row['Model Name']) else ''
    engine = str(row['Engine']) if not pd.isna(row['Engine']) else ''
    drive = str(row['Drive']) if not pd.isna(row['Drive']) else ''
    transmission = str(row['Transmission']) if not pd.isna(row['Transmission']) else ''
    year = str(row['Year']) if not pd.isna(row['Year']) else ''
    version_url = str(row['Version URL']) if not pd.isna(row['Version URL']) else ''

    # Create the MODEL column and remove any 'nan' substrings
    model = ' '.join([marca, model_name, engine, drive, transmission, year])
    model = model.replace('nan', '').strip()

    # Remove any extra spaces
    model = ' '.join(model.split())

    # Print progress
    print(f"Processing model: {model}")

    # Check if version_url is valid
    if not version_url or pd.isna(version_url) or version_url.lower() == 'nan':
        print(f"Skipping {model} due to invalid Version URL")
        continue  # Skip to next row

    # Initialize retry parameters
    retries = 0
    max_retries = 20
    success = False

    while retries < max_retries and not success:
        try:
            response = requests.get(version_url)
            if response.status_code == 200:
                success = True
                html_content = response.content
            elif response.status_code == 500:
                retries += 1
                time.sleep(1)  # Wait for 1 second before retrying
                continue
            else:
                # Handle other HTTP errors
                print(f"Error fetching {version_url}: HTTP {response.status_code}")
                break
        except requests.exceptions.RequestException as e:
            print(f"Request exception for {version_url}: {e}")
            break

    if not success:
        print(f"Failed to fetch {version_url} after {retries} retries.")
        continue  # Skip to next row

    # Parse the HTML content with BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Initialize a dictionary to hold the attributes
    attributes = {}

    # Scrape 'Especificaciones técnicas' section
    especificaciones_section = soup.find('section', {'id': 'especificaciones'})
    if especificaciones_section:
        # Extract all tables within this section
        tables = especificaciones_section.find_all('table', {'class': 'ficha'})
        for table in tables:
            # Get the caption (category)
            caption_tag = table.find('caption')
            category = caption_tag.get_text(strip=True) if caption_tag else 'Unknown'

            # For each row in the table
            rows = table.find_all('tr')
            for row_tr in rows:
                cols = row_tr.find_all('td')
                if len(cols) == 2:
                    attr_name = cols[0].get_text(strip=True)
                    attr_value = cols[1].get_text(strip=True)
                    # Prefix the attribute name with the category to avoid duplicates
                    key = f"{category} - {attr_name}"
                    attributes[key] = attr_value
    else:
        print(f"No 'Especificaciones técnicas' section found in {version_url}")
        # We can continue to scrape 'Equipamiento' even if 'Especificaciones técnicas' is missing

    # Scrape 'Equipamiento' section
    equipamiento_section = soup.find('section', {'id': 'equipamiento'})
    if equipamiento_section:
        # Extract all tables within this section
        tables = equipamiento_section.find_all('table', {'class': 'ficha'})
        for table in tables:
            # Get the caption (category)
            caption_tag = table.find('caption')
            category = caption_tag.get_text(strip=True) if caption_tag else 'Unknown'

            # For each row in the table
            rows = table.find_all('tr')
            for row_tr in rows:
                cols = row_tr.find_all('td')
                if len(cols) == 2:
                    attr_name = cols[0].get_text(strip=True)
                    attr_value = cols[1].get_text(strip=True)
                    # Prefix the attribute name with the category to avoid duplicates
                    key = f"{category} - {attr_name}"
                    attributes[key] = attr_value
    else:
        print(f"No 'Equipamiento' section found in {version_url}")

    # Create a dictionary for this row
    data_row = {
        'MODEL': model,
        'MARCA': marca,
        'Model Name': model_name,
        'Engine': engine,
        'Drive': drive,
        'Transmission': transmission,
        'Year': year,
        'Version URL': version_url
    }
    data_row.update(attributes)

    # Replace 'nan' with empty string in data_row values
    data_row = {k: ('' if v == 'nan' else v) for k, v in data_row.items()}

    # Append to output_data
    output_data.append(data_row)

# Create a DataFrame from the output data
df_output = pd.DataFrame(output_data)

# Drop columns that are entirely empty
df_output.dropna(axis=1, how='all', inplace=True)

# Replace NaN values with empty strings
df_output.fillna('', inplace=True)

# Save to a new CSV file
df_output.to_csv('scraped_data.csv', index=False)

print("Data scraping completed. Results saved to 'scraped_data.csv'.")
# Out:
# Processing model: CHANGAN HUNTER COMFORT 2.0T 4X2 MT 2024
# Processing model: CHANGAN HUNTER COMFORT 2.0T 4X4 MT 2024
# Processing model: CHANGAN HUNTER ELITE SPORT 2.0T 4X4 MT 2024
# Processing model: CHANGAN HUNTER LUXURY 2.0T 4X2 MT 2024
# Processing model: CHANGAN MD 301 AC ESP MT 2024
# Skipping CHANGAN MD 301 AC ESP MT 2024 due to invalid Version URL
# Processing model: CHANGAN MD201 MT 2024
# Processing model: CHANGAN MD201 XL 1.5L MT 2024
# Skipping CHANGAN MD201 XL 1.5L MT 2024 due to invalid Version URL
# Processing model: CHANGAN MS 201 MT 2024
# Skipping CHANGAN MS 201 MT 2024 due to invalid Version URL
# Processing model: CHANGAN MS 301 PLUS AC ESP 2024
# Skipping CHANGAN MS 301 PLUS AC ESP 2024 due to invalid Version URL
# Processing model: CHEVROLET COLORADO HIGH COUNTRY 4X4 AT 2024
# Processing model: CHEVROLET COLORADO LS 4X2 MT 2024
# Processing model: CHEVROLET COLORADO LT 4X4 AT 2024
# Processing model: CHEVROLET COLORADO LT 4X4 MT 2024
# Processing model: CHEVROLET COLORADO LTZ 4X4 AT 2024
# Processing model: CHEVROLET COLORADO Z71 4X4 AT 2024
# Processing model: CHEVROLET MONTANA T LT 1.2 MT 2024
# Processing model: CHEVROLET MONTANA T LTZ 1.2 AT 2024
# Processing model: CHEVROLET MONTANA T PREMIER 1.2 AT 2024
# Processing model: CHEVROLET MONTANA T PREMIER 1.2 MT 2024
# Processing model: CHEVROLET MONTANA T RS 1.2 AT 2024
# Processing model: CHEVROLET SILVERADO HC TD 3.0 4X4 AT 2024
# Processing model: CHEVROLET SILVERADO LT TRAIL BOSS Z71 V8 5.3L 4X4 AT 2024
# Processing model: CHEVROLET SILVERADO ZR2 V8 6.2L 4X4 AT 2024
# Processing model: DFSK D1 CONFORT 4X2 MT 2024
# Processing model: DFSK D1 LUXURY 4X4 AT 2024
# Processing model: DFSK D1 LUXURY 4X4 MT 2024
# Processing model: DONGFENG DF 212 CS MT 2024
# Skipping DONGFENG DF 212 CS MT 2024 due to invalid Version URL
# Processing model: FORD MAVERICK LARIAT FX4 HEV AT 2024
# Processing model: FORD MAVERICK XLT 2.0 4X2 AT 2024
# Processing model: FORD RANGER DSL LIMITED 3.0 4X4 AT 2024
# Processing model: FORD RANGER DSL XL 2.0 4X2 MT 2024
# Processing model: FORD RANGER DSL XL 2.0 4X4 MT 2024
# Processing model: FORD RANGER DSL XLS 2.0 4X2 MT 2024
# Processing model: FORD RANGER DSL XLS 2.0 4X4 MT 2024
# Processing model: FORD RANGER DSL XLT 2.0 4X2 AT 2024
# Processing model: FORD RANGER DSL XLT 2.0 4X4 AT 2024
# Processing model: FORD RANGER DSL XLT 2.0 4X4 MT 2024
# Processing model: FOTON G7 LITE 4X4 2024
# Processing model: FOTON G7 ULTIMATE 4X2 2024
# Processing model: FOTON G7 ULTIMATE 4X4 2024
# Processing model: GREAT WALL POER DELUXE 4X2 2024
# Processing model: GREAT WALL POER ELITE 4X2 2024
# Processing model: GREAT WALL POER ELITE PANT 4X2 2024
# Processing model: GREAT WALL POER DELUXE 4X4 2024
# Processing model: GREAT WALL POER ELITE 4X4 2024
# Processing model: GREAT WALL POER ELITE PANT 4X4 2024
# Processing model: GREAT WALL POER PLUS ELITE 4X2 2024
# Processing model: GREAT WALL POER PLUS DELUXE 4X4 2024
# Processing model: GREAT WALL POER PLUS ELITE 4X4 2024
# Processing model: GREAT WALL WINGLE 7 ELITE 4X2 2024
# Skipping GREAT WALL WINGLE 7 ELITE 4X2 2024 due to invalid Version URL
# Processing model: GREAT WALL WINGLE 7 ELITE PLUS 4X4 2024
# Skipping GREAT WALL WINGLE 7 ELITE PLUS 4X4 2024 due to invalid Version URL
# Processing model: JAC T8 CE COMFORT 2.0T 4X2 MT 2024
# Processing model: JAC T8 CE COMFORT 2.0T 4X4 MT 2024
# Processing model: JAC T8 PRO ADVANCE 4X4 MT 2024
# Processing model: JAC T8 PRO LUXURY 4X2 MT 2024
# Processing model: JAC T8 PRO LUXURY 4X4 MT 2024
# Processing model: JAC T8 XE ADVANCE 2.0T 4X2 MT 2024
# Processing model: JAC T8 XE ADVANCE 2.0T 4X4 MT 2024
# Processing model: JMC GRAND AVENUE 4X2 AT 2024
# Processing model: JMC GRAND AVENUE 4X2 MT 2024
# Processing model: JMC GRAND AVENUE 4X4 AT 2024
# Processing model: JMC GRAND AVENUE 4X4 MT 2024
# Processing model: JMC VIGUS EV AT 2024
# Processing model: JMC VIGUS NEW PLUS 4X2 MT 2024
# Processing model: JMC VIGUS NEW PLUS 4X4 MT 2024
# Processing model: JMC VIGUS NEW WORK 4X2 MT 2024
# Processing model: JMC VIGUS NEW WORK 4X4 MT 2024
# Processing model: JMC VIGUS PRO 4X2 AT 2024
# Processing model: JMC VIGUS PRO 4X4 AT 2024
# Processing model: KARRY Q52 CD 1.6L MT 2024
# Processing model: KIA FRONTIER C/C LX AV AB 2.5L MT 2024
# Processing model: KIA FRONTIER C/C LX AV 2.5L MT 2024
# Processing model: KIA FRONTIER D/C LX AV AB 2.5L MT 2024
# Processing model: KIA FRONTIER P/UP LX AV AB 2.5L MT 2024
# Processing model: MAXUS T60 ANCAP E6 4X4 MT 2024
# Processing model: MAXUS T60 DX 4X2 MT 2024
# Processing model: MAXUS T60 DX E6 4X2 MT 2024
# Processing model: MAXUS T60 DX E6 4X4 MT 2024
# Processing model: MAXUS T60 E6 GL 4X2 AT 2024
# Processing model: MAXUS T60 E6 GL 4X2 MT 2024
# Processing model: MAXUS T60 E6 GL 4X4 MT 2024
# Processing model: MAXUS T60 E6 GLX 4X4 AT 2024
# Processing model: MAXUS T60 SC DX E6 4X2 MT 2024
# Processing model: MAXUS T60 SC DX E6 4X4 MT 2024
# Processing model: MAXUS T90 E6 4X4 AT 2024
# Processing model: MAXUS T90 E6 4X4 MT 2024
# Processing model: MAXUS T90 EV 4X2 AT 2024
# Processing model: MAZDA BT-50 CORE 4X4 AT 2024
# Processing model: MAZDA BT-50 CORE 4X4 MT 2024
# Processing model: MAZDA BT-50 HIGH 4X4 AT 2024
# Processing model: MAZDA BT-50 HIGH PLUS 4X4 AT 2024
# Processing model: MITSUBISHI L200 D/C TD DAKAR CRS 4X4 MT 2024
# Processing model: MITSUBISHI L200 D/C TD KATANA CR 4X2 MT 2024
# Processing model: MITSUBISHI L200 D/C TD KATANA CRT 4X4 MT 2024
# Processing model: MITSUBISHI L200 D/C TD WORK CR 4X2 MT 2024
# Processing model: NISSAN NAVARA DC P4X 2024
# Processing model: NISSAN NAVARA DC PLATINUM 2.3D 4X4 AT 2024
# Processing model: NISSAN NAVARA DC PLATINUM 2.3D 4X4 MT 2024
# Processing model: NISSAN NAVARA DC SE 2.3D 4X2 MT 2024
# Processing model: NISSAN NAVARA DC SE 2.3D 4X4 MT 2024
# Processing model: NISSAN NAVARA DC XE 2.3D 4X2 MT 2024
# Processing model: NISSAN NAVARA DC XE 2.3D 4X4 AT 2024
# Processing model: NISSAN NAVARA DC XE 2.3D 4X4 MT 2024
# Processing model: PEUGEOT LANDTREK ACTION4 BLUEHDI 180 4X4 AT 2024
# Processing model: PEUGEOT LANDTREK ACTIVE BLUEHDI 180 4X2 MT 2024
# Processing model: PEUGEOT LANDTREK ACTIVE BLUEHDI 180 4X4 AT 2024
# Processing model: PEUGEOT LANDTREK ACTIVE BLUEHDI 180 4X4 MT 2024
# Processing model: RAM BIGHORN LX 1.8 AT 2024
# Skipping RAM BIGHORN LX 1.8 AT 2024 due to invalid Version URL
# Processing model: RAM BIGHORN NIGHT EDITION 1.8 AT 2024
# Skipping RAM BIGHORN NIGHT EDITION 1.8 AT 2024 due to invalid Version URL
# Processing model: RAM REBEL 2.0 4X4 AT 2024
# Skipping RAM REBEL 2.0 4X4 AT 2024 due to invalid Version URL
# Processing model: RAM CREW CAB BIGHORN 3.6L AT 2024
# Skipping RAM CREW CAB BIGHORN 3.6L AT 2024 due to invalid Version URL
# Processing model: RAM CREW CAB LIMITED 5.7L AT 2024
# Skipping RAM CREW CAB LIMITED 5.7L AT 2024 due to invalid Version URL
# Processing model: RAM CREW CAB REBEL 5.7L AT 2024
# Skipping RAM CREW CAB REBEL 5.7L AT 2024 due to invalid Version URL
# Processing model: RAM 700 BIGHORN CD 1.3 AT 2024
# Processing model: RAM 700 BIGHORN CD 1.3L MT 2024
# Processing model: RAM 700 LARAMIE CD 1.3 AT 2024
# Processing model: RAM 700 LARAMIE CD 1.3L MT 2024
# Processing model: RAM 700 LONGHORN CD 1.3 AT 2024
# Processing model: RAM 700 SLT CS 1.3L MT 2024
# Processing model: RAM 700 SLT DC 1.3L MT 2024
# Processing model: RAM RAMPAGE BIGHORN 2.0L AT 2024
# Processing model: RAM RAMPAGE LARAMIE 2.0L AT 2024
# Processing model: RAM RAMPAGE R/T 2.0L AT 2024
# Processing model: RENAULT OROCH INTENS TURBO 1.3 4X2 AT 2024
# Processing model: RENAULT OROCH INTENS TURBO KIT 1.3 4X2 AT 2024
# Processing model: RENAULT OROCH INTENS TURBO KITMT 1.3 4X4 2024
# Processing model: RENAULT OROCH INTENS TURBO 1.3 4X4 MT 2024
# Processing model: RENAULT OROCH ZEN 1.6L 4X2 MT 2024
# Processing model: SSANGYONG MUSSO GLX 2.2TD 4X4 MT 2024
# Processing model: SSANGYONG MUSSO GRAND GLX 2.2TD 4X2 AT 2024
# Processing model: SSANGYONG MUSSO GRAND GLX 2.2TD 4X2 MT 2024
# Processing model: SSANGYONG MUSSO GRAND GLX 2.2TD 4X4 MT 2024
# Processing model: SSANGYONG MUSSO GRAND LIMITED 2.2TD 4X4 AT 2024
# Processing model: SSANGYONG MUSSO GRAND LIMITED PLUS 2.2TD 4X4 AT 2024
# Processing model: SSANGYONG MUSSO GRAND LX 2.2TD 4X2 MT 2024
# Processing model: SSANGYONG MUSSO GRAND LX 2.2TD 4X4 MT 2024
# Processing model: SSANGYONG MUSSO LIMITED 2.2TD 4X4 AT 2024
# Processing model: SSANGYONG MUSSO LIMITED PLUS 2.2TD 4X4 AT 2024
# Processing model: TOYOTA HILUX DX 2.4 4X2 MT 2024
# Processing model: TOYOTA HILUX DX 2.4 4X4 MT 2024
# Processing model: TOYOTA HILUX DX 2.8 4X4 MT 2024
# Processing model: TOYOTA HILUX DX CS 2.8 4X4 MT 2024
# Processing model: TOYOTA HILUX DX DC 2.4 4X2 MT 2024
# Processing model: TOYOTA HILUX DX DC 2.4 4X4 MT 2024
# Processing model: TOYOTA HILUX SR 2.4 4X2 MT 2024
# Processing model: TOYOTA HILUX SR 2.4 4X4 MT 2024
# Processing model: TOYOTA HILUX SR 2.7 4X2 MT 2024
# Processing model: TOYOTA HILUX SR 2.8 4X4 MT 2024
# Processing model: TOYOTA HILUX SR DC 2.4 4X2 MT 2024
# Processing model: TOYOTA HILUX SR DC 2.4 4X4 MT 2024
# Processing model: TOYOTA HILUX SRV 2.8 4X4 AT 2024
# Processing model: ZNA R6 AT 2024
# Skipping ZNA R6 AT 2024 due to invalid Version URL
# Processing model: BAIC EU5 EV 2024
# Skipping BAIC EU5 EV 2024 due to invalid Version URL
# Processing model: BYD HAN EV 2024
# Processing model: BYD QIN PLUS DM 2024
# Processing model: BYD SEAL EV 2024
# Processing model: CHANGAN ALSVIN COMFORT 2024
# Processing model: CHANGAN ALSVIN ELITE AT 2024
# Processing model: CHANGAN ALSVIN LUXURY 2024
# Processing model: CHEVROLET ONIX LT R 1.0 2024
# Processing model: CHEVROLET ONIX LTZ P2 1.0 2024
# Processing model: CHEVROLET ONIX PREMIER R 1.0 2024
# Processing model: CHEVROLET ONIX LS P 1.2 2024
# Processing model: CHEVROLET SAIL NB LT 1.5L 2024
# Processing model: CHEVROLET SAIL NB LTZ 1.5L 2024
# Processing model: CHEVROLET SAIL NB LTZ 1.5L CVT 2024
# Processing model: CITROEN HDI 100 BVM6 C-ELYSEE FEEL PACK 1.5 2024
# Skipping CITROEN HDI 100 BVM6 C-ELYSEE FEEL PACK 1.5 2024 due to invalid Version URL
# Processing model: CITROEN C4 BLUEHDI 130 S&S FEEL PACK 1.5 EAT8 2024
# Skipping CITROEN C4 BLUEHDI 130 S&S FEEL PACK 1.5 EAT8 2024 due to invalid Version URL
# Processing model: CITROEN C4 BLUEHDI 130 S&S SHINE 1.5 EAT8 2024
# Skipping CITROEN C4 BLUEHDI 130 S&S SHINE 1.5 EAT8 2024 due to invalid Version URL
# Processing model: HYUNDAI ACCENT BN7I DESIGN 1.5 2024
# Skipping HYUNDAI ACCENT BN7I DESIGN 1.5 2024 due to invalid Version URL
# Processing model: HYUNDAI ACCENT BN7I PLUS 1.5 2024
# Skipping HYUNDAI ACCENT BN7I PLUS 1.5 2024 due to invalid Version URL
# Processing model: HYUNDAI GRAND I10 AI3 DESIGN FL 1.2 2024
# Processing model: HYUNDAI GRAND I10 AI3 PLUS FL 1.2 2024
# Processing model: KIA EV6 EV GT-LINE 77.4KWH AWD 2024
# Processing model: KIA SOLUTO EX G SRF FULL 1.4L 5MT 2024
# Processing model: KIA SOLUTO LX G LL 1.4L 5MT 2024
# Processing model: MG 3 COM AT 2024
# Processing model: MG 5 COM 1.5L CVT 2024
# Processing model: MG 5 DLX 1.5L CVT 2024
# Processing model: MG 5 COM 1.5L MT 2024
# Processing model: MG 5 DLX 1.5L MT 2024
# Processing model: MG 6 COM 1.5T MT 2024
# Processing model: MG 6 DLX 1.5T MT 2024
# Processing model: MG GT COM 1.5L 2WD CVT 2024
# Processing model: MG GT COM 1.5L 2WD MT 2024
# Processing model: MG GT DLX 1.5T DCT 2024
# Processing model: NISSAN LEAF 2024
# Processing model: NISSAN SENTRA ADVANCE CVT 2024
# Processing model: NISSAN SENTRA ADVANCE MT 2024
# Processing model: NISSAN SENTRA EXCLUSIVE CVT 2024
# Processing model: NISSAN SENTRA SENSE MT 2024
# Processing model: NISSAN VERSA ADVANCE CVT 2024
# Processing model: NISSAN VERSA ADVANCE MT 2024
# Processing model: NISSAN VERSA EXCLUSIVE CVT 2024
# Processing model: NISSAN VERSA SENSE CVT 2024
# Processing model: NISSAN VERSA SENSE MT 2024
# Processing model: TOYOTA COROLLA SEG HEV 1.8 2024
# Processing model: TOYOTA YARIS I 1.5 2024
# Processing model: BAIC BJ40P DIESEL PREMIUM 4X4 2024
# Skipping BAIC BJ40P DIESEL PREMIUM 4X4 2024 due to invalid Version URL
# Processing model: BAIC BJ40P GASOLINA ELITE 4X2 2024
# Skipping BAIC BJ40P GASOLINA ELITE 4X2 2024 due to invalid Version URL
# Processing model: BAIC BJ40P GASOLINA LUXURY 4X4 2024
# Skipping BAIC BJ40P GASOLINA LUXURY 4X4 2024 due to invalid Version URL
# Processing model: BAIC X35 LUXURY 1.5T CVT 2024
# Processing model: BAIC X35 COMFORT 1.5T MT 2024
# Processing model: BAIC X35 ELITE 1.5T MT 2024
# Processing model: BAIC X55 E6 COMFORT 1.5T MT 2024
# Processing model: BAIC X55 E6 ELITE 1.5T MT 2024
# Processing model: BAIC X55 PLUS COMFORT 2024
# Processing model: BAIC X55 PLUS ELITE 2024
# Processing model: BAIC X55 PLUS LUXURY 2024
# Processing model: BYD SONG PLUS DM GL AT 2024
# Processing model: BYD SONG PLUS DM GS AT 2024
# Processing model: BYD YUAN PLUS EV GL AT 2024
# Processing model: BYD YUAN PLUS EV GS AT 2024
# Processing model: CHANGAN CS15 COMFORT 1.5L MT 2024
# Processing model: CHANGAN CS15 ELITE 1.5L AT 2024
# Processing model: CHANGAN CS15 ELITE 1.5L MT 2024
# Processing model: CHANGAN CS15 LUXURY 1.5L MT 2024
# Processing model: CHANGAN CS35 PLUS ELITE 1.4L AT 2024
# Processing model: CHANGAN CS35 PLUS LUX 1.4L AT 2024
# Processing model: CHANGAN CS35 PLUS COMFORT 1.6L MT 2024
# Processing model: CHANGAN CS35 PLUS LUXURY 1.6L MT 2024
# Processing model: CHANGAN CS55 COMFORT 1.5L MT 2024
# Processing model: CHANGAN CS55 LUXURY 1.5L AT 2024
# Processing model: CHANGAN CS55 LUXURY 1.5L MT 2024
# Processing model: CHANGAN CS55 PLUS ELITE 1.5L AT 2024
# Processing model: CHANGAN CS55 PLUS LUXURY 1.5L AT 2024
# Processing model: CHERY TIGGO 2 PRO GLX 1.0L AT 2024
# Processing model: CHERY TIGGO 2 PRO GLX 1.0L MT 2024
# Processing model: CHERY TIGGO 2 GLS 1.5L AT 2024
# Processing model: CHERY TIGGO 2 PRO GLS 1.5L AT 2024
# Processing model: CHERY TIGGO 2 PRO GLS 1.5L MT 2024
# Processing model: CHERY TIGGO 3 PRO GLS 1.5L AT 2024
# Processing model: CHERY TIGGO 3 PRO GLX 1.5L AT 2024
# Processing model: CHERY TIGGO 3 PRO GLX 1.5L MT 2024
# Processing model: CHERY TIGGO 7 PRO GLS 1.5L AT 2024
# Processing model: CHERY TIGGO 7 PRO GLX 1.5L AT 2024
# Processing model: CHERY TIGGO 8 GLS 1.5L MT 2024
# Processing model: CHERY TIGGO 8 GLX 1.5L AT 2024
# Processing model: CHERY TIGGO 8 PRO GLX 1.6L AT 2024
# Processing model: CHERY TIGGO 8 PRO MAX GLX 1.6L AT 2024
# Processing model: CHERY TIGGO 8 PRO MAX GLX 2.0L AWD AT 2024
# Processing model: CHEVROLET BLAZER RS 3.6L AWD AT 2024
# Processing model: CHEVROLET BOLT EUV AT 2024
# Processing model: CHEVROLET CAPTIVA LTZ P 1.5L AT 2024
# Processing model: CHEVROLET CAPTIVA LTZ P 1.5L MT 2024
# Processing model: CHEVROLET CAPTIVA PREMIER P 1.5L AT 2024
# Processing model: CHEVROLET CAPTIVA PREMIER P 1.5L MT 2024
# Processing model: CHEVROLET GROOVE LTZ R 1.5L MT 2024
# Processing model: CHEVROLET GROOVE PREMIER R 1.5L MT 2024
# Processing model: CHEVROLET SPIN ACTIV 7P 1.8L AT 2024
# Processing model: CHEVROLET SPIN PREMIER 7P 1.8L MT 2024
# Processing model: CHEVROLET SUBURBAN Z71 P 5.3L 4WD AT 2024
# Processing model: CHEVROLET TAHOE Z71 P 5.3L 4WD AT 2024
# Processing model: CHEVROLET TRACKER LS R 1.2L MT 2024
# Processing model: CHEVROLET TRACKER LTZ P 1.2L MT 2024
# Processing model: CHEVROLET TRACKER LTZ R 1.2L AT 2024
# Processing model: CHEVROLET TRACKER PREMIER P3 1.2L AT 2024
# Processing model: CHEVROLET TRACKER PREMIER P4 1.2L AT 2024
# Processing model: CHEVROLET TRACKER RS R 1.2L AT 2024
# Processing model: CHEVROLET TRAVERSE LT 3.6L AWD AT 2024
# Processing model: CHEVROLET TRAVERSE PREMIER 3.6L AWD AT 2024
# Processing model: CHEVROLET TRAVERSE RS 3.6L AWD AT 2024
# Processing model: CITROEN C5 AIRCROSS BLUEHDI 130 S&S FEEL 1.5L AT 2024
# Skipping CITROEN C5 AIRCROSS BLUEHDI 130 S&S FEEL 1.5L AT 2024 due to invalid Version URL
# Processing model: CITROEN C5 AIRCROSS BLUEHDI 130 S&S FEEL PACK 1.5L AT 2024
# Skipping CITROEN C5 AIRCROSS BLUEHDI 130 S&S FEEL PACK 1.5L AT 2024 due to invalid Version URL
# Processing model: CITROEN C5 AIRCROSS BLUEHDI 130 S&S SHINE 1.5L AT 2024
# Skipping CITROEN C5 AIRCROSS BLUEHDI 130 S&S SHINE 1.5L AT 2024 due to invalid Version URL
# Processing model: CITROEN C5 AIRCROSS HYBRID 225 SHINE AT 2024
# Skipping CITROEN C5 AIRCROSS HYBRID 225 SHINE AT 2024 due to invalid Version URL
# Processing model: DFSK SUV 500 COMFORT 1.5 2024
# Skipping DFSK SUV 500 COMFORT 1.5 2024 due to invalid Version URL
# Processing model: DFSK SUV 500 LUXURY 1.5 2024
# Skipping DFSK SUV 500 LUXURY 1.5 2024 due to invalid Version URL
# Processing model: DFSK SUV 500 LUXURY 1.5 CVT 2024
# Skipping DFSK SUV 500 LUXURY 1.5 CVT 2024 due to invalid Version URL
# Processing model: DFSK SUV 560 COMFORT 1.8 2R 2024
# Processing model: DFSK SUV 560 COMFORT 1.8L 2024
# Processing model: DFSK SUV 600 COMFORT 1.5T AT 2024
# Processing model: DFSK SUV 600 COMFORT 1.5T MT 2024
# Processing model: DFSK SUV 600 LUXURY 1.5T AT 2024
# Processing model: EXEED LX ADVANCED 1.5T AT 2024
# Processing model: EXEED LX UNLIMITED 1.5T AT 2024
# Processing model: EXEED LX UNLIMITED 1.5T AWD AT 2024
# Processing model: EXEED TXL UNLIMITED 2.0T AT 2024
# Processing model: EXEED TXL UNLIMITED 2.0T AWD AT 2024
# Processing model: FIAT FASTBACK AUDACE 1.0L AT 2024
# Processing model: FIAT FASTBACK DRIVE 1.0L AT 2024
# Processing model: FIAT FASTBACK IMPETUS 1.0L AT 2024
# Processing model: FIAT PULSE DRIVE 1.3L AT 2024
# Processing model: FIAT PULSE DRIVE 1.3L MT 2024
# Processing model: FIAT PULSE IMPETUS 1.0L AT 2024
# Processing model: FORD ESCAPE PLATINUM ECOBOOST 2.0L AWD AT 2024
# Processing model: FORD ESCAPE PLATINUM HEV 2.5L AWD AT 2024
# Processing model: FORD ESCAPE ST LINE FHEV 2.5L AT 2024
# Processing model: FORD TERRITORY TREND 1.5L 4X2 AT 2024
# Processing model: GAC EMKOO GDI GE 1.5T AT 2024
# Processing model: GAC EMKOO GDI GL 1.5T AT 2024
# Processing model: GAC EMZOOM GB 1.5T AT 2024
# Processing model: GAC EMZOOM GL 1.5T AT 2024
# Processing model: GAC EMZOOM GL R-STYLE 1.5T AT 2024
# Processing model: GAC GS3 POWER GB 1.5T AT 2024
# Processing model: GAC GS3 POWER GS 1.5T AT 2024
# Processing model: GAC GS3 POWER GB 1.5T MT 2024
# Processing model: GAC GS3 POWER GS 1.5T MT 2024
# Processing model: GAC GS4 POWER GB 1.5T AT 2024
# Processing model: GAC GS4 POWER GE 1.5T AT 2024
# Processing model: GAC GS4 POWER GL 1.5T AT 2024
# Processing model: GAC GS4 POWER GB 1.5T MT 2024
# Processing model: GAC GS8 GL 2.0T 2WD AT 2024
# Processing model: GAC GS8 GT 2.0T 2WD AT 2024
# Processing model: GAC GS8 GT 2.0T 4WD AT 2024
# Processing model: GAC GS8 GX 2.0T 4WD AT 2024
# Processing model: HAVAL H6 ACTIVE 2WD AT 2024
# Processing model: HAVAL H6 DELUXE 2WD AT 2024
# Processing model: HAVAL H6 DELUXE AWD AT 2024
# Processing model: HAVAL H6 ELITE 2WD AT 2024
# Processing model: HAVAL H6 GT DELUXE AWD AT 2024
# Processing model: HAVAL H6 GT ELITE 2WD AT 2024
# Processing model: HAVAL H6 HIBRIDA DELUXE 2WD AT 2024
# Processing model: HAVAL H6 HIDRIDA ELITE 2WD AT 2024
# Processing model: HAVAL JOLION ACTIVE MT 2024
# Processing model: HAVAL JOLION DELUXE AT 2024
# Processing model: HAVAL JOLION ELITE AT 2024
# Processing model: HAVAL JOLION ELITE MT 2024
# Processing model: HAVAL JOLION HIBRIDO DELUXE 2WD AT 2024
# Processing model: HAVAL JOLION HIBRIDO ELITE 2WD AT 2024
# Processing model: HYUNDAI CRETA GRAND SU2I VALUE 2.0 AT 2024
# Processing model: HYUNDAI CRETA GRAND SU2I PLUS 2.0 MT 2024
# Processing model: HYUNDAI CRETA SU2ID DESIGN 1.5 CVT 2024
# Processing model: HYUNDAI CRETA SU2ID PLUS 1.5 CVT 2024
# Processing model: HYUNDAI CRETA SU2ID PREMIUM 1.5 CVT 2024
# Processing model: HYUNDAI CRETA SU2ID GO 1.5 MT 2024
# Processing model: HYUNDAI CRETA SU2ID DESIGN 1.5 MT 2024
# Processing model: HYUNDAI CRETA SU2ID PLUS 1.5 MT 2024
# Processing model: HYUNDAI IONIQ 5 NE EV LIMITED AWD AT 2024
# Processing model: HYUNDAI IONIQ 5 NE EV LIMITED AT 2024
# Processing model: HYUNDAI IONIQ 5 NE EV PREMIUM AT 2024
# Processing model: HYUNDAI KONA OS EV PREMIUM AT 2024
# Processing model: HYUNDAI PALISADE LX2 PREMIUM FL 3.5 AWD AT 2024
# Processing model: HYUNDAI SANTA FE MX5 GDI DESIGN 2.5 AT 2024
# Processing model: HYUNDAI SANTA FE MX5 GDI PLUS 2.5 AT 2024
# Processing model: HYUNDAI SANTA FE MX5 GDI CALLIGRAPHY 2.5T AT 2024
# Processing model: HYUNDAI SANTA FE MX5 GDI LIMITED 2.5T AT 2024
# Processing model: HYUNDAI SANTA FE TM VALUE FL 2.5 AT 2024
# Processing model: HYUNDAI TUCSON NX4 LIMITED 1.6 4WD AT 2024
# Processing model: HYUNDAI TUCSON NX4 PLUS 1.6 AT 2024
# Processing model: HYUNDAI TUCSON NX4 HEV LIMITED 1.6 AT 2024
# Processing model: HYUNDAI TUCSON NX4 HEV VALUE 1.6 AT 2024
# Processing model: HYUNDAI TUCSON NX4 PLUS 2.0 4WD AT 2024
# Processing model: HYUNDAI TUCSON NX4 PLUS 2.0 AT 2024
# Processing model: HYUNDAI TUCSON NX4 VALUE 2.0 AT 2024
# Processing model: HYUNDAI TUCSON NX4 PLUS 2.0 MT 2024
# Processing model: HYUNDAI VENUE QX VALUE 1.6 AT 2024
# Processing model: HYUNDAI VENUE QX PLUS 1.6 MT 2024
# Processing model: HYUNDAI VENUE QX VALUE 1.6 MT 2024
# Processing model: JAC JS2 COMFORT MT 2024
# Processing model: JAC JS2 LUXURY AT 2024
# Processing model: JAC JS2 LUXURY MT 2024
# Processing model: JAC JS3 SE LUXURY 1.6 MT 2024
# Processing model: JAC JS3 XE ADVANCE 1.6 AT 2024
# Processing model: JAC JS3 XE ADVANCE 1.6 MT 2024
# Processing model: JAC JS3 XE LUXURY 1.6 AT 2024
# Processing model: JAC JS4 ADVANCE 1.5T AT 2024
# Processing model: JAC JS4 ADVANCE BICOLOR 1.5T AT 2024
# Processing model: JAC JS4 COMFORT 1.6 MT 2024
# Processing model: JAC JS4 COMFORT BICOLOR 1.6 MT 2024
# Processing model: JAC JS4 LUXURY 1.5T AT 2024
# Processing model: JAC JS4 LUXURY 1.5T MT 2024
# Processing model: JAC JS4 LUXURY BICOLOR 1.5T AT 2024
# Processing model: JAC JS4 LUXURY BICOLOR 1.5T MT 2024
# Processing model: JAC JS6 ADVANCE AT 2024
# Processing model: JAC JS6 COMFORT AT 2024
# Processing model: JAC JS6 LUXURY AT 2024
# Processing model: JAC JS8 ADVANCE XE AT 2024
# Processing model: JAC JS8 COMFORT CE MT 2024
# Processing model: JAC JS8 LUXURY SE AT 2024
# Processing model: JAC JS8 LUXURY SE MT 2024
# Processing model: JEEP COMMANDER LIMITED 1.3 4X2 AT 2024
# Processing model: JEEP COMMANDER LIMITED 2.0 4X4 AT 2024
# Processing model: JEEP COMMANDER LIMITED G 2.0 4X4 AT 2024
# Processing model: JEEP COMMANDER OVERLAND 1.3 4X2 AT 2024
# Processing model: JEEP COMMANDER OVERLAND G 2.0 4X4 AT 2024
# Processing model: JEEP COMPASS LIMITED 4X2 AT 2024
# Processing model: JEEP COMPASS LONGITUDE 4X2 AT 2024
# Processing model: JEEP COMPASS SPORT 4X2 AT 2024
# Processing model: JEEP GRAND CHEROKEE L SUMMIT 3ROW 3.6L AT 2024
# Processing model: JEEP RENEGADE LONGITUDE 1.3 AT 2024
# Processing model: JEEP RENEGADE LONGITUDE X 1.3 AT 2024
# Processing model: JEEP RENEGADE SPORT 1.3 AT 2024
# Processing model: JEEP WRANGLER UNLIMITED RUBICON 3.6L AT 2024
# Processing model: JETOUR DASHING TURBO LUX 1.5L MT 2024
# Processing model: JETOUR DASHING TURBO LUX 1.5L AT 2024
# Processing model: JETOUR DASHING TURBO GDI LIMITED 1.6L AT 2024
# Processing model: JETOUR X70 LUX 1.5T AT 2024
# Processing model: JETOUR X70 LUX 1.5T MT 2024
# Processing model: JETOUR X70 STD 1.5T AT 2024
# Processing model: JETOUR X70 STD 1.5T MT 2024
# Processing model: JETOUR X70 PLUS 1.5T AT 2024
# Processing model: JETOUR X70 PLUS 1.6T AT 2024
# Processing model: JETOUR X90 PLUS GDI 2.0T AT 2024
# Processing model: KAIYI KYX3 LUX MT 2024
# Processing model: KAIYI KYX3 STD MT 2024
# Processing model: KAIYI KYX3 LUX AT 2024
# Processing model: KAIYI KYX3 PRO 1.5T AT 2024
# Processing model: KIA CARENS EX TURBO-GDI 7P 1.4L 7DCT 2024
# Processing model: KIA CARENS EX TURBO-GDI FULL 7P 1.4L 7DCT 2024
# Processing model: KIA CARENS LX 7P 1.5L 6MT 2024
# Processing model: KIA NIRO EV EX 64.8KWH FULL 2WD 2024
# Skipping KIA NIRO EV EX 64.8KWH FULL 2WD 2024 due to invalid Version URL
# Processing model: KIA NIRO EV LX 64.8KWH 2WD 2024
# Skipping KIA NIRO EV LX 64.8KWH 2WD 2024 due to invalid Version URL
# Processing model: KIA NIRO EV6 GT-LINE 77.4KWH AWD 2024
# Processing model: KIA NIRO EV9 GT-LINE 99.8KWH 6P1 AWD 2024
# Processing model: KIA NIRO EV9 GT-LINE 99.8KWH 6P2 AWD 2024
# Processing model: KIA NIRO EV9 GT-LINE 99.8KWH 6P3 AWD 2024
# Processing model: KIA NIRO EV9 GT-LINE 99.8KWH 7P AWD 2024
# Processing model: KIA SELTOS EX TURBO 1.4L 7DCT 2024
# Processing model: KIA SELTOS EX TURBO FULL 1.4L 7DCT 2024
# Processing model: KIA SELTOS EX 1.5L 6MT 2024
# Processing model: KIA SELTOS EX IVT 1.5L 2024
# Processing model: KIA SONET EX AC RI 1.5L 6MT 2024
# Processing model: KIA SONET EX RI FULL 1.5L 6MT 2024
# Processing model: KIA SONET EX IVT ACC PLUS 1.5L 2024
# Processing model: KIA SONET EX IVT FULL 1.5L 2024
# Processing model: KIA SONET EX IVT IR FULL 1.5L 2024
# Processing model: KIA SORENTO EX DSL 2.2L 2WD 8DCT 2024
# Processing model: KIA SORENTO EX GSL 2.5L 2WD 6AT 2024
# Processing model: KIA SORENTO EX GSL FULL 2.5L 2WD 6AT 2024
# Processing model: KIA SORENTO EX GSL FULL 2.5L AWD 6AT 2024
# Processing model: KIA SPORTAGE EX TURBO-GDI GSL 1.6L AWD 7DCT 2024
# Processing model: KIA SPORTAGE EX GSL 2.0L 6AT 2024
# Processing model: KIA SPORTAGE EX GSL BS 2.0L 6AT 2024
# Processing model: KIA SPORTAGE EX GSL 2.0L 6MT 2024
# Processing model: KIA SPORTAGE EX DSL 2.0L AWD 8AT 2024
# Processing model: KIA SPORTAGE EX DSL BS 2.0L 8AT 2024
# Processing model: KIA SPROTAGE EX GSL 2.0L AWD 6AT 2024
# Skipping KIA SPROTAGE EX GSL 2.0L AWD 6AT 2024 due to invalid Version URL
# Processing model: KIA SPROTAGE EX DSL 2.0L 8AT 2024
# Skipping KIA SPROTAGE EX DSL 2.0L 8AT 2024 due to invalid Version URL
# Processing model: MAHINDRA XUV300 COMFORT MT 2024
# Skipping MAHINDRA XUV300 COMFORT MT 2024 due to invalid Version URL
# Processing model: MAHINDRA XUV300 ELITE MT 2024
# Skipping MAHINDRA XUV300 ELITE MT 2024 due to invalid Version URL
# Processing model: MAHINDRA XUV300 LUXURY MT 2024
# Skipping MAHINDRA XUV300 LUXURY MT 2024 due to invalid Version URL
# Processing model: MAXUS D60 ELITE 4X2 AT 2024
# Processing model: MAXUS D60 LUXURY 4X2 AT 2024
# Processing model: MAXUS D90 ELITE 4X4 AT 2024
# Processing model: MAXUS D90 FLAGSHIP 4X4 AT 2024
# Processing model: MAXUS D90 LUXURY 4X4 AT 2024
# Processing model: MAXUS EUNIQ 6 AT 2024
# Processing model: MAXUS G90 ELITE AT 2024
# Skipping MAXUS G90 ELITE AT 2024 due to invalid Version URL
# Processing model: MAXUS G90 LUXURY AT 2024
# Skipping MAXUS G90 LUXURY AT 2024 due to invalid Version URL
# Processing model: MG 3 STD 1.5 AT 2024
# Processing model: MG HS COM 1.5T 2024
# Processing model: MG HS DLX 1.5T DCT 2024
# Processing model: MG HS TROPHY 1.5T DCT 2024
# Processing model: MG MARVEL R DLX AT 2024
# Processing model: MG MG ZS COM 1.5L AT 2024
# Processing model: MG MG ZS STD 1.5L AT 2024
# Processing model: MG ONE COM 1.5T CVT 2024
# Processing model: MG ONE DLX 1.5T CVT 2024
# Processing model: MG RX5 COM 1.5T 2024
# Processing model: MG RX5 COM 1.5T DCT 2024
# Processing model: MG RX5 DLX 1.5T DCT 2024
# Processing model: MG ZS COM 1.5L 2024
# Processing model: MG ZS STD 1.5L 2024
# Processing model: MG ZS EV DLX AT 2024
# Processing model: MG ZX 6 TROPHY 1.3T AT 2024
# Processing model: MG ZX COM 1.5L 2024
# Processing model: MG ZX DLX 1.5L CVT 2024
# Processing model: MG ZX DLX 1.5L 2024
# Processing model: MITSUBISHI ASX GL 1.6L 4X2 MT 2024
# Processing model: MITSUBISHI ASX GLS 1.6L 4X2 MT 2024
# Processing model: MITSUBISHI ASX GLS 2.0L 4X2 AT 2024
# Processing model: MITSUBISHI ECLIPSE CROSS RS 1.5 4X2 AT 2024
# Processing model: MITSUBISHI ECLIPSE CROSS RX 1.5 4X2 AT 2024
# Processing model: MITSUBISHI MONTERO SPORT 3.0 2WD AT 2024
# Processing model: MITSUBISHI MONTERO SPORT 3.0 4WD AT 2024
# Processing model: MITSUBISHI MONTERO SPORT LIMITED 3.0 4WD AT 2024
# Processing model: MITSUBISHI OUTLANDER GL 4X2 AT 2024
# Processing model: MITSUBISHI OUTLANDER GLS 4X4 AT 2024
# Processing model: MITSUBISHI OUTLANDER GLS LIMITED 4X4 AT 2024
# Processing model: MITSUBISHI OUTLANDER GLX 4X2 AT 2024
# Processing model: MITSUBISHI XPANDER CROSS AT 2024
# Processing model: MITSUBISHI XPANDER GL MT 2024
# Processing model: MITSUBISHI XPANDER GLX AT 2024
# Processing model: NISSAN KICKS ADVANCE CVT 2024
# Processing model: NISSAN KICKS ADVANCE MT 2024
# Processing model: NISSAN KICKS EXCLUSIVE CVT 2024
# Processing model: NISSAN KICKS SENSE MT 2024
# Processing model: NISSAN PATHFINDER ADVANCE 2WD AT 2024
# Processing model: NISSAN PATHFINDER ADVANCE 4WD AT 2024
# Processing model: NISSAN PATHFINDER EXCLUSIVE 4WD AT 2024
# Processing model: NISSAN PATHFINDER SENSE 2WD AT 2024
# Processing model: NISSAN QASHQAI ADVANCE CVT 2024
# Processing model: NISSAN QASHQAI ADVANCE PLUS CVT 2024
# Processing model: NISSAN QASHQAI ADVANCE MT 2024
# Processing model: NISSAN QASHQAI EXCLUSIVE 4WD CVT 2024
# Processing model: NISSAN QASHQAI SENSE MT 2024
# Processing model: NISSAN X-TRAIL ADVANCE 3 ROW E-POWER AWD 2024
# Processing model: NISSAN X-TRAIL ADVANCE 3ROW CVT 2024
# Processing model: NISSAN X-TRAIL EXCLUSIVE 3 ROW E-POWER AWD 2024
# Processing model: NISSAN X-TRAIL EXCLUSIVE 3ROW - AWD CVT 2024
# Processing model: NISSAN X-TRAIL SEMSE 3ROW CVT 2024
# Processing model: NISSAN X-TRAIL SENSE 2ROW CVT 2024
# Processing model: OPEL CROSSLAND EDITION AT6 E6.4 1.2T 2024
# Processing model: OPEL CROSSLAND EDITION MT6 1.2T 2024
# Processing model: OPEL GRANDLAND GRANDLAND GS AT8 1.2T 2024
# Processing model: OPEL GRANDLAND GRANDLAND GS MT6 1.2T 2024
# Processing model: OPEL GRANDLAND GRANDLAND GS 1.5TD AT8 2024
# Processing model: OPEL GRANDLAND GRANDLAND ULTIMATE AT8 1.2T 2024
# Processing model: OPEL MOKKA ELEGANCE 130HP MT6 E6.4 1.2 2024
# Processing model: OPEL MOKKA ELEGANCE 130HP AT8 1.2T 2024
# Processing model: OPEL MOKKA GS LINE 130HP AT8 1.2T 2024
# Processing model: OPEL MOKKA 1.5TD ELEGANCE 110HP MT6 2024
# Processing model: PEUGEOT ACTIVE PACK PURETECH 130HP 1.2 2024
# Skipping PEUGEOT ACTIVE PACK PURETECH 130HP 1.2 2024 due to invalid Version URL
# Processing model: PEUGEOT ALTURE PACK PURETECH 130HP 1.2 2024
# Skipping PEUGEOT ALTURE PACK PURETECH 130HP 1.2 2024 due to invalid Version URL
# Processing model: PEUGEOT ALTURE PACK BLUEHDI 130HP 1.5 EAT8 2024
# Skipping PEUGEOT ALTURE PACK BLUEHDI 130HP 1.5 EAT8 2024 due to invalid Version URL
# Processing model: PEUGEOT ELÉCTRICO 136HP 2024
# Skipping PEUGEOT ELÉCTRICO 136HP 2024 due to invalid Version URL
# Processing model: PEUGEOT ALTURE BLUEHDI 130HP 1.5 EAT8 2024
# Skipping PEUGEOT ALTURE BLUEHDI 130HP 1.5 EAT8 2024 due to invalid Version URL
# Processing model: PEUGEOT ALTURE PACK THP 1650HP 1.6 EAT6 2024
# Skipping PEUGEOT ALTURE PACK THP 1650HP 1.6 EAT6 2024 due to invalid Version URL
# Processing model: PEUGEOT GT BLUEHDI 130HP 1.5 EAT8 2024
# Skipping PEUGEOT GT BLUEHDI 130HP 1.5 EAT8 2024 due to invalid Version URL
# Processing model: PEUGEOT GT PURETECH 180HP 1.6 EAT8 2024
# Skipping PEUGEOT GT PURETECH 180HP 1.6 EAT8 2024 due to invalid Version URL
# Processing model: PEUGEOT HYBRID4 300 EEAT8 2024
# Processing model: PEUGEOT ALTURETHP 165HP 1.6 EAT6 2024
# Skipping PEUGEOT ALTURETHP 165HP 1.6 EAT6 2024 due to invalid Version URL
# Processing model: PEUGEOT GT BLACK PACK BLUEHDI 130 EAT8 2024
# Skipping PEUGEOT GT BLACK PACK BLUEHDI 130 EAT8 2024 due to invalid Version URL
# Processing model: PEUGEOT GT BLACK PACK PURETECH 180 EAT8 2024
# Skipping PEUGEOT GT BLACK PACK PURETECH 180 EAT8 2024 due to invalid Version URL
# Processing model: PEUGEOT RIFTER ALURE BLUEHDI 100 MT 2024
# Processing model: PEUGEOT RIFTER ALURE BLUEHDI 130 AT 2024
# Processing model: PEUGEOT RIFTER ALURE PURETECH 130 AT 2024
# Processing model: SSANGYONG KORANDO GLX 6AB 1.5T 2WD AT 2024
# Processing model: SSANGYONG KORANDO GLX 6AB 1.5T 2WD MT 2024
# Processing model: SSANGYONG KORANDO GLX 1.6TD 6AB 2WD AT 2024
# Processing model: SSANGYONG KORANDO GLX 1.6TD 6AB 2WD MT 2024
# Processing model: SSANGYONG KORANDO LIMITED 6AB 1.5T 2WD AT 2024
# Processing model: SSANGYONG KORANDO LX 1.5T 2WD MT 2024
# Processing model: SSANGYONG REXTON GLX 2.2TD 6AB 2WD AT 2024
# Processing model: SSANGYONG REXTON GLX 2.2TD 6AB 2WD MT 2024
# Processing model: SSANGYONG REXTON GLX 2.2TD 6AB 4WD AT 2024
# Processing model: SSANGYONG REXTON LX 6AB 2.0T 4WD AT 2024
# Processing model: SSANGYONG REXTON LX 6AB 2.0T 2WD MT 2024
# Processing model: SSANGYONG REXTON LX 2.2TD 2AB 2WD AT 2024
# Processing model: SSANGYONG REXTON LX 2.2TD 2AB 2WD MT 2024
# Processing model: SSANGYONG TIVOLI GLX 1.6 2WD MT 2024
# Processing model: SSANGYONG TIVOLI LIMITED 6 AB 1.6 2WD AT 2024
# Processing model: SSANGYONG TIVOLI LX 1.6 2WD MT 2024
# Processing model: SSANGYONG TORRES GLX 1.5T 2WD AT 2024
# Processing model: SSANGYONG TORRES GLX 1.5T 2WD MT 2024
# Processing model: SSANGYONG TORRES GLX 1.5T 4WD AT 2024
# Processing model: SSANGYONG TORRES LIMITED PLUS BITONO 1.5T 4WD AT 2024
# Processing model: SSANGYONG TORRES LIMITED PLUS SUNROOF 1.5T 4WD AT 2024
# Processing model: SUBARU CROSSTREK 2.0I AWD AT 2024
# Processing model: SUBARU CROSSTREK 2.0I DYNAMIC EYESIGH AWD AT 2024
# Processing model: SUBARU CROSSTREK 2.0I TOURING EYESIGH AWD AT 2024
# Processing model: TOYOTA 4RUNNER LIMITED 4X4 AT 2024
# Processing model: TOYOTA 4RUNNER SR5 4X2 AT 2024
# Processing model: TOYOTA 4RUNNER SR5 4X4 AT 2024
# Processing model: TOYOTA COROLLA CROSS HEV SEG HEV 1.8 AT 2024
# Processing model: TOYOTA COROLLA CROSS HEV XEI HEV 1.8 AT 2024
# Processing model: TOYOTA FORTUNER SR5 2.7L 4X2 AT 2024
# Processing model: TOYOTA FORTUNER SR5 TDI 2.8 4X4 AT 2024
# Processing model: TOYOTA FORTUNER SR5 TDI 2.8 4X4 MT 2024
# Processing model: TOYOTA FORTUNER SRX TDI 2.8 4X4 AT 2024
# Processing model: TOYOTA RAIZE GAS E 1.2 MT 2024
# Processing model: TOYOTA RAIZE GAS 1.2 MT 2024
# Processing model: TOYOTA RAV4 LE 2.0 4X2 AT 2024
# Processing model: TOYOTA RAV4 LE 2.0 4X2 MT 2024
# Processing model: TOYOTA RAV4 LE 2.0 4X4 MT 2024
# Processing model: TOYOTA RAV4 LIMITED HV 2.5 4X4 AT 2024
# Processing model: TOYOTA RAV4 XLE 2.0 4X2 AT 2024
# Processing model: TOYOTA RAV4 XLE HV 2.5 4X2 AT 2024
# Processing model: TOYOTA RAV4 XSE HV 2.5 4X2 AT 2024
# Processing model: TOYOTA YARIS CROSS XI 1.5 AT 2024
# Data scraping completed. Results saved to 'scraped_data.csv'.
