# %% [markdown]
# ### Obtenemos los Productos

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('raw_data/Vehiculos/MaestraProd_cm_2239-8-lr23.csv', sep=';')

# Get unique values from the "TIPO PRODUCTO" column
unique_tipos = df['TIPO PRODUCTO'].unique()

# Print the unique values
print("Unique TIPO PRODUCTO values:")
for tipo in unique_tipos:
    print(tipo)
# Out:
# Unique TIPO PRODUCTO values:
# CAMIONETA
# SEDÁN
# SUV
# MINIBUS
# FURGÓN
# CARGO
# EXCAVADORA
# MOTONIVELADORA
# RETROEXCAVADORA
# TOLVA
# CARGADOR
# BUS PESADO

# %% [markdown]
# ### Para las categorías que nos importan obtenemos la marca y modelo de manera única

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('raw_data/Vehiculos/MaestraProd_cm_2239-8-lr23.csv', sep=';')

# List of Tipo Producto we're interested in
tipos_producto = ['CAMIONETA', 'SEDÁN', 'SUV', 'MINIBUS', 'FURGÓN']

# Create an empty list to store all results
all_results = []

# Iterate through each Tipo Producto
for tipo in tipos_producto:
    print(f"\nTipo Producto: {tipo}")
    
    # Filter the dataframe for the current Tipo Producto
    df_filtered = df[df['TIPO PRODUCTO'] == tipo]
    
    # Get unique combinations of Marca and Modelo
    unique_combinations = df_filtered[['MARCA', 'MODELO']].drop_duplicates()
    
    # Sort the combinations by Marca and Modelo
    unique_combinations = unique_combinations.sort_values(['MARCA', 'MODELO'])
    
    # Add Tipo Producto column
    unique_combinations['TIPO PRODUCTO'] = tipo
    
    # Append to all_results
    all_results.append(unique_combinations)

# Combine all results into a single DataFrame
result_df = pd.concat(all_results, ignore_index=True)

# Save the result to a CSV file
output_file = 'unique_marca_modelo_by_tipo_producto.csv'
result_df.to_csv(output_file, index=False)
print(f"\nResults saved to {output_file}")
# Out:
# Tipo Producto: CAMIONETA
# Marca: CHANGAN, Modelo: HUNTER COMFORT 2.0T 4X2 MT 2024
# Marca: CHANGAN, Modelo: HUNTER COMFORT 2.0T 4X4 MT 2024
# Marca: CHANGAN, Modelo: HUNTER ELITE SPORT 2.0T 4X4 MT 2024
# Marca: CHANGAN, Modelo: HUNTER LUXURY 2.0T 4X2 MT 2024
# Marca: CHANGAN, Modelo: MD 301 AC ESP MT 2024
# Marca: CHANGAN, Modelo: MD201 MT 2024
# Marca: CHANGAN, Modelo: MD201 XL 1.5L MT 2024
# Marca: CHANGAN, Modelo: MS 201 MT 2024
# Marca: CHANGAN, Modelo: MS 301 PLUS AC ESP 2024
# Marca: CHEVROLET, Modelo: COLORADO HIGH COUNTRY 4X4 AT 2024
# Marca: CHEVROLET, Modelo: COLORADO LS 4X2 MT 2024
# Marca: CHEVROLET, Modelo: COLORADO LT 4X4 AT 2024
# Marca: CHEVROLET, Modelo: COLORADO LT 4X4 MT 2024
# Marca: CHEVROLET, Modelo: COLORADO LTZ 4X4 AT 2024
# Marca: CHEVROLET, Modelo: COLORADO Z71 4X4 AT 2024
# Marca: CHEVROLET, Modelo: MONTANA 1.2 T LT MT 2024
# Marca: CHEVROLET, Modelo: MONTANA 1.2 T LTZ AT 2024
# Marca: JMC, Modelo: GRAND AVENUE 4X2 AT 2024
# Marca: JMC, Modelo: GRAND AVENUE 4X2 MT 2024
# Marca: JMC, Modelo: GRAND AVENUE 4X4 AT 2024
# Marca: JMC, Modelo: GRAND AVENUE 4X4 MT 2024
# Marca: JMC, Modelo: VIGUS EV AT 2024
# Marca: JMC, Modelo: VIGUS NEW PLUS 4X2 MT 2024
# Marca: JMC, Modelo: VIGUS NEW PLUS 4X4 MT 2024
# Marca: JMC, Modelo: VIGUS NEW WORK 4X2 MT 2024
# Marca: JMC, Modelo: VIGUS NEW WORK 4X4 MT 2024
# Marca: JMC, Modelo: VIGUS PRO 4X2 AT 2024
# Marca: JMC, Modelo: VIGUS PRO 4X4 AT 2024
# Marca: KARRY, Modelo: Q52 CD 1.6L MT 2024
# Marca: KIA, Modelo: FRONTIER C/C LX 2.5L AV AB MT 2024
# Marca: KIA, Modelo: FRONTIER C/C LX 2.5L AV MT 2024
# Marca: KIA, Modelo: FRONTIER D/C LX 2.5L AV AB MT 2024
# Marca: KIA, Modelo: FRONTIER P/UP LX 2.5L AV AB MT 2024
# Marca: MAXUS, Modelo: T60 ANCAP E6 4X4 MT 2024
# Marca: MAXUS, Modelo: T60 DX 4X2 MT 2024
# Marca: MAXUS, Modelo: T60 DX E6 4X2 MT 2024
# Marca: MAXUS, Modelo: T60 DX E6 4X4 MT 2024
# Marca: MAXUS, Modelo: T60 E6 GL 4X2 AT 2024
# Marca: MAXUS, Modelo: T60 E6 GL 4X2 MT 2024
# Marca: MAXUS, Modelo: T60 E6 GL 4X4 MT 2024
# Marca: MAXUS, Modelo: T60 E6 GLX 4X4 AT 2024
# Marca: MAXUS, Modelo: T60 SC DX E6 4X2 MT 2024
# Marca: MAXUS, Modelo: T60 SC DX E6 4X4 MT 2024
# Marca: MAXUS, Modelo: T90 E6 4X4 AT 2024
# Marca: MAXUS, Modelo: T90 E6 4X4 MT 2024
# Marca: MAXUS, Modelo: T90 EV 4X2 AT 2024
# Marca: MAZDA, Modelo: BT-50 CORE 4X4 AT 2024
# Marca: MAZDA, Modelo: BT-50 CORE 4X4 MT 2024
# Marca: MAZDA, Modelo: BT-50 HIGH 4X4 AT 2024
# Marca: MAZDA, Modelo: BT-50 HIGH PLUS 4X4 AT 2024
# Marca: MITSUBISHI, Modelo: L200 D/C TD DAKAR CRS 4X4 MT 2024
# Marca: MITSUBISHI, Modelo: L200 D/C TD KATANA CR 4X2 MT 2024
# Marca: MITSUBISHI, Modelo: L200 D/C TD KATANA CRT 4X4 MT 2024
# Marca: MITSUBISHI, Modelo: L200 D/C TD WORK CR 4X2 MT 2024
# Marca: NISSAN, Modelo: NAVARA DC P4X 2024
# Marca: NISSAN, Modelo: NAVARA DC PLATINUM 2.3D 4X4 AT 2024
# Marca: NISSAN, Modelo: NAVARA DC PLATINUM 2.3D 4X4 MT 2024
# Marca: NISSAN, Modelo: NAVARA DC SE 2.3D 4X2 MT 2024
# Marca: NISSAN, Modelo: NAVARA DC SE 2.3D 4X4 MT 2024
# Marca: NISSAN, Modelo: NAVARA DC XE 2.3D 4X2 MT 2024
# Marca: NISSAN, Modelo: NAVARA DC XE 2.3D 4X4 AT 2024
# Marca: NISSAN, Modelo: NAVARA DC XE 2.3D 4X4 MT 2024
# Marca: PEUGEOT, Modelo: LANDTREK ACTION4 BLUEHDI 180 4X4 AT 2024
# Marca: PEUGEOT, Modelo: LANDTREK ACTIVE BLUEHDI 180 4X2 MT 2024
# Marca: PEUGEOT, Modelo: LANDTREK ACTIVE BLUEHDI 180 4X4 AT 2024
# Marca: PEUGEOT, Modelo: LANDTREK ACTIVE BLUEHDI 180 4X4 MT 2024
# Marca: RAM, Modelo: 1000 BIGHORN LX 1.8 AT 2024
# Marca: RAM, Modelo: 1000 BIGHORN NIGHT EDITION 1.8 AT 2024
# Marca: RAM, Modelo: 1000 REBEL 2.0 4X4 AT 2024
# Marca: RAM, Modelo: 1500 CREW CAB BIGHORN 3.6L AT 2024
# Marca: RAM, Modelo: 1500 CREW CAB LIMITED 5.7L AT 2024
# Marca: RAM, Modelo: 1500 CREW CAB REBEL 5.7L AT 2024
# Marca: RAM, Modelo: 700 BIGHORN CD 1.3 CVT AT 2024
# Marca: RAM, Modelo: 700 BIGHORN CD 1.3L MT 2024
# Marca: RAM, Modelo: 700 LARAMIE CD 1.3 CVT AT 2024
# Marca: RAM, Modelo: 700 LARAMIE CD 1.3L MT 2024
# Marca: RAM, Modelo: 700 LONGHORN CD 1.3 CVT AT 2024
# Marca: RAM, Modelo: 700 SLT CS 1.3L MT 2024
# Marca: RAM, Modelo: 700 SLT DC 1.3L MT 2024
# Marca: RAM, Modelo: RAMPAGE BIGHORN 2.0L AT 2024
# Marca: RAM, Modelo: RAMPAGE LARAMIE 2.0L AT 2024
# Marca: RAM, Modelo: RAMPAGE R/T 2.0L AT 2024
# Marca: RENAULT, Modelo: OROCH INTENS 1.3 TURBO 4X2 AT 2024
# Marca: RENAULT, Modelo: OROCH INTENS 1.3 TURBO 4X2 KIT AT 2024
# Marca: RENAULT, Modelo: OROCH INTENS 1.3 TURBO 4X4 KITMT 2024
# Marca: RENAULT, Modelo: OROCH INTENS 1.3 TURBO 4X4 MT 2024
# Marca: RENAULT, Modelo: OROCH ZEN 1.6L 4X2 MT 2024
# Marca: SSANGYONG, Modelo: MUSSO GLX 2.2TD 4X4 MT 2024
# Marca: SSANGYONG, Modelo: MUSSO GRAND GLX 2.2TD 4X2 AT 2024
# Marca: SSANGYONG, Modelo: MUSSO GRAND GLX 2.2TD 4X2 MT 2024
# Marca: SSANGYONG, Modelo: MUSSO GRAND GLX 2.2TD 4X4 MT 2024
# Marca: SSANGYONG, Modelo: MUSSO GRAND LIMITED 2.2TD 4X4 AT 2024
# Marca: SSANGYONG, Modelo: MUSSO GRAND LIMITED PLUS 2.2TD 4X4 AT 2024
# Marca: SSANGYONG, Modelo: MUSSO GRAND LX 2.2TD 4X2 MT 2024
# Marca: SSANGYONG, Modelo: MUSSO GRAND LX 2.2TD 4X4 MT 2024
# Marca: SSANGYONG, Modelo: MUSSO LIMITED 2.2TD 4X4 AT 2024
# Marca: SSANGYONG, Modelo: MUSSO LIMITED PLUS 2.2TD 4X4 AT 2024
# Marca: TOYOTA, Modelo: HILUX DX 2.4 4X2 MT 2024
# Marca: TOYOTA, Modelo: HILUX DX 2.4 4X4 MT 2024
# Marca: TOYOTA, Modelo: HILUX DX 2.8 4X4 MT 2024
# Marca: TOYOTA, Modelo: HILUX DX CS 2.8 4X4 MT 2024
# Marca: TOYOTA, Modelo: HILUX DX DC 2.4 4X2 MT 2024
# Marca: TOYOTA, Modelo: HILUX DX DC 2.4 4X4 MT 2024
# Marca: TOYOTA, Modelo: HILUX SR 2.4 4X2 MT 2024
# Marca: TOYOTA, Modelo: HILUX SR 2.4 4X4 MT 2024
# Marca: TOYOTA, Modelo: HILUX SR 2.7 4X2 MT 2024
# Marca: TOYOTA, Modelo: HILUX SR 2.8 4X4 MT 2024
# Marca: TOYOTA, Modelo: HILUX SR DC 2.4 4X2 MT 2024
# Marca: TOYOTA, Modelo: HILUX SR DC 2.4 4X4 MT 2024
# Marca: TOYOTA, Modelo: HILUX SRV 2.8 4X4 AT 2024
# Marca: ZNA, Modelo: R6 AT 2024
# Total unique combinations for CAMIONETA: 152
#
# Tipo Producto: SEDÁN
# Marca: BAIC, Modelo: EU5 EV 2024
# Marca: BYD, Modelo: HAN EV 2024
# Marca: BYD, Modelo: QIN PLUS DM 2024
# Marca: BYD, Modelo: SEAL EV 2024
# Marca: CHANGAN, Modelo: ALSVIN COMFORT 2024
# Marca: CHANGAN, Modelo: ALSVIN ELITE AT 2024
# Marca: CHANGAN, Modelo: ALSVIN LUXURY 2024
# Marca: CHEVROLET, Modelo: ONIX 1.0 LT R 2024
# Marca: CHEVROLET, Modelo: ONIX 1.0 LTZ P2 2024
# Marca: CHEVROLET, Modelo: ONIX 1.0 PREMIER R 2024
# Marca: CHEVROLET, Modelo: ONIX 1.2 LS P 2024
# Marca: CHEVROLET, Modelo: SAIL NB 1.5L LT 2024
# Marca: CHEVROLET, Modelo: SAIL NB 1.5L LTZ 2024
# Marca: CHEVROLET, Modelo: SAIL NB 1.5L LTZ CVT 2024
# Marca: CITROEN, Modelo: 1.5 HDI 100 BVM6 C-ELYSEE FEEL PACK 2024
# Marca: CITROEN, Modelo: C4 1.5 BLUEHDI 130 S&S EAT8 FEEL PACK 2024
# Marca: CITROEN, Modelo: C4 1.5 BLUEHDI 130 S&S EAT8 SHINE 2024
# Marca: HYUNDAI, Modelo: ACCENT BN7I 1.5 DESIGN 2024
# Marca: HYUNDAI, Modelo: ACCENT BN7I 1.5 PLUS 2024
# Marca: HYUNDAI, Modelo: GRAND I10 AI3 1.2 DESIGN FL 2024
# Marca: HYUNDAI, Modelo: GRAND I10 AI3 1.2 PLUS FL 2024
# Marca: KIA, Modelo: EV6 EV GT-LINE 77.4KWH AWD 2024
# Marca: KIA, Modelo: SOLUTO EX 1.4L 5MT G SRF FULL 2024
# Marca: KIA, Modelo: SOLUTO LX 1.4L 5MT G LL 2024
# Marca: MG, Modelo: 3 AT COM 2024
# Marca: MG, Modelo: 5 1.5L CVT COM 2024
# Marca: CHANGAN, Modelo: CS55 1.5L PLUS ELITE AT 2024
# Marca: CHANGAN, Modelo: CS55 1.5L PLUS LUXURY AT 2024
# Marca: CHERY, Modelo: TIGGO 2 1.0L PRO GLX CVT AT 2024
# Marca: CHERY, Modelo: TIGGO 2 1.0L PRO GLX MT 2024
# Marca: CHERY, Modelo: TIGGO 2 1.5L GLS CVT AT 2024
# Marca: CHERY, Modelo: TIGGO 2 1.5L PRO GLS CVT AT 2024
# Marca: CHERY, Modelo: TIGGO 2 1.5L PRO GLS MT 2024
# Marca: CHERY, Modelo: TIGGO 3 1.5L PRO GLS CVT AT 2024
# Marca: CHERY, Modelo: TIGGO 3 1.5L PRO GLX CVT AT 2024
# Marca: CHERY, Modelo: TIGGO 3 1.5L PRO GLX MT 2024
# Marca: CHERY, Modelo: TIGGO 7 1.5L PRO GLS CVT AT 2024
# Marca: CHERY, Modelo: TIGGO 7 1.5L PRO GLX CVT AT 2024
# Marca: CHERY, Modelo: TIGGO 8 1.5L GLS MT 2024
# Marca: CHERY, Modelo: TIGGO 8 1.5L GLX DCT AT 2024
# Marca: CHERY, Modelo: TIGGO 8 1.6L PRO GLX DCT AT 2024
# Marca: CHERY, Modelo: TIGGO 8 1.6L PRO MAX GLX DCT AT 2024
# Marca: CHERY, Modelo: TIGGO 8 2.0L PRO MAX GLX AWD AT 2024
# Marca: CHEVROLET, Modelo: BLAZER 3.6L RS AWD AT 2024
# Marca: CHEVROLET, Modelo: BOLT EUV AT 2024
# Marca: CHEVROLET, Modelo: CAPTIVA 1.5L LTZ CVT P AT 2024
# Marca: CHEVROLET, Modelo: CAPTIVA 1.5L LTZ P MT 2024
# Marca: CHEVROLET, Modelo: CAPTIVA 1.5L PREMIER CVT P AT 2024
# Marca: CHEVROLET, Modelo: CAPTIVA 1.5L PREMIER P MT 2024
# Marca: CHEVROLET, Modelo: GROOVE 1.5L LTZ R MT 2024
# Marca: CHEVROLET, Modelo: GROOVE 1.5L PREMIER R MT 2024
# Marca: CHEVROLET, Modelo: SPIN 1.8L ACTIV 7P AT 2024
# Marca: CHEVROLET, Modelo: SPIN 1.8L PREMIER 7P MT 2024
# Marca: CHEVROLET, Modelo: SUBURBAN Z71 5.3L 4WD P AT 2024
# Marca: CHEVROLET, Modelo: TAHOE Z71 5.3L AT 4WD P AT 2024
# Marca: CHEVROLET, Modelo: TRACKER 1.2L LS R MT 2024
# Marca: CHEVROLET, Modelo: TRACKER 1.2L LTZ P MT 2024
# Marca: CHEVROLET, Modelo: TRACKER 1.2L LTZ R AT 2024
# Marca: CHEVROLET, Modelo: TRACKER 1.2L PREMIER P3 AT 2024
# Marca: CHEVROLET, Modelo: TRACKER 1.2L PREMIER P4 AT 2024
# Marca: CHEVROLET, Modelo: TRACKER 1.2L RS R AT 2024
# Marca: CHEVROLET, Modelo: TRAVERSE 3.6L LT AWD AT 2024
# Marca: CHEVROLET, Modelo: TRAVERSE 3.6L PREMIER AWD AT 2024
# Marca: CHEVROLET, Modelo: TRAVERSE 3.6L RS AWD AT 2024
# Marca: CITROEN, Modelo: C5 AIRCROSS 1.5L BLUEHDI 130 S&S FEEL AT 2024
# Marca: CITROEN, Modelo: C5 AIRCROSS 1.5L BLUEHDI 130 S&S FEEL PACK AT 2024
# Marca: CITROEN, Modelo: C5 AIRCROSS 1.5L BLUEHDI 130 S&S SHINE AT 2024
# Marca: CITROEN, Modelo: C5 AIRCROSS HYBRID 225 SHINE AT 2024
# Marca: DFSK, Modelo: SUV 500 1.5 COMFORT 2024
# Marca: DFSK, Modelo: SUV 500 1.5 LUXURY 2024
# Marca: DFSK, Modelo: SUV 500 1.5 LUXURY CVT 2024
# Marca: DFSK, Modelo: SUV 560 1.8 COMFORT 2R 2024
# Marca: DFSK, Modelo: SUV 560 1.8L COMFORT 2024
# Marca: DFSK, Modelo: SUV 600 COMFORT 1.5T AT 2024
# Marca: DFSK, Modelo: SUV 600 COMFORT 1.5T MT 2024
# Marca: DFSK, Modelo: SUV 600 LUXURY 1.5T AT 2024
# Marca: EXEED, Modelo: LX 1.5T CVT ADVANCED AT 2024
# Marca: EXEED, Modelo: LX 1.5T CVT UNLIMITED AT 2024
# Marca: EXEED, Modelo: LX 1.5T CVT UNLIMITED AWD AT 2024
# Marca: EXEED, Modelo: TXL 2.0T DCT UNLIMITED AT 2024
# Marca: EXEED, Modelo: TXL 2.0T DCT UNLIMITED AWD AT 2024
# Marca: FIAT, Modelo: FASTBACK AUDACE CVT 1.0L AT 2024
# Marca: FIAT, Modelo: FASTBACK DRIVE CVT 1.0L AT 2024
# Marca: FIAT, Modelo: FASTBACK IMPETUS CVT 1.0L AT 2024
# Marca: FIAT, Modelo: PULSE DRIVE CVT 1.3L AT 2024
# Marca: FIAT, Modelo: PULSE DRIVE MT 1.3L MT 2024
# Marca: FIAT, Modelo: PULSE IMPETUS 1.0L CVT AT 2024
# Marca: FORD, Modelo: ESCAPE PLATINUM 2.0L ECOBOOST AWD AT 2024
# Marca: FORD, Modelo: ESCAPE PLATINUM 2.5L HEV AWD AT 2024
# Marca: FORD, Modelo: ESCAPE ST LINE 2.5L FHEV AT 2024
# Marca: FORD, Modelo: TERRITORY TREND 1.5L 4X2 AT 2024
# Marca: GAC, Modelo: EMKOO 1.5T GDI GE AT 2024
# Marca: GAC, Modelo: EMKOO 1.5T GDI GL AT 2024
# Marca: GAC, Modelo: EMZOOM 1.5T GB AT 2024
# Marca: GAC, Modelo: EMZOOM 1.5T GL AT 2024
# Marca: GAC, Modelo: EMZOOM 1.5T GL R-STYLE AT 2024
# Marca: GAC, Modelo: GS3 POWER 1.5T AT GB AT 2024
# Marca: GAC, Modelo: GS3 POWER 1.5T AT GS AT 2024
# Marca: GAC, Modelo: GS3 POWER 1.5T MT GB MT 2024
# Marca: GAC, Modelo: GS3 POWER 1.5T MT GS MT 2024
# Marca: GAC, Modelo: GS4 POWER 1.5T AT GB AT 2024
# Marca: GAC, Modelo: GS4 POWER 1.5T AT GE AT 2024
# Marca: GAC, Modelo: GS4 POWER 1.5T AT GL AT 2024
# Marca: GAC, Modelo: GS4 POWER 1.5T MT GB MT 2024
# Marca: HYUNDAI, Modelo: TUCSON NX4 1.6 HEV AT VALUE  2024
# Marca: HYUNDAI, Modelo: TUCSON NX4 2.0 4WD AT PLUS  2024
# Marca: HYUNDAI, Modelo: TUCSON NX4 2.0 AT PLUS  2024
# Marca: HYUNDAI, Modelo: TUCSON NX4 2.0 AT VALUE  2024
# Marca: HYUNDAI, Modelo: TUCSON NX4 2.0 MT PLUS  2024
# Marca: HYUNDAI, Modelo: VENUE QX 1.6 AT VALUE  2024
# Marca: HYUNDAI, Modelo: VENUE QX 1.6 MT PLUS  2024
# Marca: HYUNDAI, Modelo: VENUE QX 1.6 MT VALUE  2024
# Marca: JAC, Modelo: JS2 COMFORT MT 2024
# Marca: JAC, Modelo: JS2 LUXURY CVT AT 2024
# Marca: JAC, Modelo: JS2 LUXURY MT 2024
# Marca: JAC, Modelo: JS3 SE LUXURY 1.6 MT 2024
# Marca: JAC, Modelo: JS3 XE ADVANCE 1.6 CVT AT 2024
# Marca: JAC, Modelo: JS3 XE ADVANCE 1.6 MT 2024
# Marca: JAC, Modelo: JS3 XE LUXURY 1.6 CVT AT 2024
# Marca: JAC, Modelo: JS4 ADVANCE 1.5T AT 2024
# Marca: JAC, Modelo: JS4 ADVANCE BICOLOR 1.5T AT 2024
# Marca: JAC, Modelo: JS4 COMFORT 1.6 MT 2024
# Marca: JAC, Modelo: JS4 COMFORT BICOLOR 1.6 MT 2024
# Marca: JAC, Modelo: JS4 LUXURY 1.5T CVT AT 2024
# Marca: JAC, Modelo: JS4 LUXURY 1.5T MT 2024
# Marca: JAC, Modelo: JS4 LUXURY BICOLOR 1.5T CVT AT 2024
# Marca: JAC, Modelo: JS4 LUXURY BICOLOR 1.5T MT 2024
# Marca: JAC, Modelo: JS6 ADVANCE DCT AT 2024
# Marca: JAC, Modelo: JS6 COMFORT DCT AT 2024
# Marca: JAC, Modelo: JS6 LUXURY DCT AT 2024
# Marca: JAC, Modelo: JS8 ADVANCE XE DCT AT 2024
# Marca: JAC, Modelo: JS8 COMFORT CE MT 2024
# Marca: JAC, Modelo: JS8 LUXURY SE DCT AT 2024
# Marca: JAC, Modelo: JS8 LUXURY SE MT 2024
# Marca: JEEP, Modelo: COMMANDER LIMITED 1.3 4X2 AT 2024
# Marca: JEEP, Modelo: COMMANDER LIMITED 2.0 4X4 AT 2024
# Marca: JEEP, Modelo: COMMANDER LIMITED 2.0 G 4X4 AT 2024
# Marca: JEEP, Modelo: COMMANDER OVERLAND 1.3 4X2 AT AT 2024
# Marca: JEEP, Modelo: COMMANDER OVERLAND 2.0 G 4X4 AT AT 2024
# Marca: JEEP, Modelo: COMPASS LIMITED 4X2 AT 2024
# Marca: JEEP, Modelo: COMPASS LONGITUDE 4X2 AT 2024
# Marca: JEEP, Modelo: COMPASS SPORT 4X2 AT 2024
# Marca: JEEP, Modelo: GRAND CHEROKEE L SUMMIT 3.6L 3ROW AT 2024
# Marca: JEEP, Modelo: RENEGADE LONGITUDE 1.3 AT 2024
# Marca: JEEP, Modelo: RENEGADE LONGITUDE X 1.3 AT 2024
# Marca: JEEP, Modelo: RENEGADE SPORT 1.3 AT 2024
# Marca: JEEP, Modelo: WRANGLER UNLIMITED RUBICON 3.6L AT 2024
# Marca: JETOUR, Modelo: DASHING 1.5L TURBO LUX MT 2024
# Marca: JETOUR, Modelo: DASHING 6DCT 1.5L TURBO LUX AT 2024
# Marca: JETOUR, Modelo: DASHING 7DCT 1.6L TURBO GDI LIMITED AT 2024
# Marca: JETOUR, Modelo: X70 1.5T LUX AT 2024
# Marca: JETOUR, Modelo: X70 1.5T LUX MT 2024
# Marca: JETOUR, Modelo: X70 1.5T STD AT 2024
# Marca: JETOUR, Modelo: X70 1.5T STD MT 2024
# Marca: JETOUR, Modelo: X70 PLUS 1.5T 6DCT AT 2024
# Marca: JETOUR, Modelo: X70 PLUS 1.6T 7DCT AT 2024
# Marca: JETOUR, Modelo: X90 PLUS 2.0T GDI 7DCT AT 2024
# Marca: KAIYI, Modelo: KYX3 5MT LUX MT 2024
# Marca: KAIYI, Modelo: KYX3 5MT STD MT 2024
# Marca: KAIYI, Modelo: KYX3 CVT LUX AT 2024
# Marca: KAIYI, Modelo: KYX3 PRO 1.5T CVT AT 2024
# Marca: KIA, Modelo: CARENS EX 1.4L 7DCT TURBO-GDI 7P 2024
# Marca: KIA, Modelo: CARENS EX 1.4L 7DCT TURBO-GDI FULL 7P 2024
# Marca: KIA, Modelo: CARENS LX 1.5L 6MT 7P 2024
# Marca: KIA, Modelo: NIRO EV EX 64.8KWH 2WD FULL 2024
# Marca: KIA, Modelo: NIRO EV LX 64.8KWH 2WD 2024
# Marca: KIA, Modelo: NIRO EV6 GT-LINE 77.4KWH AWD 2024
# Marca: KIA, Modelo: NIRO EV9 GT-LINE 99.8KWH AWD 6P1 2024
# Marca: KIA, Modelo: NIRO EV9 GT-LINE 99.8KWH AWD 6P2 2024
# Marca: KIA, Modelo: NIRO EV9 GT-LINE 99.8KWH AWD 6P3 2024
# Marca: KIA, Modelo: NIRO EV9 GT-LINE 99.8KWH AWD 7P 2024
# Marca: KIA, Modelo: SELTOS EX 1.4L 7DCT TURBO 2024
# Marca: KIA, Modelo: SELTOS EX 1.4L 7DCT TURBO FULL 2024
# Marca: KIA, Modelo: SELTOS EX 1.5L 6MT 2024
# Marca: KIA, Modelo: SELTOS EX 1.5L IVT 2024
# Marca: KIA, Modelo: SONET EX 1.5L 6MT AC RI 2024
# Marca: KIA, Modelo: SONET EX 1.5L 6MT RI FULL 2024
# Marca: KIA, Modelo: SONET EX 1.5L IVT ACC PLUS 2024
# Marca: KIA, Modelo: SONET EX 1.5L IVT FULL 2024
# Marca: KIA, Modelo: SONET EX 1.5L IVT IR FULL 2024
# Marca: KIA, Modelo: SORENTO EX 2.2L DSL 8DCT 2WD 2024
# Marca: KIA, Modelo: SORENTO EX 2.5L GSL 6AT 2WD 2024
# Marca: KIA, Modelo: SORENTO EX 2.5L GSL 6AT 2WD FULL 2024
# Marca: KIA, Modelo: SORENTO EX 2.5L GSL 6AT AWD FULL 2024
# Marca: KIA, Modelo: SPORTAGE EX 1.6L TURBO-GDI 7DCT GSL AWD 2024
# Marca: KIA, Modelo: SPORTAGE EX 2.0L 6AT GSL 2024
# Marca: KIA, Modelo: SPORTAGE EX 2.0L 6AT GSL BS 2024
# Marca: KIA, Modelo: SPORTAGE EX 2.0L 6MT GSL 2024
# Marca: KIA, Modelo: SPORTAGE EX 2.0L 8AT DSL AWD 2024
# Marca: KIA, Modelo: SPORTAGE EX 2.0L 8AT DSL BS 2024
# Marca: KIA, Modelo: SPROTAGE EX 2.0L 6AT GSL AWD 2024
# Marca: KIA, Modelo: SPROTAGE EX 2.0L 8AT DSL 2024
# Marca: MAHINDRA, Modelo: XUV300 MT COMFORT 2024
# Marca: MAHINDRA, Modelo: XUV300 MT ELITE 2024
# Marca: MAHINDRA, Modelo: XUV300 MT LUXURY 2024
# Marca: MAXUS, Modelo: D60 ELITE 7DCT 4X2 AT 2024
# Marca: MAXUS, Modelo: D60 LUXURY 7DCT 4X2 AT 2024
# Marca: MAXUS, Modelo: D90 ELITE 4X4 AT 2024
# Marca: MAXUS, Modelo: D90 FLAGSHIP 4X4 AT 2024
# Marca: MAXUS, Modelo: D90 LUXURY 4X4 AT 2024
# Marca: MAXUS, Modelo: EUNIQ 6 AT 2024
# Marca: MAXUS, Modelo: G90 ELITE AT 2024
# Marca: MAXUS, Modelo: G90 LUXURY AT 2024
# Marca: MG, Modelo: 3 1.5 STD AT 2024
# Marca: MG, Modelo: HS 1.5T COM 2024
# Marca: MG, Modelo: HS 1.5T DCT DLX 2024
# Marca: MG, Modelo: HS 1.5T DCT TROPHY 2024
# Marca: MG, Modelo: MARVEL R DLX AT 2024
# Marca: MG, Modelo: MG ZS 1.5L COM AT 2024
# Marca: MG, Modelo: MG ZS 1.5L STD AT 2024
# Marca: MG, Modelo: ONE 1.5T CVT COM 2024
# Marca: MG, Modelo: ONE 1.5T CVT DLX 2024
# Marca: MG, Modelo: RX5 1.5T COM 2024
# Marca: MG, Modelo: RX5 1.5T DCT COM 2024
# Marca: MG, Modelo: RX5 1.5T DCT DLX 2024
# Marca: MG, Modelo: ZS 1.5L COM 2024
# Marca: MG, Modelo: ZS 1.5L STD 2024
# Marca: MG, Modelo: ZS EV DLX AT 2024
# Marca: MG, Modelo: ZX 1.3T AT 6 TROPHY 2024
# Marca: MG, Modelo: ZX 1.5L COM 2024
# Marca: MG, Modelo: ZX 1.5L CVT DLX 2024
# Marca: MG, Modelo: ZX 1.5L DLX 2024
# Marca: MITSUBISHI, Modelo: ASX 1.6L GL 4X2 MT 2024
# Marca: MITSUBISHI, Modelo: ASX 1.6L GLS 4X2 MT 2024
# Marca: MITSUBISHI, Modelo: ASX 2.0L GLS 4X2 AT 2024
# Marca: MITSUBISHI, Modelo: ECLIPSE CROSS RS 1.5 4X2 AT AT 2024
# Marca: MITSUBISHI, Modelo: ECLIPSE CROSS RX 1.5 4X2 AT AT 2024
# Marca: MITSUBISHI, Modelo: MONTERO SPORT 3.0 2WD AT 2024
# Marca: MITSUBISHI, Modelo: MONTERO SPORT 3.0 4WD AT 2024
# Marca: SSANGYONG, Modelo: TORRES GLX 1.5T 2WD AT 2024
# Marca: SSANGYONG, Modelo: TORRES GLX 1.5T 2WD MT 2024
# Marca: SSANGYONG, Modelo: TORRES GLX 1.5T 4WD AT 2024
# Marca: SSANGYONG, Modelo: TORRES LIMITED PLUS 1.5T 4WD BITONO AT 2024
# Marca: SSANGYONG, Modelo: TORRES LIMITED PLUS 1.5T 4WD SUNROOF AT 2024
# Marca: SUBARU, Modelo: CROSSTREK 2.0I AWD CVT AT 2024
# Marca: SUBARU, Modelo: CROSSTREK 2.0I AWD CVT DYNAMIC EYESIGH AT 2024
# Marca: SUBARU, Modelo: CROSSTREK 2.0I AWD CVT TOURING EYESIGH AT 2024
# Marca: TOYOTA, Modelo: 4RUNNER LIMITED 4X4 AT 2024
# Marca: TOYOTA, Modelo: 4RUNNER SR5 4X2 AT 2024
# Marca: TOYOTA, Modelo: 4RUNNER SR5 4X4 AT 2024
# Marca: TOYOTA, Modelo: COROLLA CROSS HEV SEG 1.8 HEV AT 2024
# Marca: TOYOTA, Modelo: COROLLA CROSS HEV XEI 1.8 HEV AT 2024
# Marca: TOYOTA, Modelo: FORTUNER SR5 4X2 2.7L AT 2024
# Marca: TOYOTA, Modelo: FORTUNER SR5 4X4 TDI 2.8 AT 2024
# Marca: TOYOTA, Modelo: FORTUNER SR5 4X4 TDI 2.8 MT 2024
# Marca: TOYOTA, Modelo: FORTUNER SRX 4X4 TDI 2.8 AT 2024
# Marca: TOYOTA, Modelo: RAIZE 1.2 CVT GAS E MT 2024
# Marca: TOYOTA, Modelo: RAIZE 1.2 MT GAS MT 2024
# Marca: TOYOTA, Modelo: RAV4 LE 2.0 4X2 CVT AT 2024
# Marca: TOYOTA, Modelo: RAV4 LE 2.0 4X2 MT 2024
# Marca: TOYOTA, Modelo: RAV4 LE 2.0 4X4 MT 2024
# Marca: TOYOTA, Modelo: RAV4 LIMITED 2.5 HV CVT 4X4 AT 2024
# Marca: TOYOTA, Modelo: RAV4 XLE 2.0 4X2 CVT AT 2024
# Marca: TOYOTA, Modelo: RAV4 XLE 2.5 4X2 CVT HV AT 2024
# Marca: TOYOTA, Modelo: RAV4 XSE 2.5 4X2 CVT HV AT 2024
# Marca: TOYOTA, Modelo: YARIS CROSS XI 1.5 AT 2024
# Total unique combinations for SUV: 367
#
# Tipo Producto: MINIBUS
# Marca: CITROEN, Modelo: SPACETOURER BLUEHDI 150 S&S BVM6 BUSINESS TALLA XL 2024
# Marca: HYUNDAI, Modelo: STARIA MB 2.2 CEDI 11P 2024
# Marca: HYUNDAI, Modelo: STARIA MB 2.2 CRDI 4WD 9P LUXURY 2024
# Marca: HYUNDAI, Modelo: STARIA MB 2.2 CRDI 9P 2024
# Marca: JAC, Modelo: SUNRAY 13+1 MT 2024
# Marca: JAC, Modelo: SUNRAY 14+1 MT 2024
# Marca: JAC, Modelo: SUNRAY 16+1 MT 2024
# Marca: JAC, Modelo: SUNRAY 17+1 MT 2024
# Marca: MAXUS, Modelo: G10 MINIBUS 6+1 E6 2024
# Marca: RAM, Modelo: V 700 CITY 1.3L 2024
# Marca: RAM, Modelo: V1000 CORTO 1.3L 2024
# Marca: RAM, Modelo: V700 RAPID 1.4L 2024
# Marca: TOYOTA, Modelo: HIACE CARGO L1H1 2024
# Total unique combinations for FURGÓN: 35
#
# Results saved to unique_marca_modelo_by_tipo_producto.csv

# %% [markdown]
# ### Vemos que en el nombre del producto hay varias especificaciones aparte del nombre, como el motor, drive, transmisión y año. Todos son del 2024.

# %%
import pandas as pd
import re

# Read the CSV data into a DataFrame
df = pd.read_csv('unique_marca_modelo_by_tipo_producto.csv')

def parse_modelo(modelo):
    parsed = {
        'Model Name': '',
        'Engine': '',
        'Drive': '',
        'Transmission': '',
        'Year': ''
    }
    tokens = modelo.strip().split()
    model_name_tokens = []
    started_fields = False

    for token in tokens:
        # Check for year (assuming it's a 4-digit number)
        if re.match(r'^\d{4}$', token):
            parsed['Year'] = token
            started_fields = True
        # Check for engine size with decimal or ending with 'L' or 'T'
        elif re.match(r'^\d+(\.\d+)?[LT]?T?$', token):
            if ('.' in token) or token.endswith(('L', 'T')):
                parsed['Engine'] = token
                started_fields = True
            else:
                if not started_fields:
                    model_name_tokens.append(token)
                else:
                    model_name_tokens.append(token)
        # Check for drive types
        elif token.upper() in ['4X2', '4X4', '2WD', '4WD', 'AWD', '2R', 'FWD', 'RWD']:
            parsed['Drive'] = token.upper()
            started_fields = True
        # Check for transmission types (including multi-character)
        elif re.match(r'^\d?(MT|AT|CVT|DCT|EAT6|EAT8)$', token.upper()):
            parsed['Transmission'] = token.upper()
            started_fields = True
        else:
            # Always add to Model Name
            model_name_tokens.append(token)

    parsed['Model Name'] = ' '.join(model_name_tokens).strip()
    return parsed



# Apply the parsing function to the DataFrame
parsed_data = df['MODELO'].apply(parse_modelo)
parsed_df = pd.DataFrame(parsed_data.tolist())

# Combine the parsed data with the original DataFrame
result_df = pd.concat([df.drop(columns=['MODELO']), parsed_df], axis=1)

# Save the result to a new CSV file
result_df.to_csv('parsed_output.csv', index=False)

# %% [markdown]
# OTRAS PÁGINAS WEB
# https://www.car.info/
# cars.com
# edmunds.com
#
# Changan...
# https://db.carnewschina.com/changan/changan-hunter/2024

# %% [markdown]
# API de https://api-ninjas.com/api/cars

# %%
import csv
import requests

api_key = 'API_KEY="6ue2W96PLx7uIy8/aSzZjg==BjuLPBac2jh5yqGI"'  # Replace with your actual API key

output_rows = []

with open('parsed_output.csv', mode='r', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    fieldnames = reader.fieldnames + ['API_Response']
    for row in reader:
        model_name = row.get('Model Name', '').strip()
        if model_name:
            first_word = model_name.split()[0].lower()
            api_url = f'https://api.api-ninjas.com/v1/cars?model={first_word}&year=2024'
            response = requests.get(api_url, headers={'X-Api-Key': api_key})
            if response.status_code == requests.codes.ok:
                row['API_Response'] = response.text
            else:
                row['API_Response'] = f"Error: {response.status_code} {response.text}"
        else:
            row['API_Response'] = "No model name found"
        output_rows.append(row)

with open('output.csv', mode='w', encoding='utf-8', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(output_rows)

# %% [markdown]
# ### Ejemplo del get de los modelo Colorado, hay varios modelos pero no exactos. A nivel de la API hay match exactos, modelos parecidos y algunos que no están.

# %%
API_KEY="6ue2W96PLx7uIy8/aSzZjg==BjuLPBac2jh5yqGI"

api_url = "https://api.api-ninjas.com/v1/cars?limit=50&model=colorado&year=2024&transmission=a"

headers = {'X-Api-Key': API_KEY}

response = requests.get(api_url, headers=headers)

print(response.json())
# Out:
# [{'city_mpg': 18, 'class': 'small pickup truck', 'combination_mpg': 20, 'cylinders': 4, 'displacement': 2.7, 'drive': '4wd', 'fuel_type': 'gas', 'highway_mpg': 23, 'make': 'chevrolet', 'model': 'colorado 4wd', 'transmission': 'a', 'year': 2024}, {'city_mpg': 19, 'class': 'small pickup truck', 'combination_mpg': 21, 'cylinders': 4, 'displacement': 2.7, 'drive': 'rwd', 'fuel_type': 'gas', 'highway_mpg': 24, 'make': 'chevrolet', 'model': 'colorado 2wd', 'transmission': 'a', 'year': 2024}, {'city_mpg': 20, 'class': 'small pickup truck', 'combination_mpg': 22, 'cylinders': 4, 'displacement': 2.7, 'drive': 'rwd', 'fuel_type': 'gas', 'highway_mpg': 24, 'make': 'chevrolet', 'model': 'colorado 2wd', 'transmission': 'a', 'year': 2024}, {'city_mpg': 16, 'class': 'small pickup truck', 'combination_mpg': 16, 'cylinders': 4, 'displacement': 2.7, 'drive': '4wd', 'fuel_type': 'gas', 'highway_mpg': 16, 'make': 'chevrolet', 'model': 'colorado zr2 bison 4wd', 'transmission': 'a', 'year': 2024}, {'city_mpg': 17, 'class': 'small pickup truck', 'combination_mpg': 18, 'cylinders': 4, 'displacement': 2.7, 'drive': '4wd', 'fuel_type': 'gas', 'highway_mpg': 20, 'make': 'chevrolet', 'model': 'colorado mud terrain tires 4wd', 'transmission': 'a', 'year': 2024}, {'city_mpg': 17, 'class': 'small pickup truck', 'combination_mpg': 17, 'cylinders': 4, 'displacement': 2.7, 'drive': '4wd', 'fuel_type': 'gas', 'highway_mpg': 17, 'make': 'chevrolet', 'model': 'colorado zr2 4wd', 'transmission': 'a', 'year': 2024}, {'city_mpg': 18, 'class': 'small pickup truck', 'combination_mpg': 20, 'cylinders': 4, 'displacement': 2.7, 'drive': '4wd', 'fuel_type': 'gas', 'highway_mpg': 22, 'make': 'chevrolet', 'model': 'colorado 4wd', 'transmission': 'a', 'year': 2024}]

# %% [markdown]
# colorado
# silverado
# maverick
# ranger
# sentra
# leaf
# yaris
# bolt
# traverse
# escape
# commander
# compass
# montero
# outlander
# kicks
# pathfinder
# crosstrek
# 4runner
# rav4

# %%
import requests
import csv

url = "https://api.perplexity.ai/chat/completions"

# Read your existing CSV file
with open('parsed_output.csv', mode='r', encoding='utf-8-sig') as infile:
    reader = csv.DictReader(infile)
    rows = list(reader)

# Prepare to write to a new CSV file with additional columns
fieldnames = reader.fieldnames + [
    "FuelType", "MilesPerGallon",
    "Power", "Torque",
    "NumSeats", "FuelTankCapacity", "CargoCapacity",
    "CountryOfManufacture"
]

fieldnames_search = reader.fieldnames + [
    "Fuel Type", "Miles per gallon",
    "Power", "Torque",
    "Number of seats", "Capacity of Fuel Tank", "Cargo Capacity",
    "Country Of Manufacture"
]


with open('output.csv', mode='w', newline='', encoding='utf-8') as outfile:
    writer = csv.DictWriter(outfile, fieldnames=fieldnames)
    writer.writeheader()

    for row in rows:
        # Construct the prompt
        vehicle_data = ', '.join([f"{key}: {value}" for key, value in row.items() if value])
        additional_fields = ', '.join(fieldnames_search[len(reader.fieldnames):])
        prompt = f"Given the following vehicle data: {vehicle_data}. Please search and provide the following additional information in the same order, separated by commas: {additional_fields}. If you do not find the information fill with NA, do not put any additional text only the string separated with comas."

        payload = {
            "model": "llama-3.1-sonar-huge-128k-online",
            "messages": [
                {
                    "role": "system",
                    "content": "You are a helpful assistant that outputs data in CSV format without any additional text. Only output the data in the specified order, separated by commas."
                },
                {
                    "role": "user",
                    "content": prompt
                }
            ],
            "max_tokens": 300,  # Adjusted for longer responses
            "temperature": 0.2,
            "top_p": 0.9,
            "return_citations": False,
            "return_images": False,
            "return_related_questions": False,
            "search_recency_filter": "month",
            "top_k": 0,
            "stream": False,
            "presence_penalty": 0,
            "frequency_penalty": 1
        }
        headers = {
            "Authorization": "Bearer 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",
            "Content-Type": "application/json"
        }

        response = requests.post(url, json=payload, headers=headers)

        # Check the response status code
        print(f"Status Code: {response.status_code}")

        if response.status_code == 200:
            try:
                data = response.json()
                # Extract the assistant's reply
                assistant_reply = data['choices'][0]['message']['content']
                print(assistant_reply)

                # Split the reply into a list of values
                new_values = assistant_reply.strip().split(',')
                print(new_values)

                # Create a dictionary of the new data
                new_data = dict(zip(fieldnames[len(reader.fieldnames):], [value.strip() for value in new_values]))
                print(new_data)

                # Combine the old and new data
                combined_row = {**row, **new_data}
                print(combined_row)

                # Write the combined data to the new CSV file
                writer.writerow(combined_row)

            except ValueError as e:
                print("Failed to parse JSON response.")
                print("Response Text:", response.text)
                continue  # Skip to the next iteration or handle the error accordingly
        else:
            print(f"Error: Received status code {response.status_code}")
            print("Response Text:", response.text)
            continue  # Skip to the next iteration or handle the error accordingly

        break  # Remove this break statement if you want to process all rows
# Out:
# Status Code: 200
# Unleaded Petrol/Electric, NA, 114bhp, 141Nm, 5, NA, 390L, Japan
# ['Unleaded Petrol/Electric', ' NA', ' 114bhp', ' 141Nm', ' 5', ' NA', ' 390L', ' Japan']
# {'FuelType': 'Unleaded Petrol/Electric', 'MilesPerGallon': 'NA', 'Power': '114bhp', 'Torque': '141Nm', 'NumSeats': '5', 'FuelTankCapacity': 'NA', 'CargoCapacity': '390L', 'CountryOfManufacture': 'Japan'}
# {'MARCA': 'TOYOTA', 'TIPO PRODUCTO': 'SUV', 'Model Name': 'YARIS CROSS XI', 'Engine': '1.5', 'Drive': '', 'Transmission': 'AT', 'Year': '2024', 'FuelType': 'Unleaded Petrol/Electric', 'MilesPerGallon': 'NA', 'Power': '114bhp', 'Torque': '141Nm', 'NumSeats': '5', 'FuelTankCapacity': 'NA', 'CargoCapacity': '390L', 'CountryOfManufacture': 'Japan'}
