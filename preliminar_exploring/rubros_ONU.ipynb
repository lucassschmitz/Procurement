# %%
import pandas as pd
import os

# %%
path = os.path.join('..', 'Listado_rubros_ONU.xlsx')
df = pd.read_excel(path)
df
# Out:
#        CodigoProductoONU   NombreProducto                            RubroN1  \
# 0                     -1  Sin Información                    Sin Información
# 1               10101501            Gatos  Artículos para plantas y animales
# 2               10101502           Perros  Artículos para plantas y animales
# 3               10101504          Visones  Artículos para plantas y animales
# 4               10101505            Ratas  Artículos para plantas y animales
# ...                  ...              ...                                ...
# 18830          102109081             1a S                        Consultoria
# 18831          102109082             1era                        Consultoria
# 18832          102109083              2da                        Consultoria
# 18833          102109084             3era                        Consultoria
# 18834          103101001        eCommerce                          eCommerce
#
#                RubroN2              RubroN3
# ...

# %% [markdown]
# Categories samples

# %%
df.groupby('RubroN1').first()
# Out:
#                                                     CodigoProductoONU  \
# RubroN1
# Alimentos, bebidas y tabaco                                  50101538
# Artículos de electrónica                                     32101502
# Artículos de fabricación y producción                        31101501
# Artículos eléctricos y de iluminación                        39101601
# Artículos para estructuras, obras y construcciones           30101501
# Artículos para plantas y animales                            10101501
# Combustibles, lubricantes y anticorrosivos                   15101502
# Consultoria                                                 102101001
# Educación, formación, entrenamiento y capacitación           86101501
# Equipamiento para el acondicionamiento, distrib...           40101501
# Equipamiento para laboratorios                               41101502
# Equipamiento para manejo y estiba de materiales              24101501
# ...
