# %% [markdown]
# This file useses the purchases of the four FAs that we could find (2239-5-LR21, 2239-8-LR23, 2239-4-LR17 and ID 2239-20-LP13 ) and does the following things:
# 1. Joins them
# 2. merges them with the car data
# 3. estimates a demand model

# %%
import os
import pandas as pd
from pandasgui import show
import socket
from unidecode import unidecode
import unicodedata
from difflib import SequenceMatcher

# %% [markdown]
# ### Functions

# %%
def clean_text(text):
    if isinstance(text, str):
        return unidecode(text)
    return text


def fix_encoding(text):
    if isinstance(text, str):
        replacements = {
            'Ã³': 'ó',
            'Ã­': 'í',
            'Ã¡': 'á',
            'Ã©': 'é',
            'Ã±': 'ñ',
            'Ãº': 'ú',
            'Ã¼': 'ü',
            'Ã': 'í'
        }
        for wrong, right in replacements.items():
            text = text.replace(wrong, right)
    return text

def process_prices(df):
    """
    Process prices in a dataframe according to specific rules using vectorized operations:
    1. Process all prices in scientific notation first
    2. For remaining prices with commas, remove everything after the comma
    3. For USD prices, multiply by 700
    
    Parameters:
    df (pd.DataFrame): Input dataframe with Moneda and Precio Unitario columns
    
    Returns:
    pd.DataFrame: Processed dataframe
    pd.DataFrame: Rows with processing issues
    """
    # Create a copy to avoid modifying the original
    df_processed = df.copy()
    
    # Ensure the required columns exist
    required_cols = ['Moneda', 'Precio Unitario']
    if not all(col in df_processed.columns for col in required_cols):
        raise ValueError(f"Missing required columns. Need: {required_cols}")
    
    # Convert Precio Unitario to string type for string operations
    df_processed['Precio Unitario'] = df_processed['Precio Unitario'].astype(str)
    
    # Create masks for different conditions
    has_scientific_notation = df_processed['Precio Unitario'].str.contains('e', case=False, na=False)
    has_comma_mask = df_processed['Precio Unitario'].str.contains(',', na=False)
    is_usd_mask = df_processed['Moneda'] == 'USD'
    
    # 1. Process scientific notation first
    scientific_values = df_processed[has_scientific_notation]['Precio Unitario']
    if not scientific_values.empty:
        # Replace comma with dot for proper float conversion
        scientific_values = scientific_values.str.replace(',', '.')
        df_processed.loc[has_scientific_notation, 'Precio Unitario'] = (
            pd.to_numeric(scientific_values, errors='coerce')
        )
    
    # 2. Process remaining prices with commas (excluding already processed scientific notation)
    remaining_comma_mask = has_comma_mask & ~has_scientific_notation
    if any(remaining_comma_mask):
        df_processed.loc[remaining_comma_mask, 'Precio Unitario'] = (
            df_processed.loc[remaining_comma_mask, 'Precio Unitario']
            .str.split(',')
            .str[0]
        )
    
    # Convert all prices to numeric
    df_processed['Precio Unitario'] = pd.to_numeric(df_processed['Precio Unitario'], errors='coerce')
    
    # 3. Multiply USD prices by 700
    df_processed.loc[is_usd_mask, 'Precio Unitario'] = df_processed.loc[is_usd_mask, 'Precio Unitario'] * 700
    
    # Find problematic rows (where conversion to numeric failed)
    problematic_rows = df_processed[df_processed['Precio Unitario'].isna()].copy()
    print(f"Number of problematic rows: {len(problematic_rows)}")

    return df_processed

# %% [markdown]
# ## Read the purchases for the FAs and join them
#
# In 2017 we have also leases and repairs of cars. This has to be fixed.

# %%
transac_cm_2013_path = os.path.join('..', 'interm_data', 'yearly_data', 'Transacciones', 'transacciones_cm_2013.csv')
transac_cm_2013_df = pd.read_csv(transac_cm_2013_path)
print(f"Dimensions of transac_cm_2013_df: {transac_cm_2013_df.shape}")
transac_cm_2013_df.head()
# Out:
# Dimensions of transac_cm_2013_df: (0, 1)
# Empty DataFrame
# Columns: [Unnamed: 0]
# Index: []

# %% [markdown]
# ### 2017

# %%
transac_cm_2017_path = os.path.join('..', 'interm_data', 'yearly_data', 'Transacciones', 'transacciones_cm_2017.csv')
transac_cm_2017_df = pd.read_csv(transac_cm_2017_path)
transac_cm_2017_df.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
print(f"Dimensions of transac_cm_2017_df: {transac_cm_2017_df.shape}")

# Extract the year from the 'Fecha Envío OC' column
transac_cm_2017_df['year'] = pd.to_datetime(transac_cm_2017_df['Fecha Envío OC']).dt.year

# Count the number of observations for each year
year_counts = transac_cm_2017_df['year'].value_counts().sort_index()
print(year_counts)

nro_counts = transac_cm_2017_df['Nro Licitación Pública'].value_counts().sort_index() 
print(nro_counts)

transac_cm_2017_df.head()
transac_cm_2017_df = process_prices(transac_cm_2017_df)
# Out:
# Dimensions of transac_cm_2017_df: (19997, 45)
# year
# 2018    3574
# 2019    6056
# 2020    5174
# 2021    5193
# Name: count, dtype: int64
# Nro Licitación Pública
# 2239-4-LR17    19997
# Name: count, dtype: int64
# Number of problematic rows: 0

# %% [markdown]
# clean the 2017 data

# %%
#clean based on the 'Convenio Marco' column
convenio_aux = transac_cm_2017_df['Convenio Marco'].unique()
#print(convenio_aux)
transac_cm_2017_df = transac_cm_2017_df[transac_cm_2017_df['Convenio Marco'] == 'Compra de Vehículos Livianos y Medianos']


#clean based on the 'Tipo de Producto' column (drop Productos with less than 30 observations, they were weird products like 'City car' or 'oficinas moviles')
counts = transac_cm_2017_df['Tipo de Producto'].value_counts()
print(counts)
to_drop = counts[counts < 30].index
transac_cm_2017_df = transac_cm_2017_df[
    ~transac_cm_2017_df['Tipo de Producto'].isin(to_drop)
]
transac_cm_2017_df = transac_cm_2017_df[transac_cm_2017_df['Tipo de Producto'] != 'MANTENCIÓN PREVENTIVA VEHÍCULO LIVIANO Y MEDIANO']
# Out:
# Tipo de Producto
# MANTENCIÓN PREVENTIVA VEHÍCULO LIVIANO Y MEDIANO    14843
# CAMIONETA                                            1178
# SUV                                                   554
# MINIBUS                                               349
# SEDÁN                                                 234
# AMBULANCIAS                                           184
# VEHÍCULOS POLICIALES                                  119
# CAMIÓN LIVIANO                                        103
# FURGÓN                                                 87
# HATCHBACK                                              41
# CITY CAR                                               29
# OFICINAS MOVILES                                        4
# VEHÍCULO TRASLADO MENORES                               3
# VEHÍCULO TRASLADO INTERNOS                              2
# Name: count, dtype: int64

# %%
# check that the data makes sense and is clean
counts = transac_cm_2017_df['Tipo de Producto'].value_counts()
print(counts)
summary_precio_unitario = transac_cm_2017_df['Precio Unitario'].describe()
print(summary_precio_unitario)
# Out:
# Tipo de Producto
# CAMIONETA               1178
# SUV                      554
# MINIBUS                  349
# SEDÁN                    234
# AMBULANCIAS              184
# VEHÍCULOS POLICIALES     119
# CAMIÓN LIVIANO           103
# FURGÓN                    87
# HATCHBACK                 41
# Name: count, dtype: int64
# count    2.849000e+03
# mean     1.761404e+07
# std      1.023039e+07
# min      4.058600e+06
# 25%      1.269076e+07
# 50%      1.535040e+07
# 75%      1.899000e+07
# max      1.240800e+08
# Name: Precio Unitario, dtype: float64

# %% [markdown]
# ### 2021

# %%
transac_cm_2021_path = os.path.join('..', 'interm_data', 'yearly_data', 'Transacciones', 'transacciones_cm_2021.csv')
transac_cm_2021_df = pd.read_csv(transac_cm_2021_path)
transac_cm_2021_df.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
print(f"Dimensions of transac_cm_2021_df: {transac_cm_2021_df.shape}")

 # Fix weird characters in columns and in text 
#transac_cm_2021_df.columns = [clean_text(col) for col in transac_cm_2021_df.columns]
#for column in transac_cm_2021_df.select_dtypes(include=['object']).columns:
#    transac_cm_2021_df[column] = transac_cm_2021_df[column].apply(clean_text)



transac_cm_2021_df.columns = [fix_encoding(col) for col in transac_cm_2021_df.columns]
for column in transac_cm_2021_df.select_dtypes(include=['object']).columns:
    transac_cm_2021_df[column] = transac_cm_2021_df[column].apply(fix_encoding)


transac_cm_2021_df['year'] = pd.to_datetime(transac_cm_2021_df['Fecha Envío OC']).dt.year


# Count the number of observations for each year
year_counts = transac_cm_2021_df['year'].value_counts().sort_index()
print(year_counts)

nro_counts = transac_cm_2021_df['Nro Licitación Pública'].value_counts().sort_index() 

print(nro_counts)

transac_cm_2021_df = process_prices(transac_cm_2021_df)
transac_cm_2021_df.head()
# Out:
# Dimensions of transac_cm_2021_df: (1071, 45)
# year
# 2021      7
# 2022    277
# 2023    721
# 2024     66
# Name: count, dtype: int64
# Nro Licitación Pública
# 2239-5-LR21    1071
# Name: count, dtype: int64
# Number of problematic rows: 0
#   Nro Licitación Pública  Id Convenio Marco
# 0            2239-5-LR21          5800296.0  \
# 1            2239-5-LR21          5800296.0
# 2            2239-5-LR21          5800296.0
# 3            2239-5-LR21          5800296.0
# 4            2239-5-LR21          5800296.0
#
#                                       Convenio Marco          CodigoOC
# 0  CM Adquisición de Vehículos SUV y Camionetas (...     2564-270-CM21  \
# 1  CM Adquisición de Vehículos SUV y Camionetas (...      4360-75-CM21
# 2  CM Adquisición de Vehículos SUV y Camionetas (...     3140-819-CM21
# 3  CM Adquisición de Vehículos SUV y Camionetas (...  1084170-110-CM21
# 4  CM Adquisición de Vehículos SUV y Camionetas (...     4236-722-CM21
#
#                                             NombreOC Fecha Envío OC
# 0                     Orden de Compra: 2564-270-CM21     2021-10-20  \
# 1                            Camioneta maxus d/c 4x4     2021-12-24
# 2  Orden de Compra: 3140-819-CM21, ADQUISICIíN D...     2021-12-21
# 3                        Camioneta para Uso del SLEP     2021-12-28
# 4                     Orden de Compra: 4236-722-CM21     2021-12-29
#
#               EstadoOC Proviene de Gran Compra  idGranCompra
# 0  Enviada a Proveedor                      No           NaN  \
# 1  Enviada a Proveedor                      No           NaN
# 2  Enviada a Proveedor                      No           NaN
# 3   Recepción Conforme                      No           NaN
# 4             Aceptada                      No           NaN
#
#                         Especificación del Comprador  ...
# 0  (1840093) CAMIONETAS MAXUS T60 T60 DX 4X4  MAC...  ...  \
# 1  (1840095) CAMIONETAS MAXUS T60 T60 DX 4X4  MAC...  ...
# 2  (1848052) CAMIONETA NISSAN NAVARA DC SE 2.3D M...  ...
# 3  (1840060) CAMIONETAS MAHINDRA PIK UP PICK UP R...  ...
# 4  (1848008) CAMIONETA TOYOTA HILUX 4X4 2.4 MT DX...  ...
#
#                       Nombre Empresa Comuna del Proveedor
# 0      Mediterraneo Automotores S.A.                  NaN  \
# 1      Mediterraneo Automotores S.A.                  NaN
# 2  SALINAS Y FABRES SOCIEDAD ANONIMA                  NaN
# 3                BRUNO FRITSCH S.A.                   NaN
# 4       Maritano y Ebensperger Ltda.                  NaN
#
#   Región del Proveedor                                      Observaciones
# 0                  NaN  Orden de Compra codigo: 2564-270-CM21 dirigida...  \
# 1                  NaN  Orden de Compra codigo: 4360-75-CM21 dirigida ...
# 2                  NaN  Orden de Compra codigo: 3140-819-CM21 dirigida...
# 3                  NaN  1.\tAceptar la OC y facturar después de entreg...
# 4                  NaN  Orden de Compra codigo: 4236-722-CM21 dirigida...
#
#                                        Forma de Pago Orgcode_Comprador
# 0  30 días contra la recepción conforme de la fac...            3555.0  \
# 1  30 días contra la recepción conforme de la fac...            5277.0
# 2  30 días contra la recepción conforme de la fac...            4061.0
# 3  30 días contra la recepción conforme de la fac...         1084170.0
# 4  30 días contra la recepción conforme de la fac...            5154.0
#
#    Entcode_Comprador  Orgcode_Proveedor Entcode_Proveedor  year
# 0            92414.0             824156             27979  2021
# 1           135561.0             824156             27979  2021
# 2           113735.0              26569             26778  2021
# 3          1675231.0              24507             24823  2021
# 4           127036.0              62896             61164  2021
#
# [5 rows x 46 columns]

# %% [markdown]
# clean the 2021 data

# %%
#not necessary to do anything with Convenio Marco, since there is no subletting in 2021
convenio_aux = transac_cm_2021_df['Convenio Marco'].unique()
#print(convenio_aux)

# not necessary to do anything with Tipo de Producto since there are only SUVs and pick-ups
counts = transac_cm_2021_df['Tipo de Producto'].value_counts()
print(counts)

# check that the data makes sense and is clean
counts = transac_cm_2021_df['Tipo de Producto'].value_counts()
print(counts)
summary_precio_unitario = transac_cm_2021_df['Precio Unitario'].describe()
print(summary_precio_unitario)
# Out:
# Tipo de Producto
# CAMIONETA    800
# SUV          271
# Name: count, dtype: int64
# Tipo de Producto
# CAMIONETA    800
# SUV          271
# Name: count, dtype: int64
# count    1.071000e+03
# mean     1.965587e+07
# std      5.451048e+06
# min      7.651600e+06
# 25%      1.579042e+07
# 50%      1.842240e+07
# 75%      2.419873e+07
# max      3.818530e+07
# Name: Precio Unitario, dtype: float64

# %% [markdown]
# ### merge 2021 data with auctions data
#
# The merging criteria should be
# 1. Marca(transactions) coincides with Marca(auction)
# 2. Macrozona(transactions, created) coincides with Macrozona(auction),
# 3. Tipo de Producto (transactions) coincides with Categoria (auction)
# 4. Rut proveedor (transactions) coincides with Rut(auction)

# %%
#1. create a merge variable in transactions data 
transac_cm_2021_df['Macrozona'] = transac_cm_2021_df['Producto'].str.extract(r'MACROZONA\s+(\w+)')
transac_cm_2021_df['exact_merge_var'] = (transac_cm_2021_df['Marca'].astype(str) + ' '
                                        + transac_cm_2021_df['Macrozona'].astype(str) + ' '
                                        + transac_cm_2021_df['Tipo de Producto'].astype(str) + ' '
                                        + transac_cm_2021_df['Rut Proveedor'].astype(str))

transac_cm_2021_df['exact_merge_var'] = transac_cm_2021_df['exact_merge_var'].str.upper()

#show(transac_cm_2021_df)

# %%
#2. import the acution data and create a merge variable
auction_path = r"C:\Users\lucas\OneDrive - Yale University\Documents\GitHub\2nd-year-paper\interm_data\CM_auctions"
auction_df = pd.read_excel(os.path.join(auction_path, 'auction21.xlsx'))


#2.1 create the matching variable 
print(auction_df.columns)
auction_df.loc[auction_df['Categoría_x'] == 'Camionetas', 'Categoría_x'] = 'CAMIONETA'
auction_df['exact_merge_var'] = (auction_df['Marca_x'].astype(str) + ' '
                                        + auction_df['Macrozona_x'].astype(str) + ' '
                                        + auction_df['Categoría_x'].astype(str) + ' '
                                        + auction_df['RUT_x'].astype(str))
auction_df['exact_merge_var'] = auction_df['exact_merge_var'].str.upper()

#2.2 keep only observations that were selected in the auction stage. 
print(auction_df['Estado Final'].unique())
auction_df = auction_df[auction_df['Estado Final'] == 'ADJUDICA']


#auction_df.sort_values(by='Marca', inplace=True)
auction_df.sort_values(by='exact_merge_var', inplace=True)
#show(auction_df)
# Out:
# Index(['RUT_x', 'Nombre_x', 'Estado Anterior_x', 'Categoría_x', 'Vehículo',
#        'Macrozona_x', 'Gama_x', 'Pgm', 'Puntaje Precio_x', 'PUNTAJE OFERTA',
#        'Estado Final', 'Marca_x', 'Precio', 'Modelo', 'Versión',
#        'Precio + Despacho', 'Precio Macrozona-Gama', 'Puntaje Precio_y'],
#       dtype='object')
# ['INADMISIBLE' 'ADJUDICA' 'No Adjudica']

# %%
# 3. merge the two datasets
transac_cm_2021_df['Index'] = transac_cm_2021_df.index + 1

# Merge on 'exact_merge_var'
merged_df = transac_cm_2021_df.merge(auction_df, on='exact_merge_var', how='left', indicator=True)

# 1. Calculate the share of observations in auction_21 that are merged
share_merged = merged_df['_merge'].value_counts(normalize=True).get('both', 0)
print(f"Share of observations in auction_21 that are merged: {share_merged:.2%}")

# 2. Create a variable that counts how many matches are found in the other file
match_counts = auction_df.groupby('exact_merge_var').size()
transac_cm_2021_df['match_count'] = transac_cm_2021_df['exact_merge_var'].map(match_counts).fillna(0).astype(int)

#unmatched_df = merged_df[merged_df['_merge'] == 'left_only']
#print(unmatched_df.shape)

#show(merged_df)
# Out:
# Share of observations in auction_21 that are merged: 32.02%

# %%
# 4. keep only one obs in cases with various matches 

#4.1 create the variables to compute similarity 
#print(merged_df.columns)
merged_df['Vehículo_y'] = merged_df['Marca'].astype(str) + ' '  + merged_df['Modelo_x'].astype(str)
merged_df['Vehículo_y'] = merged_df['Vehículo_y'].str.upper()
merged_df['Vehículo'] = merged_df['Vehículo'].str.upper()


#4.2 create the similarity measure 
merged_df['Vehículo'] = merged_df['Vehículo'].fillna('').astype(str).str.upper()
merged_df['Vehículo_y'] = merged_df['Vehículo_y'].fillna('').astype(str).str.upper()
def calculate_similarity(a, b):
    return SequenceMatcher(None, a, b).ratio()
merged_df['similarity'] = merged_df.apply(
    lambda row: calculate_similarity(row['Vehículo'], row['Vehículo_y']), axis=1
)

# 4.3. For observations where match_count_x > 1, keep only the observation with the highest similarity
merged_df = merged_df.loc[
    merged_df.groupby('Index')['similarity'].idxmax()
]
#show(merged_df)

# 5. rename the merged_df 
transac_cm_2021_df = merged_df.copy()

# %% [markdown]
# ### 2023

# %% [markdown]
# import 2023 data

# %%
transac_cm_2023_path = os.path.join('..', 'interm_data',  'yearly_data', 'Transacciones', 'transacciones_cm_2023.csv')
transac_cm_2023_df = pd.read_csv(transac_cm_2023_path)
transac_cm_2023_df.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
print(f"Dimensions of transac_cm_2023_df: {transac_cm_2023_df.shape}")

transac_cm_2023_df.columns = [fix_encoding(col) for col in transac_cm_2023_df.columns]
for column in transac_cm_2023_df.select_dtypes(include=['object']).columns:
    transac_cm_2023_df[column] = transac_cm_2023_df[column].apply(fix_encoding)


transac_cm_2023_df['year'] = pd.to_datetime(transac_cm_2023_df['Fecha Envío OC']).dt.year


# Count the number of observations for each year
year_counts = transac_cm_2023_df['year'].value_counts().sort_index()
print(year_counts)

nro_counts = transac_cm_2023_df['Nro Licitación Pública'].value_counts().sort_index() 
print(nro_counts)

transac_cm_2023_df = process_prices(transac_cm_2023_df)


transac_cm_2023_df.head()
# Out:
# Dimensions of transac_cm_2023_df: (366, 45)
# year
# 2024    366
# Name: count, dtype: int64
# Nro Licitación Pública
# 2239-8-LR23    366
# Name: count, dtype: int64
# Number of problematic rows: 0
#   Nro Licitación Pública  Id Convenio Marco
# 0            2239-8-LR23          5802342.0  \
# 1            2239-8-LR23          5802342.0
# 2            2239-8-LR23          5802342.0
# 3            2239-8-LR23          5802342.0
# 4            2239-8-LR23          5802342.0
#
#                                 Convenio Marco       CodigoOC
# 0  Convenio Marco de  Adquisición de Vehículos  4062-187-CM24  \
# 1  Convenio Marco de  Adquisición de Vehículos   3577-41-CM24
# 2  Convenio Marco de  Adquisición de Vehículos  3030-177-CM24
# 3  Convenio Marco de  Adquisición de Vehículos  2381-308-CM24
# 4  Convenio Marco de  Adquisición de Vehículos   316-212-CM24
#
#                                             NombreOC Fecha Envío OC
# 0                     Orden de Compra: 4062-187-CM24     2024-03-12  \
# 1                      Orden de Compra: 3577-41-CM24     2024-03-14
# 2                CAMIONETA JMC PARA DEPTO. DE SALUD      2024-03-14
# 3  ADQUISICIíN DE 01 CAMIONETA TODO TERRENO PARA...     2024-03-18
# 4                      Orden de Compra: 316-212-CM24     2024-03-20
#
#              EstadoOC Proviene de Gran Compra  idGranCompra
# 0  Recepcion Conforme                      No           NaN  \
# 1            Aceptada                      No           NaN
# 2            Aceptada                      No           NaN
# 3            Aceptada                      No           NaN
# 4            Aceptada                      No           NaN
#
#                         Especificación del Comprador  ...
# 0  (2042525) CAMIONETA MAXUS T60 E6 GL 4X4 MT 202...  ...  \
# 1  (2041399) CAMIONETA TOYOTA HILUX DX 2.4 4X4 MT...  ...
# 2  (2041534) CAMIONETA JMC VIGUS NEW WORK 4X4 MT ...  ...
# 3  (2041392) CAMIONETA TOYOTA HILUX DX 2.4 4X4 MT...  ...
# 4  (2041566) CAMIONETA JMC VIGUS NEW PLUS 4X4 MT ...  ...
#
#                Nombre Empresa Comuna del Proveedor Región del Proveedor
# 0     AUTOMOTRIZ SERVIMAQ SPA                  NaN                  NaN  \
# 1         BRUNO FRITSCH S.A.                   NaN                  NaN
# 2  AUTOMOTRIZ CORDILLERA S.A.                  NaN                  NaN
# 3         BRUNO FRITSCH S.A.                   NaN                  NaN
# 4  AUTOMOTRIZ CORDILLERA S.A.                  NaN                  NaN
#
#                                        Observaciones
# 0  Orden de Compra codigo: 4062-187-CM24 dirigida...  \
# 1  Orden de Compra codigo: 3577-41-CM24 dirigida ...
# 2  CAMIONETA JMC VIGUS NEW WORK 4X4 MT 2024 PARA ...
# 3  ADQUISICIíN DE 01 CAMIONETA TODO TERRENO PARA...
# 4  Orden de Compra codigo: 316-212-CM24 dirigida ...
#
#                                        Forma de Pago Orgcode_Comprador
# 0  30 dias contra la recepcion conforme de la fac...              4982  \
# 1  30 dias contra la recepcion conforme de la fac...              4497
# 2  30 dias contra la recepcion conforme de la fac...              3978
# 3  30 dias contra la recepcion conforme de la fac...              3373
# 4  30 dias contra la recepcion conforme de la fac...              1313
#
#    Entcode_Comprador  Orgcode_Proveedor Entcode_Proveedor  year
# 0             120001             100329             97856  2024
# 1             115285              24507             24823  2024
# 2             113252              32639             32414  2024
# 3              86872              24507             24823  2024
# 4               7233              32639             32414  2024
#
# [5 rows x 46 columns]

# %% [markdown]
# clean the 2023 data

# %%
#not necessary to do anything with Convenio Marco, since there is no subletting in 2023
convenio_aux = transac_cm_2023_df['Convenio Marco'].unique()
#print(convenio_aux)

# clean based on the 'Tipo de Producto' column
counts = transac_cm_2023_df['Tipo de Producto'].value_counts()
#print(counts)
to_drop = ['RETROEXCAVADORA','BUS PESADO' ]
transac_cm_2023_df = transac_cm_2023_df[
    ~transac_cm_2023_df['Tipo de Producto'].isin(to_drop)
]


# Normalize text by removing accents
transac_cm_2023_df['Tipo de Producto'] = transac_cm_2023_df['Tipo de Producto'].apply(
    lambda x: unicodedata.normalize('NFKD', x).encode('ASCII', 'ignore').decode('ASCII')
)

# Step 1: Create a mapping dictionary for all variations
replacements = {
    'SEDiN': 'SEDÁN',
    'FURGiN' : 'FURGÓN'
}

# Step 2: Replace all variations using the mapping
transac_cm_2023_df['Tipo de Producto'] = transac_cm_2023_df['Tipo de Producto'].replace(replacements)

print( transac_cm_2023_df['Tipo de Producto'].value_counts())



# check that the data makes sense and is clean
counts = transac_cm_2023_df['Tipo de Producto'].value_counts()
print(counts)
summary_precio_unitario = transac_cm_2023_df['Precio Unitario'].describe()
print(summary_precio_unitario)
# Out:
# Tipo de Producto
# CAMIONETA    211
# SUV           83
# MINIBUS       31
# SEDÁN         21
# FURGÓN         8
# CARGO          8
# Name: count, dtype: int64
# Tipo de Producto
# CAMIONETA    211
# SUV           83
# MINIBUS       31
# SEDÁN         21
# FURGÓN         8
# CARGO          8
# Name: count, dtype: int64
# count    3.620000e+02
# mean     2.091208e+07
# std      6.801193e+06
# min      6.844800e+06
# 25%      1.642131e+07
# 50%      2.087100e+07
# 75%      2.573550e+07
# max      5.243080e+07
# Name: Precio Unitario, dtype: float64

# %% [markdown]
# ### Join the purchases from all the different FAs

# %%
# Concatenate the dataframes vertically
transac = pd.concat([transac_cm_2017_df, transac_cm_2021_df, transac_cm_2023_df], axis=0)

# Reset the index if needed
transac_df = transac.reset_index(drop=True)
print(transac_df.columns)
print(f"Dimensions of transac_df: {transac_df.shape}")
transac_df.head(2)


output_path = os.path.join('..', 'interm_data', 'yearly_data', 'Transacciones')
transac_df.to_csv(os.path.join(output_path, 'joined_transac.csv'), index=False)
# Out:
# Index(['Nro Licitación Pública', 'Id Convenio Marco', 'Convenio Marco',
#        'CodigoOC', 'NombreOC', 'Fecha Envío OC', 'EstadoOC',
#        'Proviene de Gran Compra', 'idGranCompra',
#        'Especificación del Comprador', 'IDProductoCM', 'Producto',
#        'Nombre Producto ONU', 'Tipo de Producto', 'Marca', 'Modelo',
#        'Precio Unitario', 'Cantidad', 'TotaLínea(Neto)', 'Moneda',
#        'Monto Total OC Neto', 'Descuento Global OC', 'Cargos Adicionales OC',
#        'Subtotal OC', 'Impuestos', 'Monto Total OC', 'Rut Unidad de Compra',
#        'Unidad de Compra', 'Razón Social Comprador', 'Dirección Unidad Compra',
#        'Comuna Unidad Compra', 'Región Unidad de Compra', 'Institución',
#        'Sector', 'Rut Proveedor', 'Nombre Proveedor Sucursal',
#        'Nombre Empresa', 'Comuna del Proveedor', 'Región del Proveedor',
#        'Observaciones', 'Forma de Pago', 'Orgcode_Comprador',
#        'Entcode_Comprador', 'Orgcode_Proveedor', 'Entcode_Proveedor', 'year',
#        'Modelo_x', 'Macrozona', 'exact_merge_var', 'Index', 'RUT_x',
#        'Nombre_x', 'Estado Anterior_x', 'Categoría_x', 'Vehículo',
#        'Macrozona_x', 'Gama_x', 'Pgm', 'Puntaje Precio_x', 'PUNTAJE OFERTA',
#        'Estado Final', 'Marca_x', 'Precio', 'Modelo_y', 'Versión',
#        'Precio + Despacho', 'Precio Macrozona-Gama', 'Puntaje Precio_y',
#        '_merge', 'Vehículo_y', 'similarity'],
#       dtype='object')
# Dimensions of transac_df: (4282, 71)

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Remove the observations that are not purchases of cars, but rather maintenance or leases.

# %% [markdown]
# Do some cleaning based on Tipo de Producto (this is harmless, already did it for each file)

# %%
#%reset -f
output_path = os.path.join('..', 'interm_data', 'yearly_data', 'Transacciones')

# %%
df = pd.read_csv(os.path.join(output_path, 'joined_transac.csv'))

print(f"Shape of transac_df: {df.shape}")
tipo_producto_values = df['Tipo de Producto'].unique()
print(tipo_producto_values)

# Create a list of product types to drop
drop_product_types = ['ARRIENDO', 'MANTENCIÓN', 'OFICINAS', 'RODILLO',
                      'PESADO', 'BULL', 'TRASLADO', 'EXCAVA', 'TRACTO', 'ADORA', 'TOLVA', 'CARGADOR', 
                      'VEHÍCULOS POLICIALES', 'AMBULANCIAS']

# Create a regex pattern to match any of the product types in the list
pattern = '|'.join(drop_product_types)

# Drop observations where 'Tipo de Producto' contains an element of the list
drop_mask = ~df['Tipo de Producto'].str.contains(pattern, case=False, na=False)
df = df[drop_mask]
print(f"Shape of transac_df after dropping specified product types: {df.shape}")
# Out:
# Shape of transac_df: (4282, 71)
# ['MINIBUS' 'SUV' 'CAMIONETA' 'SEDÁN' 'FURGÓN' 'HATCHBACK' 'CAMIÓN LIVIANO'
#  'VEHÍCULOS POLICIALES' 'AMBULANCIAS' 'CARGO']
# Shape of transac_df after dropping specified product types: (3979, 71)

# %% [markdown]
# Do some cleaning based on 'Convenio Marco'  (this is harmless, already did it for each file)

# %%
print(f"Shape of transac_df: {df.shape}")
tipo_convenio = df['Convenio Marco'].unique()
print(tipo_convenio)

avg_precio = df.groupby('Convenio Marco')['Precio Unitario'].mean()
print(avg_precio)


# Remove products from FA of heavy and medium heavy vehicles in the Convenio Marco column
heavy_mask = ~df['Convenio Marco'].str.contains('Compra de Vehículos Pesados y Maquinarias', na=False)
df = df[heavy_mask]
print(f"Shape of transac_df: {df.shape}")
# Out:
# Shape of transac_df: (3979, 71)
# ['Compra de Vehículos Livianos y Medianos'
#  'CM Adquisición de Vehículos SUV y Camionetas (Magento)'
#  'CM Adquisición de Vehículos SUV y Camionetas'
#  'Convenio Marco de  Adquisición de Vehículos']
# Convenio Marco
# CM Adquisición de Vehículos SUV y Camionetas              2.001232e+07
# CM Adquisición de Vehículos SUV y Camionetas (Magento)    1.683101e+07
# Compra de Vehículos Livianos y Medianos                   1.487118e+07
# Convenio Marco de  Adquisición de Vehículos               2.091208e+07
# Name: Precio Unitario, dtype: float64
# Shape of transac_df: (3979, 71)

# %%
tipo_producto_counts = df['Convenio Marco'].value_counts()
print(tipo_producto_counts)
# Out:
# Convenio Marco
# Compra de Vehículos Livianos y Medianos                   2546
# CM Adquisición de Vehículos SUV y Camionetas               951
# Convenio Marco de  Adquisición de Vehículos                362
# CM Adquisición de Vehículos SUV y Camionetas (Magento)     120
# Name: count, dtype: int64

# %%
#share of 2021 obs for whicch we have auction data
grouped = df.groupby(['Nro Licitación Pública', '_merge']).size().reset_index(name='count')
grouped['total'] = grouped.groupby('Nro Licitación Pública')['count'].transform('sum')
grouped['share'] = grouped['count'] / grouped['total']
print(grouped)
# Out:
#   Nro Licitación Pública     _merge  count  total     share
# 0            2239-5-LR21       both    296   1071  0.276377
# 1            2239-5-LR21  left_only    775   1071  0.723623

# %%
print(df.value_counts('Nro Licitación Pública'))
# Out:
# Nro Licitación Pública
# 2239-4-LR17    2546
# 2239-5-LR21    1071
# 2239-8-LR23     362
# Name: count, dtype: int64

# %% [markdown]
# ## Pair the variables of the model with the variables of the data
#
#     'IDProductoCM' -> j
#     To create product characteristics: 'Tipo de Producto', 'Marca', 'Nombre Producto ONU'
#     'Precio Unitario'-> net not including taxes, just changes the scale of the price parameter
#     'Rut Unidad de Compra' -> i
#     To create the groups (k):  'Región Unidad de Compra', 'Sector'
#      'year' -> t
#
#      'Modelo'-> to do the match with the product characteristics.
#
# Variables not directly paired but which could be useful:
#     'Nro Licitación Pública', 'Id Convenio Marco', 'Convenio Marco', 'CodigoOC', 'Fecha Envío OC', 'Cantidad', 'Rut Proveedor',
#     'Nombre Proveedor Sucursal', 'Orgcode_Comprador', 'Entcode_Comprador',

# %%
# Variables to keep - directly paired with model
model_vars = ['IDProductoCM', 'Modelo',  'Tipo de Producto', 'Marca', 'Nombre Producto ONU',
              'Precio Unitario', 'Rut Unidad de Compra', 'Región Unidad de Compra',
              'Sector', 'year']

# Additional useful variables
extra_vars = ['Nro Licitación Pública', 'Convenio Marco', 'CodigoOC',
              'Fecha Envío OC', 'Cantidad', 'Rut Proveedor',
              'Nombre Proveedor Sucursal']

#extra_vars2 = list(auction_df.columns)
#elements_to_remove = ['RUT_x', 'Nombre_x', 'Estado Anterior_x' ]
#extra_vars2 = [x for x in extra_vars2 if x not in elements_to_remove]
extra_vars2 = [ 'Vehículo', 'Macrozona_x', 'Gama_x', 'Pgm', 'Puntaje Precio_x', 'PUNTAJE OFERTA', 
               'Marca_x', 'Precio', 'Modelo', 'Versión', 'Precio + Despacho', 'Precio Macrozona-Gama', 'Puntaje Precio_y', 'exact_merge_var']

# Create new dataframe with only the specified columns
df = df[ model_vars + extra_vars + extra_vars2]

print(f"Dimensions of transac_df: {df.shape}")
# Out:
# Dimensions of transac_df: (3979, 31)

# %% [markdown]
# store the data

# %%
df.to_csv(os.path.join(output_path, 'joined_cleaned_transac.csv'), index=False)

# %%
print(df.value_counts('year'))
# Out:
# year
# 2019    898
# 2018    767
# 2023    721
# 2020    504
# 2024    428
# 2021    384
# 2022    277
# Name: count, dtype: int64

# %% [markdown]
# ### Answer the following questions
# - are firms selling multiple products? Yes
# - What is the share of firms for which we have the auction data? 28%
# - what shar of firms have a binding price ceiling?

# %%
# Group by supplier and count unique products
supplier_products = df.groupby('Nombre Proveedor Sucursal')['IDProductoCM'].nunique().sort_values(ascending=False)
print(supplier_products)

n_unique_products = df['IDProductoCM'].nunique()
print(f"Total number of unique products: {n_unique_products}")
# Out:
# Nombre Proveedor Sucursal
# Salinas y Fabres S.A.                            296
# SALAZAR ISRAEL                                   204
# Automotores Gildemeister CAMIONES                185
# Dercosa                                          143
# BRUNO FRITSCH S.A.                               113
# Maritano y Ebensperger Ltda.                      92
# Mediterraneo Automotores SA                       85
# PORTILLO S A - Casa Matriz                        59
# Kovacs SpA Seminario 385 Providencia              46
# COMERCIAL ANFRUNS Y COMPAíIA SPA                 46
# POMPEYO CARRASCO Y CIA. LTDA.                     45
# Anfruns Motors SPA                                41
# AUTOMOTORA MELHUISH SPA                           38
# Comercial Motores de los Andes SpA                36
# Curifor Coquimbo                                  34
# Derco SPA                                         33
# DIFOR CHILE SOCIEDAD ANONIMA                      31
# Automotriz Tecnosur Limitada                      29
# PORSCHE CHILE SPA                                 27
# Kovacs SpA                                        21
# PIAMONTE S.A.                                     18
# Comasa Movicenter                                 17
# HVCCSA                                            16
# KIA CHILE SPA                                     15
# Guillermo Morales Ltda                            12
# Convenio Marco                                    12
# SERVIMAQ SPA                                      10
# CONVERSIONES SAN JOSE - Vehículos Especiales       8
# Ing.de Serv.Automotriz Macias y Cia.Ltda           7
# Automotora Comercial Costabal y Echenique S.A      7
# ESTEBAN GUIC Y CIA LTDA                            6
# DERCOMAQ SPA                                       6
# AUTOMOTRIZ PORTILLO S.A. - Casa Matriz             6
# KIA                                                5
# Cidef Comercial S.A.                               5
# MARCELO FRONZA Y CIA LTDA                          5
# Honda Motor de Chile S.A.                          4
# Automotriz For Center SA                           4
# CIDEF S.A                                          4
# Cecor S.A.                                         4
# PAULINA ANDREA                                     3
# AUTOMOTORA INALCO S A                              3
# KIA CHILE                                          3
# AUTOMOTRIZ GUILLERMO MORALES LIMITADA              3
# COVEMIN                                            2
# Salinas y Fabres S.A. - Casa Matriz                2
# Automotores Gildemeister - Casa Matriz             2
# Autocar                                            2
# AUTOMOTORA MELHUISH RETAIL SPA                     2
# Salinas y Fabres S.A.- Sucursal Rondizzoni         2
# COMERCIALIZADORA DITEC AUTOMOVILES S A             1
# BUSES                                              1
# Frontera                                           1
# AUTOMOTRIZ PORTILLO SUR LTDA                       1
# SALAZAR ISRAEL Temuco                              1
# E. Kovacs SpA                                      1
# SUBARU CHILE S.A.                                  1
# AUTOMOTORES FRANCO CHILENA  S.A                    1
# MARITANO Y EBENSPERGER LTDA                        1
# Salinas y Fabres S.A. - Sucursal Punta Arenas      1
# Name: IDProductoCM, dtype: int64
# Total number of unique products: 1376

# %%
print(df.columns)
price_list = [ 'Precio Unitario', 'Pgm', 'Puntaje Precio_x', 'Precio', 'Precio + Despacho', 'Precio Macrozona-Gama']

df_filtered = df[df['Nro Licitación Pública'] == '2239-5-LR21']

df_filtered = df_filtered[price_list]
# Out:
# Index(['IDProductoCM', 'Modelo', 'Tipo de Producto', 'Marca',
#        'Nombre Producto ONU', 'Precio Unitario', 'Rut Unidad de Compra',
#        'Región Unidad de Compra', 'Sector', 'year', 'Nro Licitación Pública',
#        'Convenio Marco', 'CodigoOC', 'Fecha Envío OC', 'Cantidad',
#        'Rut Proveedor', 'Nombre Proveedor Sucursal', 'Vehículo', 'Macrozona_x',
#        'Gama_x', 'Pgm', 'Puntaje Precio_x', 'PUNTAJE OFERTA', 'Marca_x',
#        'Precio', 'Modelo', 'Versión', 'Precio + Despacho',
#        'Precio Macrozona-Gama', 'Puntaje Precio_y', 'exact_merge_var'],
#       dtype='object')

# %%
# Only calculate for observations where neither 'Precio Unitario' nor 'Precio' is missing
df_filtered.loc[df_filtered['Precio Unitario'].notna() & df_filtered['Precio'].notna(), 'binding_ceiling'] = (
    df_filtered['Precio Unitario'] > 1.1*df_filtered['Precio']
).astype(int)
shares = df_filtered['binding_ceiling'].value_counts(normalize=True, dropna=True) * 100

print("Shares for 'binding_ceiling':", shares)

 
# Only calculate for observations where neither 'Precio Unitario' nor 'Precio' is missing
df_filtered['Precio + Despacho'] = pd.to_numeric(df_filtered['Precio + Despacho'], errors='coerce')
df_filtered.loc[df_filtered['Precio Unitario'].notna() & df_filtered['Precio'].notna(), 'binding_ceiling2'] = (
    df_filtered['Precio Unitario'] > 1.1*df_filtered['Precio + Despacho']
).astype(int)
shares = df_filtered['binding_ceiling2'].value_counts(normalize=True, dropna=True) * 100

print("Shares for 'binding_ceiling':", shares)
# Out:
# Shares for 'binding_ceiling': binding_ceiling
# 1.0    96.283784
# 0.0     3.716216
# Name: proportion, dtype: float64
# Shares for 'binding_ceiling': binding_ceiling2
# 1.0    95.27027
# 0.0     4.72973
# Name: proportion, dtype: float64

# %%
# 1. Share of observations where 'Precio Unitario' is greater than 'Precio'
share_precio_unitario_greater = (df_filtered['Precio Unitario'] > df_filtered['Precio']).mean()
share_precio_greater = (df_filtered['Precio Unitario'] <= df_filtered['Precio']).mean()

print(f"Share where 'Precio Unitario' > 'Precio': {share_precio_unitario_greater:.2%}")
print(f"Share where 'Precio' >= 'Precio Unitario': {share_precio_greater:.2%}")

# 2. Average difference when 'Precio Unitario' is less than 'Precio'
average_difference = (df_filtered['Precio'] - df_filtered['Precio Unitario']).mean()

print(f"On average, 'Precio Unitario' is {average_difference:.2f} lower than 'Precio'")
#show(df_filtered)
# Out:
# Share where 'Precio Unitario' > 'Precio': 27.17%
# Share where 'Precio' >= 'Precio Unitario': 0.47%
# On average, 'Precio Unitario' is -6151351.29 lower than 'Precio'

# %% [markdown]
# ## Merge product characteristics (still to do, Pablo has to send me the code)

# %% [markdown]
# 1. take transac_df and obtain a dataset with model-id where model is created in the same way pablo created model to do the web-scraping
# 2. do the merge with the web-scraped data of pablo to obtain a dataset with model-id-prod_char
# 3. decrease number of models (e.g rav4 and rav4 mt are the same car) to have dataset  model-id-prod_char-id2 where id2 is a more coarse measure of id.
# 4. merge with purchases according to id
# 5. estimate demand based on id2

# %%
df = pd.read_csv(os.path.join(output_path, 'joined_cleaned_transac.csv'))

# %%
# Get value counts as a Series
modelos = df.value_counts('Modelo')

# Iterate through the key-value pairs using .iteritems()
for modelo, count in modelos.items():
    print(f'{modelo}: {count}')
# Out:
# H-1 TQ MB 2.5 CRDI MT 12S FL: 144
# NP300 DC SE 2.3D MT 4WD: 92
# HILUX 2.4 4X4 MT DX: 57
# HILUX 4X4 2.4 MT DX: 35
# NEW RAV4 LE 6MT AWD: 32
# NP300 DC SE 2.3D MT: 31
# T60 2.8L DX 4X4: 30
# HILUX 2.4 4X4 MT SR: 29
# H-1  MB 2.5 CRDI 6M/T GLS 10S AC 2AB ABS: 28
# NEW DMAX CC 2.5TD 4WD: 27
# L200 4X4 KATANA CRM: 27
# COLORADO LT MT 2.8TD 4WD M: 26
# RAV4 LUJO 2.0 4X4 MT: 26
# HILUX DX 2.4 4X4 MT 2024: 25
# HILUX 2.4 4X2 MT DX (WIDE): 25
# NP300 DC XE 2.3D MT 4WD: 23
# NAVARA CD SE 4X4: 23
# SAIL NB 1.5L LS: 22
# NP300 DC S 2.5 MT: 21
# NAVARA NP300 DC SE 2.3D MT: 21
# T60 DX E6 4X4 MT 2024: 20
# TUCSON TL 2.0 MT 4WD PLUS FL: 20
# H-1 TQ MB 2.5 CRDI MT 10S PE: 20
# FRONTIER D/C 2,5 6MT SR DELUXE: 20
# PORTER 2.5 CRDI 6M/T GL DC 2AB AC: 20
# FRONTIER D/C LX 2.5L AV AB MT 2024: 19
# L200 4X4 KATANA CRT: 19
# TRANSIT MINIBUS 17+1: 19
# NAVARA NP300 DC SE 2.3D MT 4WD: 18
# FRONTIER D/C 2.5L 6MT: 17
# D-MAX CC 2.5TD 4WD III: 17
# WINGLE 5 GASOLINA 4X2 ELITE: 17
# L200 4X2 WORK CR WF: 16
# X-TRAIL SENSE CVT 4WD 2F: 16
# DMAX CC 2.5TD 4WD III: 15
# WIDE S-LONG BUS 2.5D MT: 15
# NP300 DC XE 2.5 MT: 15
# TUCSON TL 2.0 MT PLUS FL: 15
# NP300 DC XE 2.3D MT: 14
# HILUX 2.7 4X2 MT SR GASOLINA: 14
# T60 DX 4X4: 14
# BT-50 DOBLE CABINA 2.2 SDX 6MT 4X4 DIESEL (E5): 14
# NEW RANGER DSL XL 4X4 2.2L: 14
# HILUX 2.4 4X2 MT SR: 14
# AMAROK TRENDLINE 4MOTION: 12
# VERSA SENSE MT: 12
# NEW D-MAX CC 2.5TD 4WD: 12
# NP300 DC LE 2.3D MT 4WD: 12
# NAVARA CD SE 4X2: 11
# 4RUNNER 4X4 SR5 CONTROL VOLANTE: 11
# TRAVELLER BUSINESS L3 9 ASIENTOS 2.0 BLUEHDI 150HP MT: 11
# T60 DX/4X4 : 11
# WINGLE 7 4X2 ELITE 2024: 10
# AZERA IG 3.0 AT PREMIUM: 9
# HILUX DX DC 2.4 4X4 MT 2024: 9
# STARIA MB 2.2 CEDI 11P 2024: 9
# COLORADO 2.8TD LTZ MT 4WD: 9
# G10 MINIBUS 9+1 E6 2024: 9
# FRONTIER D/C 2,5 6MT SR: 9
# 4X2 2.4 MT DX: 9
# NAVARA NP300 DC XE 2.3D MT: 9
# GRAND VITARA 1.6 GLX SPORT: 9
# COLORADO 2.8 CTDI 4X4 LTZ MT: 9
# HILUX 2.4L DX CD 4X4: 8
# QASHQAI SENSE MT: 8
# HILUX DX 2.4 4X2 MT 2024: 8
# SANTA FE TM 2.2 CRDI E6 AT 4WD VALUE: 8
# NAVARA DC SE 2.3D 4X4 MT 2024: 8
# NEW MAZDA6 V 2.0 6AT (CUERO NEGRO): 8
# NUEVO YARIS SEDAN GLI MT     : 8
# ACCENT RB SDN 1.4 6M/T GL 2AB AC: 8
# NEW D-MAX CC 2.5TD: 8
# NP300 DC LE 2.3D AT 4WD: 8
# PORTER 2.5 CRDI 6M/T GLS CAMIONETA 2AB AC: 8
# GRAND I-10 BA SDN MT GLS 2AB AC ABS PE: 8
# RUSH LEI 4X4 MEC: 8
# OUTLANDER 4X4 GLX AT: 8
# C-ELYSÉE 1.6 HDI 92 BVM FEEL: 7
# MUSSO GRAND GLX 2.2TD 4X2 AT 2024: 7
# PORTER 2.5 CRDI 6M/T GL DC 2AB: 7
# VIGUS NEW WORK 4X4 MT 2024: 7
# TUCSON NX4 2.0 MT PLUSÂ  2024: 7
# H-1 TQ MB 2.5 CRDI MT 9S FL: 7
# L200 4X4 KATANA CRM 4X4: 7
# NV350 WIDE S-LONG BUS 2.5D MT: 7
# COLORADO LT AT 2.8TD 4WD M: 7
# GRAND NOMADE 2.4 GLX NAV: 7
# X-TRAIL SENSE 2ROW 4X4: 7
# FRONTIER D/C 2.5L 6MT DELUXE: 6
# L200 4X2 WORK CR: 6
# TUCSON TL 2.0 CRDI MT PLUS FL: 6
# DMAX CC 2.5TD III: 6
# NUEVA L200 4X4 KATANA CRT: 6
# HILUX SR 2.4 4X4 MT 2024: 6
# QUBO DYNAMIC: 6
# GRAND I-10 BA SDN MT GL 2AB AC PE: 6
# T60 DX E6 4X2 MT 2024: 6
# MONTERO SPORT 4X4 MT: 6
# T60 E6 GL 4X4 MT 2024: 6
# BT-50 DOBLE CAB 2.2 SDX 6MT 4X4 DIESEL (E5): 6
# NEW DMAX CC 2.5TD 2WD: 6
# NV350 2.5L PASAJEROS 15: 6
# TUCSON NX4 2.0 4WD AT PLUSÂ  2024: 6
# PICK UP REFRESH DC 4X4 MT WORK: 5
# NEW MAZDA6 GT 2.5 6AT GPS (CUERO NEGRO): 5
# NEW RANGER DSL XLS 4X4 3.2L: 5
# ALL NEW CX-5 R 2.0 AWD 6AT: 5
# VERNA CB 1.4 MT PLUS: 5
# X-TRAIL EXCLUSIVE CVT 4WD: 5
# NUEVO YARIS GLI MT: 5
# HILUX 4X4 2.4 MT SR: 5
# TRACKER II 1.8 FWD LS MT: 5
# NUEVA L200  4X2 WORK CR: 5
# ACCENT BN7I 1.5 PLUS 2024: 5
# SUNRAY 1.9L GREEN JET 11+1 PAS: 5
# NAVARA CD XE 4X4: 5
# URBAN 1042 DC MT PLATAFORMA 2024: 5
# L200 KATANA CRM 4X4: 5
# WINGLE 5 DIESEL 4X4 DC LUX: 5
# MIDI DOBLE CABINA: 5
# T60 DX 4X2: 5
# SANTA FE TM 2.4 MT PLUS: 5
# TUCSON NX4 2.0 AT PLUSÂ  2024: 5
# SANTA FE DM  WGN 2.4 6M/T GLS PE: 5
# SPACETOURER 2.0 BLUEHDI 150 S&S BVM6 BUSINESS XL: 5
# FRONTIER P/UP LX 2.5L AV AB MT 2024: 5
# H-350 FURGON SOLATI CARGO VAN: 4
# G10 9+1: 4
# DUSTER ZEN 2,0 6 MT 4 X 4: 4
# GRAND I-10 BA SDN  MT GLS 2AB AC ABS PE: 4
# GRAND AVENUE 4X4 MT 2024: 4
# T60 2.8L DX 4X2: 4
# HILUX 4X2 2.4 MT DX: 4
# T60 DX 4X2 MT 2024: 4
# GRAND NOMADE 2.4 2WD AT GLX SPORT: 4
# T60 GL/4X2 : 4
# TRAVELLER BUSINESS L3 9P BLUEHDI 145 2024: 4
# DUSTER ZEN TECH 2,0L 6MT 4X2: 4
# VIGUS NEW WORK 4X2 MT 2024: 4
# FRONTIER P/UP 2.5L 6MT: 4
# NEW RAV4 LE 6MT 2WD: 4
# N400 MAX II 1.5L MT AC: 4
# BT-50 DOBLE CABINA 2.2 SDX 6MT 4X4 DIESEL: 4
# MONTERO SPORT 2.4 DIESEL 4X4 MT: 4
# SOLATI H350 : 4
# SOLATI H350 PASAJEROS: 4
# SOLUTO LX 1.4L 5MT G LL 2024: 4
# AZERA IG 3.0 AT LIMITED: 4
# ATOS 1.1L PLUS: 4
# REFINE M4 EXECUTIVE 11 ASIENTOS: 4
# SAIL NB 1.5 LS ABS L: 4
# NUEVA AMAROK TRENDLINE 4MOTION MT: 4
# RAV4 2.0L LE AUT: 4
# L200 KATANA CRT 4X4: 4
# ASX 4X2 MT: 4
# L200 4X2 KATANA CR: 4
# CROSSTREK 2.0I AWD CVT AT 2024: 4
# NV350 BUS WIDE S-LONG 2.5D MT: 4
# AMAROK TRENDLINE 4X2: 4
# STARIA MB 2.2 CRDI 4WD 9P LUXURY 2024: 4
# KICKS SENSE MT 2024: 4
# KICKS ADVANCE MT 2024: 4
# JUMPER L3H2 BLUEHDI 163 S&S BVM6: 4
# YARIS SEDAN GLI E MT: 4
# SANTA FE DM  WGN 2.4 6A/T GLS PE: 4
# SANTA FE DM  WGN 2.4 6A/T 4WD GLS FULL PE: 4
# CRETA GS 1.6 MT PLUS FL: 4
# CRETA GS 1.6 MT VALUE FL: 4
# POER 4X2 ELITE PANT 2024: 4
# POER 4X4 ELITE PANT 2024: 4
# RUSH 1.5 XLI AT: 3
# T60 GL 4X4: 3
# RAV4 XLE 2.5 4X2 CVT HV AT 2024: 3
# NEW RAV4 LE MT 4WD: 3
# REFINE M4 EXECUTIVE 9 ASIENTOS: 3
# NEW V80 FL MINIBUS 15+1 E5 DLX: 3
# T8 CE COMFORT 2.0T 4X2 MT 2024: 3
# RANGER XL 4X4 DIESEL: 3
# RAM V700 CITY DIESEL: 3
# PICK UP REFRESH DC 4X2 MT FULL: 3
# PICK UP REFRESH DC 4X2 MT WORK: 3
# TEPEE OUTDOOR NUEVA ALLURE 1.6 HDI 92HP 7 ASIENTOS: 3
# GRAND VITARA 2.4 GLX NAV: 3
# HILUX SR 2.7 4X2 MT 2024: 3
# SAIL NB 1.5L: 3
# SANTA FE DM  WGN 2.2 CRDI 6M/T GLS PE: 3
# HILUX SR 2.8 4X4 MT 2024: 3
# HILUX SRV 2.8 4X4 AT 2024: 3
# HR-V LX 1.8 CVT: 3
# IONIQ EV GLS: 3
# JIMNY 1.5 GLX: 3
# SUNRAY 11+1: 3
# L-200 2.4L KATANA CRT 4X4: 3
# T6 2.0L COMFORT 4X2 DIESEL: 3
# L200 DAKAR MT: 3
# HILUX 2.4L DX CD 4X2: 3
# L200 WORK CR 4X2: 3
# T6 DIESEL 4X4 COMFORT SMART: 3
# LAND CRUISER PRADO VX-L LIMITED: 3
# SPACETOURER XL BLUEHDI 150 S&S BVM6 BUSINESS: 3
# SPACETOURER 2.0 XL BLUEHDI 150 S&S BVM6 BUSINESS: 3
# SONATA LF HEV AT PREMIUM: 3
# SANTA FE TM 2.4 AT 4WD VALUE: 3
# NAVARA NP300 DC S 2.5 MT: 3
# NAVARA NP300 DC XE 2.3D MT 4WD: 3
# SANTA FE TM 2.2 CRDI E6 MT PLUS: 3
# PORTER  2.5 CRDI 6M/T GL DC 2AB AC: 3
# BT-50 DOBLE CAB 2.2 SDX HIGH 6MT 4X4 DIESEL (E5): 3
# BERLINGO MULTISPACE 1.6 HDI 92 BVM FEEL: 3
# YARIS 1.5L GLI: 3
# WINGLE5 2.2L ELITE GASOLINA: 3
# V80 MINIBUS 12+1: 3
# 700 SLT CD: 3
# WINGLE7 2.0L ELITE 4X4: 3
# VITARA II 1.6 4WD GLS: 3
# D60 LUXURY 7DCT 4X2 AT 2024: 3
# COROLLA XEI MT: 3
# D-MAX CC 2.5TD III: 3
# ACTYON SPORTS 4X2 MEC NAS610AA: 3
# ACTYON SPORTS 2.2 4X4 FULL MT 6AS712: 3
# TRANSIT MINIBÚS: 3
# X-TRAIL SENSE CVT: 3
# ELANTRA AD 1.6 MT PREMIUM FL: 3
# TUCSON TL 2.0 CRDI E6 AT VALUE FL: 3
# TUCSON TL  2.0 MT 4WD VALUE: 3
# FORTUNER SR5 4X4 TDI 2.8L: 3
# BALENO 1.4 GLS: 3
# VAN 700 RAPID ST AA: 3
# VAN 1000 CARGO CORTO: 3
# FRONTIER P/UP 2,5 6MT SR: 3
# VERNA CB 1.4 MT SEL: 3
# COLORADO 2.8 CTDI LTZ AT: 3
# 4RUNNER 4X4 LIMITED : 3
# X-TRAIL EXCLUSIVE M-CVT 4WD: 3
# TUCSON TL 2.0 CRDI E6 AT PLUS FL: 3
# COROLLA XEI 2.0 MT: 3
# VERSA SENSE MT 2024: 3
# NAVARA NP300 DC XE 2.5 MT: 2
# SANTA FE DM  WGN 2.4 6A/T 4WD GLS PE: 2
# BERLINGO C HDI 92 BVM: 2
# WINGLE 5 DIESEL 4X2 CS LUX: 2
# WINGLE 5 DIESEL 4X2 DC LUX: 2
# BOXER DOBLE CABINA L4 2.0 BLUEHDI 160 HP: 2
# BERLINGO MULTISPACE XL 1.6 BLUEHDI 100 BVM 7 P: 2
# NAVARA NP300 DC LE 2.3D MT 4WD: 2
# AMAROK TRENDLINE 4 MOTION: 2
# NAVARA DC SE 2.3D 4X2 MT 2024: 2
# BERLINGO MULTISPACE XL 1,6 BLUEHDI 100 S&S: 2
# AZERA IG  3.0 AT PREMIUM: 2
# SANTA FE TM 2.2 CRDI E6 AT PLUS: 2
# NAVARA NP300 2.3L XE 4X4 DC AUDIO: 2
# NAVARA NP300 2.3L SE 4X4 DC: 2
# TIGUAN TDI AT COMFORLINE 150HP 4 MOTION: 2
# NAVARA CD  LE AT 4X4: 2
# BT-50 DOBLE CAB 2.2 SDX 6MT 4X2 DIESEL (E5): 2
# COLORADO LT 4X4 MT 2024: 2
# L200 DAKAR HIGH POWER MT: 2
# CARRY PICK UP: 2
# SPIN II 1.8L PREMIER MT: 2
# L200 WORK CR 4X2 SC: 2
# LEAF: 2
# VIGUS NEW PLUS 4X2 MT 2024: 2
# SPACETOURER BLUEHDI 150 S&S BVM6 BUSINESS TALLA XL 2024: 2
# VIGUS NEW PLUS 4X4 MT 2024: 2
# MARCH SPORT DRIVE AC: 2
# MARCH SPORT II DRIVE AC: 2
# CAMRY HYBRID: 2
# SOLATI PASAJEROS: 2
# MONTANA 1.2 T LT MT 2024: 2
# BT-50 DOBLE CABINA 2.2 SDX HIGH 6MT 4X4 DIESEL (E5): 2
# SENTRA  SENSE MT: 2
# T8 XE ADVANCE 2.0T 4X4 MT 2024: 2
# JIMNY 1.5L GLX: 2
# T90 E6 4X4 AT 2024: 2
# SUNRAY 13+1: 2
# T8 2.0L COMFORT 4X4: 2
# COROLLA XLI CVT: 2
# KICKS 1.6L SENSE MT: 2
# KICKS ADVANCE CVT 2024: 2
# KICKS SENSE MT: 2
# COROLLA XEI 2.0 6MT: 2
# KYX3 5MT STD MT 2024: 2
# FRONTIER D/C 2.5L 6MT DELUXE ABS: 2
# COROLLA CROSS HEV SEG 1.8 HEV AT 2024: 2
# FT 500 LUX 4X4: 2
# SPORTAGE EX 2.0L 6MT GSL 2024: 2
# T8 PRO LUXURY 4X4 MT 2024: 2
# TUCSON TL  2.0 AT VALUE: 2
# FIORINO CITY  DIESEL: 2
# TRACKER II 1.8 AWD LT AT: 2
# GRAND I-10 BA 5DR 1.2 5M/T GLS 2AB AC ABS PE: 2
# GRAND I-10 AI3 HB 1.2 MT PLUS: 2
# GRAND I-10 BA SDN  MT GLS 2AB AC ABS FULL PE: 2
# JIMNY 1.3 JLX AB AC WINCHE: 2
# X25 1.5 MT COMFORTABLE: 1
# X-TRAIL 2.5L SENSE AUT 3FILAS: 1
# RAM 700 SLT 1.4 DC MT: 1
# T60 GLX 4X4 D20: 1
# TRAVERSE 3.6L LT AWD AT 2024: 1
# PORTER 2.5L GL DOBLE CABINA: 1
# PRISMA 1.4 LT MT: 1
# PRIUS: 1
# YARIS SPORT SPORT MT: 1
# TIGUAN TSI MT TRENDLINE 150HP: 1
# PRIUS PRIUS: 1
# X-TRAIL 2.5L SENSE AUT 2FILAS: 1
# RAV4 XSE 2.5 4X2 CVT HV AT 2024: 1
# RANGER XL 4X2 DIESEL: 1
# X-TRAIL SENSE 2ROW 4X2: 1
# REFINE 1.9L EXECUTIVE 10PAS: 1
# TIGGO 2 GL MT: 1
# TRAVERSE 3.6L LT FWD: 1
# T60 DX 4X2 CS: 1
# X-TRAIL 2.5L EXCLUSIVE AUT 3FILAS 4X4: 1
# RANGER DSL XL 4X2 2.2L: 1
# ZS 1.5L STD 2024: 1
# WR-V LX 1.5 MT: 1
# XUV300 MT COMFORT 2024: 1
# ZX 1.5L DLX 2024: 1
# REXTON YRX301 4X2: 1
# TEPEE ALLURE 1.6 HDI 92 HP: 1
# RAV4 XLE 2.0 4X2 CVT AT 2024: 1
# TAHOE 5.3L LT 4X4: 1
# QASHQAI ADVANCE-M CVT: 1
# RAV4 2.5L XLE 4X4 AUT: 1
# T60 GL/4X4 : 1
# RAV4 LE 2.0 4X2 MT: 1
# RAV4 LE 2.0 4X4 MT: 1
# RAV4 LE 2.5 4X2 CVT HV: 1
# YARIS SEDAN LEI H CVT: 1
# QASHQAI EXCLUSIVE CVT 4WD 2024: 1
# TORRES LIMITED PLUS 1.5T 4WD SUNROOF AT 2024: 1
# TRAILBLAZER 2.8TD PREMIER AT 4WD: 1
# QASHQAI EXCLUSIVE CVT 4WD: 1
# YARIS SPORT GLE MT: 1
# TRAILBLAZER PREMIER AT 2.8D AWD L: 1
# RIFTER ALURE BlUEHDi 100 MT 2024: 1
# WINGLE 6 GASOLINA 2.4 G 4X4 ELITE: 1
# SAIL NB 1.5L LTZ CVT 2024: 1
# WINGLE 6 GASOLINA 4X4 ELITE: 1
# WINGLE5 2.0L LUX CD 4X2 DIESEL: 1
# TUCSON TL  2.0 MT PLUS: 1
# S60 D2 COMFORT: 1
# S3 1.6L COMFORT SMART: 1
# WINGLE5 2.0L LUX CD 4X4 DIESEL: 1
# S3 1.6L COMFORT: 1
# T6 DIESEL 4X4 LUXURY: 1
# S2 COMFORT SMART 1.5 MT: 1
# T60 2.8L DX 4X2 CS: 1
# WINGLE7 2.0L DELUXE 4X4: 1
# S-CROSS II 1.6 4WD AT LIMITED: 1
# RUSH MEC 4X4: 1
# RUSH MEC 4X2: 1
# RUSH LEI 4X2 MEC: 1
# T60 2.8L GL 4X2: 1
# WR-V EXL 1.5 CVT: 1
# RUSH 1.5 XEI AT: 1
# WINGLE 6 GASOLINA 4X2 ELITE: 1
# TUCSON TL  2.0 MT VALUE: 1
# SUNRAY 17+1 LIMITED: 1
# SANTA FE DM  WGN 2.2 CRDI 6A/T 4WD GLS FULL PE: 1
# WINGLE 5 DIESEL 2.0 VGT 4X2 LUX: 1
# TURISMO L2H2 GL: 1
# SUNRAY 21+1 ESCOLAR: 1
# TUNDRA 4X4 SR5: 1
# SUNRAY 27+1 ESCOLAR CUMMINS: 1
# TUNDRA 4X4 S/SUNROOF: 1
# SANTA FE TM 2.2 CRDI E6 AT VALUE: 1
# TUCSON TL 2.0 CRDI MT VALUE FL: 1
# SYMBOL ZEN: 1
# WINGLE 5 DIESEL DOBLE CAB 2.0 4X4 LUX: 1
# WINGLE 5 GASOLINA 4X2 DELUXE: 1
# T6 BENCINA 4X2 LUXURY: 1
# SANTA FE TM 2.2 CRDI AT PLUS FL: 1
# WINGLE 6 DIESEL 4X4 DELUXE: 1
# T6 DIESEL 4X4 COMFORT: 1
# TUCSON TL 2.0 CRDI E6 AT 4WD LIMITED FL: 1
# WINGLE 6 DIESEL DC 2.0 4X4 DELUXE: 1
# TUCSON TL 2.0 AT PLUS FL: 1
# SANTA FE DM  WGN 2.2 CRDI 6A/T 4WD GLS PE: 1
# S-PRESSO 1.0L GLX AC: 1
# 1500 CREW CAB LIMITED 5.7L AT 2024: 1
# POER PLUS 4X4 ELITE 2024: 1
# DUSTER ZEN TECH 2,0 6MT 4X2: 1
# DZIRE SEDAN 1.2 GL: 1
# ECOSPORT S 1.5L MT: 1
# EDGE SEL 2.0 ECOBOOST FWD: 1
# EDGE SEL ECOBOOST 2.0L: 1
# ELANTRA AD  1.6 AT PREMIUM: 1
# ELANTRA AD  1.6 MT PREMIUM: 1
# ELANTRA AD 1.6 AT PREMIUM FL: 1
# ELANTRA AD 1.6 MT VALUE: 1
# ELANTRA CN7 2.0 AT E6 PREMIUM: 1
# ERTIGA 1.4 GLX: 1
# ESCAPE S 2.0L 4X2 DIESEL: 1
# EXPLORER ECOBOOST 2.3L 4X2: 1
# EXPLORER XLT 4X4 3.5L: 1
# CS15 1.5L COMFORT MT 2024: 1
# CRUZE HB TURBO LT AT: 1
# CRETA SU2ID 1.5 MT PLUS 2024: 1
# ALSVIN COMFORT 2024: 1
# ACTYON SPORTS 2.0 4X2 MT NAS611: 1
# ACTYON SPORTS 2.2 4X2 STD MT 6AS611: 1
# ACTYON SPORTS 2.2 4X4 SEMI FULL MT 6AS711: 1
# ACTYON SPORTS 4X2 MEC 6AS611: 1
# ACTYON SPORTS 4X4 MEC 6AS711: 1
# ACTYON SPORTS NAS610AA 4X2 MT STD: 1
# ALL NEW COMPASS  SPORT LX: 1
# ALL NEW CX-5 R 2.0 2WD 6AT: 1
# ALL NEW CX-5 R 2.0L 2WD CA 6MT: 1
# ALL NEW CX-5 R 2.0L AWD 6MT: 1
# ALL NEW LEGACY 2.5i  AWD CVT LIMITED: 1
# ALL NEW MAZDA6 SDN GT 2.5L CA 6AT: 1
# ALL NEW MAZDA6 SDN V 2.0L CA 6MT: 1
# ALL NEW MAZDA6 SDN V 2.5L CA 6AT: 1
# ALL NEW MAZDA6 SDN V 2.5L CA 6AT (C.N.): 1
# ACTYON SPORT 2.2 4X2 EURO VI 6AS612: 1
# ACCENT RB SDN 1.6 CRDI 6M/T GL 2AB AC: 1
# ACCENT RB SDN 1.4 6M/T GL 2AB AC ABS LL: 1
# 508 ALLURE 2.0 HDI 165HP EAT6: 1
# 301 ALLURE 1.6 HDI 92HP: 1
# 301 NUEVO 301 ACTIVE PACK 1.6 HDI 92HP: 1
# 4RUNNER 4X2 SR5 CONTROL VOLANTE *NUEVA: 1
# 4RUNNER 4X4 LIMITED *NUEVA: 1
# 4RUNNER 4X4 SR5 CONTROL VOLANTE * NUEVA: 1
# 4RUNNER SR5 4X2 AT 2024: 1
# 6 2.0L V CN AUT: 1
# ACCENT RB SDN  1.4 6M/T GL 2AB AC: 1
# 6 SDN V 2.5 6AT CUERO: 1
# 700 ADVENTURE DC: 1
# 700 SLT DC 1.3L MT 2024: 1
# A500 LUXURY: 1
# ACCENT BN7I 1.5 DESIGN 2024: 1
# ACCENT RB 5DR 1.4 6M/T GL 2AB ABS AC: 1
# ALL NEW MUSSO 4WD MT QS712: 1
# AMAROK COMFORTLINE 4X2: 1
# CRETA SU2ID 1.5 CVT PLUS 2024: 1
# APV 1.6 FURGÓN: 1
# CAPTIVA LT 1.5T FWD MT: 1
# CAPTUR LIFE MT DIESEL: 1
# CIAZ SEDAN 1.4 GLX: 1
# CITAN 109 CDI 4X2 EURO5 3,1 M3: 1
# COLORADO 2.8 CTDI 4X4 HC AT: 1
# COLORADO 2.8L HIGH COUNTRY 4X4 AUT: 1
# COLORADO LT 4X4 AT 2024: 1
# COLORADO LTZ AT 2.8TD 4WD L: 1
# COMMANDER LIMITED 2.0 G 4X4 AT 2024: 1
# COMPASS 2.4L SPORT: 1
# COROLLA XLI MT: 1
# CR-V TOURING 1.5 TURBO 4X4 CVT: 1
# CR-V TOURING AWD: 1
# CRETA GRAND SU2I 2.0 AT VALUE 2024: 1
# CRETA GS  1.6 MT GLS 2AB ABS: 1
# CAPTIVA LT 1.5T 2WD MT: 1
# CAPTIVA 1.5L PREMIER CVT P AT 2024: 1
# CAPTIVA 1.5L PREMIER AUT: 1
# BT-50 2.2L SDX 4X4: 1
# APV FURGON 1.6: 1
# ASX 1.6L GLS 4X2 MT 2024: 1
# ASX 4X4 AT: 1
# BOXER FURGÓN L3H2 2.0L BLUEHDI 160HP: 1
# BOXER FURGíN L2H2 BLUEHDI 165 MT 2024: 1
# BT-50 2.2L SDX 4X2: 1
# BT-50 CORE 4X4 AT 2024: 1
# CAPTIVA 1.5L PREMIER: 1
# BT-50 DOBLE CABINA 2.2 SDX 6MT 4X2 DIESEL: 1
# BT-50 DOBLE CABINA 2.2 SDX HIGH 6MT 4X4 DIESEL: 1
# BT-50 DOBLE CABINA 3.2 SDX HIGH 6AT 4X4 DIESEL: 1
# BT-50 DOBLE CABINA 3.2 SDX HIGH 6AT 4X4 DIESEL (E5): 1
# C30 CLASSIC 1.5 COMFORT MT: 1
# CAMRY HIBRIDO: 1
# HD35 LIGHT DLX CARGA GENERAL REFRIGERADA: 1
# HD35 STD AC PICKUP BARANDAS 50CM: 1
# POER 4X4 DELUXE 2024: 1
# NEW RANGER DSL XLT 4X4 3.2L AT: 1
# NEW RANGER GAS XLT 2.5L: 1
# NEW RAV4 HIBRIDO LE CVT 2WD: 1
# NEW RAV4 XLE 8AT 2WD: 1
# NEW S-CROSS 1.6 4WD GLX: 1
# NEW S3 COMFORT SMART 1.6 MT: 1
# NEW SPIN ACTIV: 1
# NEW TRAVERSE 3.6L LT FWD: 1
# NEW TRAVERSE 3.6L PREMIER AWD: 1
# NEW V80 FL MINIBUS 12+1 E5: 1
# NEW V80 FL VAN ESCOLAR E5: 1
# NEW VERSA 1.6L SENSE MT RADIO TOUCH: 1
# NEW VERSA SENSE MT: 1
# NG TRAVERSE 3.6L PREMIER AWD: 1
# NP300 NAVARA D23 DC XE 2.3D MT 4WD: 1
# NQR 919 MT PLATAFORMA 2024: 1
# NEW RANGER GAS XL 2.5L: 1
# NEW RANGER DSL XLT 4X4 3.2L: 1
# HD35 STD AC PICKUP BARANDAS ALTAS HIDRAULICA RECICLAJE: 1
# NEW RANGER DSL XLT 4X2 3.2L: 1
# NEW C-ELYSÉE 1.2L PURETECH 82 BVM FEEL: 1
# NEW C-ELYSÉE 1.6 HDI 92 BVM FEEL: 1
# 3008 ACTIVE PACK 1.2 PURETECH 130HP 2024: 1
# NEW CX-3 R 2.0L 2WD 6AT: 1
# NEW CX-3 R 2.0L AWD 6AT: 1
# NEW CX-9 R AWD 2.5L TURBO 6AT: 1
# NEW EQUINOX 1.5T LS AT FWD: 1
# NEW H-1  MB 2.5 CRDI MT GLS 9S AC 2AB: 1
# NEW MAHINDRA PIK UP XL D/C 4X2: 1
# NEW MAHINDRA SCORPIO SUV 4X2: 1
# NEW MAHINDRA SCORPIO SUV  4X4: 1
# NEW MAHINDRA SCORPIO SUV  4X4 ABS 2AB: 1
# NEW MAZDA6 V 2.0 6MT: 1
# NEW QASHQAI MC 2.0L EXCLUSIVE CVT 4WD: 1
# NEW RANGER DSL LIMITED 4X4 3.2L AT: 1
# NUEVA AMAROK HIGHLINE 4MOTION AT: 1
# NUEVA AMAROK TRENDLINE 4X2 MT: 1
# NUEVA BOXER FURGÓN L2H2 2.0 BLUEHDI 160 HP: 1
# NUEVA BOXER FURGÓN L3H2 2.0 BLUEHDI 160 HP: 1
# ONIX 1.4 LTZ MT: 1
# OROCH INTENS 2,0 L MT 4 X 2: 1
# OROCH ZEN 1,6 L MT 4X2: 1
# OROCH ZEN 1.6L MT 4X2: 1
# OUTLANDER 2.0L AT 4X2: 1
# OUTLANDER 4X2 GL 4X2 AT 2024: 1
# OUTLANDER 4X4 GLX 6AT: 1
# PALISADE LX2 3.5 AWD PREMIUM FL AT 2024: 1
# PARTNER MAXI NUEVA MAXI 1.6 HDI 90HP NAV: 1
# PATHFINDER ADVANCE CVT: 1
# PICK UP REFRESH DC 4X4 MT DELUXE: 1
# PIK UP 2.2L DC 4X4 WORK: 1
# PILOT ELITE 3.5 AT 4X4 ACP: 1
# PLUS AIRE ACONDICIONADO: 1
# POER 4X2 ELITE 2024: 1
# ONIX 1.0 PREMIER R 2024: 1
# NV350 WIDE S LONG 2.5 MT MINUSVALIDO: 1
# NV350 S-LONG CARGO: 1
# NUEVO ASX GL 4X2 MT: 1
# NUEVA DOKKER III 1.6 GSL FURGON MT 1AB MY17: 1
# NUEVA DOKKER III 1.6 GSL FURGON MT AC 2AB MY17: 1
# NUEVA DOKKER III 1.6 GSL MT AC 2AB: 1
# NUEVA L200  4X2 KATANA CR: 1
# NUEVA PARTNER 1.6 HDI 90HP PACK AA EV: 1
# NUEVA X-TRAIL 2.5L EXCLUSIVE CVT 3FILAS 4X4  MULTIMEDIA: 1
# NUEVO SORENTO EX 2.2L DSL 6MT 2WD: 1
# NV350 CARDO WIDE S-LONG: 1
# NUEVO T-CROSS COMFORTLINE: 1
# NUEVO TIGUAN TSI AT COMFORTLINE 150HP 7P: 1
# NUEVO VOYAGE COMFORTLINE 1.6: 1
# NUEVO VOYAGE HIGHLINE: 1
# NUEVO VOYAGE TRENDLINE 1.6: 1
# NUEVO YARIS SEDAN GLI CVT: 1
# NAVARA NP300 SC S 2.3D MT 4WD: 1
# NAVARA NP300 SC S 2.3D MT: 1
# NAVARA NP300 DC LE 2.3D AT 4WD: 1
# M201 1.2L FURGÓN: 1
# KANGOO L1 ZE 33 FURGON 4P T/A: 1
# KICKS 1.6L ADVANCE AUT: 1
# KICKS EXCLUSIVE CVT: 1
# KICKS EXCLUSIVE CVT 2024: 1
# KORANDO LX 1.5T 6MT 2WD MT 2024: 1
# L 200 DC 4X4 TD DAKAR CRS AT: 1
# L 200 DC 4X4 TD DAKAR CRS MT HP: 1
# L-200 -D/C 4X2 TD WORK CR: 1
# L-200 2.4L DAKAR CRS MT 4X4: 1
# L-200 2.4L WORK CR 4X2: 1
# L200 DAKAR AT: 1
# L200 KATANA CRT 4X4 SC: 1
# LANDTREK ACTIVE BLUEHDI 180 4X2 MT 2024: 1
# LEGACY 2.5I CVT LIMITED: 1
# M 201 CARGO 2024: 1
# JS4 COMFORT 1.6 MT 2024: 1
# JS3 XE LUXURY 1.6 CVT AT 2024: 1
# IONIQ EV GLS FL: 1
# HILUX 2.8L SR CD 4X4: 1
# HILUX 2.4 4X4 DX CABINA SIMPLE: 1
# HILUX 2.4L SR CD 4X2: 1
# HILUX 2.4L SR CD 4X4: 1
# HILUX 2.7L SR GASOLINA CD 4X2: 1
# HILUX 2.8 4X4 AT SRV: 1
# HILUX 2.8 4X4 MT SR: 1
# HILUX 4X2 2.7 MT SR GASOLINA: 1
# IONIQ 5 NE EV AWD LIMITED AT 2024: 1
# HILUX 4X4 2.8 MT SR: 1
# HILUX DX DC 2.4 4X2 MT 2024: 1
# HILUX SR DC 2.4 4X4 MT 2024: 1
# HS 1.5T DCT DLX: 1
# I20 IB 1.4 MT PLUS: 1
# IGNIS 1.2 GL: 1
# M 201 CARGO AC 2024: 1
# M201 FURGÓN CARGO SIN AC SIN DIRECCIÓN: 1
# NAVARA NP300 2.3L XE 4X2 DC: 1
# M4 1.5 EN: 1
# MORNING C MT 1.2 FULL: 1
# MS201 PICK UP DOBLE CABINA CON A/C CON DIRECCIÓN ASISTIDA: 1
# MS201 PICK UP DOBLE CABINA CON AC CON DIRECCIÓN: 1
# MS201 PICK UP DOBLE CABINA SIN A/C CON DIRECCIÓN ASISTIDA: 1
# MURANO EXCLUSIVE CVT 4WD: 1
# MUSSO GLX 2.2TD 4X4 MT 2024: 1
# MUSSO GRAND DIESEL 2.2L AT: 1
# MUSSO GRAND FULL DIESEL 2.2L: 1
# N300 MAX  E5 VAN 1.2 MT: 1
# N300 MAX  VAN 1.2 MT A/C DH: 1
# N300 MAX E5 VAN 1.2 MT: 1
# N300 MAX VAN 1.2 MT AC DH: 1
# N400 MAX LL 1.5 L MT AC: 1
# NAVARA CD LE 4X4 : 1
# NAVARA NP300 2.3L SE 4X2 DC: 1
# MONTERO SPORT LIMITED 4X4 AT: 1
# MONTERO SPORT 4X4 AT: 1
# MONTERO SPORT 2.4 4X4 MT: 1
# MIDI DOBLE CABINA 1.3: 1
# M4 1.5 SR: 1
# MD201 DOBLE CABINA CON A/C CON DIRECCIÓN: 1
# MD201 MT 2024: 1
# MD201 PICK UP XL 1.5 CAB SIMPLESIN A/C - CON DIRECCIÓN ASISTIDA: 1
# MG ZS 1.5 MT STD: 1
# MIDI CARGO BOX 1.3: 1
# MIDI PLUS DOBLE CABINA: 1
# MONTERO SPORT 2.4 4WD MT: 1
# MIDI REFRIGERADO: 1
# MIDI TRUCK CARGO BOX REFRIGERADO 1.3 MT: 1
# MONTANA 1.2 T LTZ AT 2024: 1
# MONTANA 1.2 T PREMIER MT 2024: 1
# MONTANA 1.2 T RS AT 2024: 1
# MONTANA LS 1.8 COMFORT: 1
#  RIFTER ALLURE BLUEHDI 100 : 1

# %%
def clean_modelo(modelo):
    """
    Clean the 'Modelo' string by applying the following transformations:
    1. Keep the first word of the string as is.
    2. Remove any subsequent word that:
       a. Begins with a number.
       b. Has only two characters.
    3. Join the remaining words back into a single string.

    """
     # Split the string into words
    words = modelo.split()
    
    # Keep the first word and filter subsequent words
    cleaned_words = [words[0]] + [word for word in words[1:] if not word[0].isdigit() and len(word) > 2]
    
    # Join the cleaned words back into a string
    return ' '.join(cleaned_words)

# Convert the 'Modelo' column to strings and handle NaNs
df['Modelo'] = df['Modelo'].astype(str)
# Apply the cleaning function to the 'Modelo' column
df['Modelo'] = df['Modelo'].apply(clean_modelo)


modelos = df.value_counts('Modelo')
for modelo, count in modelos.items():
    print(f'{modelo}: {count}')
# Out:
# nan: 1071
# HILUX: 220
# NP300: 216
# H-1 CRDI: 176
# T60: 97
# NAVARA NP300: 65
# NAVARA: 52
# FRONTIER D/C: 45
# L200 KATANA CRM: 39
# TUCSON PLUS: 37
# COLORADO: 36
# NEW DMAX: 33
# NEW RAV4 AWD: 32
# PORTER CRDI: 30
# RAV4 LUJO: 28
# H-1 CRDI GLS ABS: 28
# L200 WORK: 27
# FRONTIER D/C DELUXE: 26
# HILUX (WIDE): 25
# SAIL: 25
# L200 KATANA CRT: 24
# DMAX III: 23
# WINGLE GASOLINA ELITE: 20
# NEW D-MAX: 20
# D-MAX III: 20
# HILUX GASOLINA: 20
# X-TRAIL SENSE CVT: 19
# TRANSIT MINIBUS: 19
# TUCSON NX4 PLUSÂ: 18
# AMAROK TRENDLINE: 16
# BT-50 DOBLE CABINA SDX DIESEL (E5): 16
# WIDE S-LONG BUS: 15
# VERSA SENSE: 15
# NEW RANGER DSL: 14
# 4RUNNER SR5 CONTROL VOLANTE: 13
# GRAND I-10 SDN GLS ABS: 12
# FRONTIER P/UP: 12
# COLORADO CTDI LTZ: 12
# SANTA WGN GLS: 11
# SPACETOURER BLUEHDI S&S BVM6 BUSINESS: 11
# T60 DX/4X4: 11
# TRAVELLER BUSINESS ASIENTOS BLUEHDI: 11
# VIGUS NEW WORK: 11
# AZERA PREMIUM: 11
# PORTER CRDI GLS CAMIONETA: 10
# COLORADO LTZ: 10
# WINGLE ELITE: 10
# NEW MAZDA6 (CUERO NEGRO): 10
# GRAND NOMADE GLX NAV: 9
# SANTA PLUS: 9
# ACCENT SDN: 9
# MONTERO SPORT: 9
# GRAND VITARA GLX SPORT: 9
# G10 MINIBUS: 9
# SANTA CRDI VALUE: 9
# TUCSON CRDI PLUS: 9
# RUSH LEI MEC: 9
# 4X2: 9
# OUTLANDER GLX: 9
# STARIA CEDI: 9
# WINGLE DIESEL LUX: 9
# NUEVO YARIS SEDAN GLI: 8
# X-TRAIL SENSE: 8
# COROLLA XEI: 8
# PICK REFRESH WORK: 8
# POER ELITE PANT: 8
# KICKS SENSE: 8
# TUCSON VALUE: 8
# BT-50 DOBLE CAB SDX DIESEL (E5): 8
# QASHQAI SENSE: 8
# ALL NEW CX-5 AWD: 8
# URBAN PLATAFORMA: 7
# NEW RAV4: 7
# SUNRAY: 7
# GRAND I-10 SDN: 7
# NV350 WIDE S-LONG BUS: 7
# TRACKER FWD: 7
# REFINE EXECUTIVE ASIENTOS: 7
# QUBO DYNAMIC: 7
# MUSSO GLX: 1
# NEW CX-3 AWD: 1
# NEW CX-3: 1
# NEW COMFORT SMART: 1
# NEW C-ELYSÉE PURETECH BVM FEEL: 1
# NEW C-ELYSÉE HDI BVM FEEL: 1
# ACCENT SDN ABS: 1
# ACCENT SDN CRDI: 1
# N300 MAX VAN A/C: 1
# MUSSO GRAND DIESEL: 1
# 1500 CREW CAB LIMITED: 1

# %%
#df['merge_var'] = df['Marca'] + ' ' + df['Tipo de Producto'] + ' ' + df['Modelo']
df['merge_var'] = df['Marca'] + ' ' + df['Modelo']

# %%
df_char = pd.read_csv("../6_car_analysis/csvs/scraped_data.csv")  
df_char['merge_var'] = df_char['model']

# %%
merged_df = df.merge(df_char, on='merge_var', how='left', indicator=True)

#1. calculate the share of obs. merged 
share_merged = merged_df['_merge'].value_counts(normalize=True).get('both', 0)
print(f"Share of observations  that are merged: {share_merged:.2%}")

# 2. Create a variable that counts how many matches are found in the other file
match_counts = df_char.groupby('merge_var').size()
df['match_count'] = df['merge_var'].map(match_counts).fillna(0).astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27232\1184508011.py in ?()
# ----> 1 merged_df = df.merge(df_char, on='merge_var', how='left', indicator=True)
#       2
#       3 #1. calculate the share of obs. merged
#       4 share_merged = merged_df['_merge'].value_counts(normalize=True).get('both', 0)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9844         validate: str | None = None,
#    9845     ) -> DataFrame:
#    9846         from pandas.core.reshape.merge import merge
#    9847
# -> 9848         return merge(
#    9849             self,
#    9850             right,
#    9851             how=how,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     140     copy: bool | None = None,
#     141     indicator: str | bool = False,
#     142     validate: str | None = None,
#     143 ) -> DataFrame:
# --> 144     op = _MergeOperation(
#     145         left,
#     146         right,
#     147         how=how,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     729         (
#     730             self.left_join_keys,
#     731             self.right_join_keys,
#     732             self.join_names,
# --> 733         ) = self._get_merge_keys()
#     734
#     735         # validate the merge keys dtypes. We may need to coerce
#     736         # to avoid incompatible dtypes
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1187                         # Then we're either Hashable or a wrong-length arraylike,
#    1188                         #  the latter of which will raise
#    1189                         rk = cast(Hashable, rk)
#    1190                         if rk is not None:
# -> 1191                             right_keys.append(right._get_label_or_level_values(rk))
#    1192                         else:
#    1193                             # work-around for merge_asof(right_index=True)
#    1194                             right_keys.append(right.index)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1774             values = self.xs(key, axis=other_axes[0])._values
#    1775         elif self._is_level_reference(key, axis=axis):
#    1776             values = self.axes[axis].get_level_values(key)._values
#    1777         else:
# -> 1778             raise KeyError(key)
#    1779
#    1780         # Check for duplicates
#    1781         if values.ndim > 1:
#
# KeyError: 'merge_var'

# %%
car_path = os.path.join('..', 'car_data', 'final_matched_data.csv')
car_df = pd.read_csv(car_path, encoding = 'latin1')
#show(car_df)

print(car_df.columns.tolist())

# Get current column names
cols = car_df.columns

# Function to clean column names
def clean_column_name(col):
    if '-' in col:
        # Split on '-' and take the second part, strip to remove extra spaces
        return col.split('-')[1].strip()
    return col

# Apply the cleaning to all columns
car_df.columns = [clean_column_name(col) for col in cols]

print(car_df.columns.tolist())
# Out:
# ['Unnamed: 0', 'Nro LicitaciÃ\x83Â³n PÃ\x83Âºblica', 'Id Convenio Marco', 'Convenio Marco', 'CodigoOC', 'NombreOC', 'Fecha EnvÃ\x83Â\xado OC', 'EstadoOC', 'Proviene de Gran Compra', 'idGranCompra', 'EspecificaciÃ\x83Â³n del Comprador', 'IDProductoCM', 'Producto', 'Nombre Producto ONU', 'Tipo de Producto', 'Marca', 'Modelo', 'Precio Unitario', 'Cantidad', 'TotaLÃ\x83Â\xadnea(Neto)', 'Moneda', 'Monto Total OC Neto', 'Descuento Global OC', 'Cargos Adicionales OC', 'Subtotal OC', 'Impuestos', 'Monto Total OC', 'Rut Unidad de Compra', 'Unidad de Compra', 'RazÃ\x83Â³n Social Comprador', 'DirecciÃ\x83Â³n Unidad Compra', 'Comuna Unidad Compra', 'RegiÃ\x83Â³n Unidad de Compra', 'InstituciÃ\x83Â³n', 'Sector', 'Rut Proveedor', 'Nombre Proveedor Sucurs
unicaciÃ³n y entretenimiento - Parlantes', 'ComunicaciÃ³n y entretenimiento - ConexiÃ³n auxiliar (iPod y Mp3)', 'ComunicaciÃ³n y entretenimiento - Interfaz bluetooth', 'ComunicaciÃ³n y entretenimiento - Pantalla', 'Seguridad - Otros', 'Seguridad - Autobloqueo de puertas con velocidad', 'Seguridad - Control de estabilidad', 'Seguridad - Control de tracciÃ³n', 'Confort - Control de velocidad crucero', 'Confort - Encendido del motor', 'ComunicaciÃ³n y entretenimiento - Apple Carplay / Android Auto', 'Confort - CÃ¡mara de visiÃ³n', 'Seguridad - Asistencia en fre ...
# ['Unnamed: 0', 'Nro LicitaciÃ\x83Â³n PÃ\x83Âºblica', 'Id Convenio Marco', 'Convenio Marco', 'CodigoOC', 'NombreOC', 'Fecha EnvÃ\x83Â\xado OC', 'EstadoOC', 'Proviene de Gran Compra', 'idGranCompra', 'EspecificaciÃ\x83Â³n del Comprador', 'IDProductoCM', 'Producto', 'Nombre Producto ONU', 'Tipo de Producto', 'Marca', 'Modelo', 'Precio Unitario', 'Cantidad', 'TotaLÃ\x83Â\xadnea(Neto)', 'Moneda', 'Monto Total OC Neto', 'Descuento Global OC', 'Cargos Adicionales OC', 'Subtotal OC', 'Impuestos', 'Monto Total OC', 'Rut Unidad de Compra', 'Unidad de Compra', 'RazÃ\x83Â³n Social Comprador', 'DirecciÃ\x83Â³n Unidad Compra', 'Comuna Unidad Compra', 'RegiÃ\x83Â³n Unidad de Compra', 'InstituciÃ\x83Â³n', 'Sector', 'Rut Proveedor', 'Nombre Proveedor Sucursal', 'Nombre Empresa', 'Comuna del Proveedor', 'RegiÃ\x83Â³n del Proveedor', 'Observaciones', 'Forma de Pago', 'Orgcode_Comprador', 'Entcode_Comprador', 'Orgcode_Proveedor', 'Entcode_Proveedor', 'MODEL', 'MARCA', 'Model Name', 'Engine', 'Drive', 'Transmission', 'Year', 'Version URL', 'Combustible', 'Cilindrada', 'Potencia', 'Torque', 'AlimentaciÃ³n', 'Cilindros', 'VÃ¡lvulas', 'CatalÃ\xadtico', 'Sistema start / stop', 'AceleraciÃ³n 0', 'Rendimiento en ciudad', 'Rendimiento en ruta', 'Rendimiento mixto', 'Velocidad mÃ¡xima', 'Motor', 'TransmisiÃ³n', 'NeumÃ¡ticos', 'Frenos (del.', 'SuspensiÃ³n delantera', 'SuspensiÃ³n trasera', 'Largo', 'Ancho sin espejos', 'Ancho con espejos', 'Alto', 'Distancia entre ejes', 'BaÃºl', 'Tanque de combustible', 'Peso', 'Capacidad de carga', 'Altura de piso', 'Capacidad de vadeo', 'Ã\x81ngulo de ataque', 'Ã\x81ngulo de partida', 'Ã\x81ngulo ventral', 'Remolque con frenos', 'Remolque sin frenos', 'Capacidad de pendiente', 'Escalonamiento vertical', 'InclinaciÃ³n lateral', 'Aire acondicionado', 'Alarma de luces encendidas', 'Asientos delanteros', 'Asientos traseros', 'Tapizados', 'Cierre de puertas', 'Vidrios (del.', 'Espejos exteriores', 'Espejo interior', 'Faros delanteros', 'Faros antiniebla', 'Computadora de a bordo', 'DirecciÃ³n asistida', 'Llantas', 'Techo solar', 'Volante', 'Apertura de baÃºl y tapa de combustible', 'Sensores de estacionamiento', 'ABS', 'DistribuciÃ³n electrÃ³nica de frenado', 'Airbags', 'Alarma e inmovilizador de motor', 'Anclaje para asientos infantiles', 'Cinturones de seguridad', 'Tercera luz de stop', 'Equipo de mÃºsica', 'Parlantes', 'ConexiÃ³n auxiliar (iPod y Mp3)', 'Interfaz bluetooth', 'Pantalla', 'Otros', 'Autobloqueo de puertas con velocidad', 'Control de estabilidad', 'Control de tracciÃ³n', 'Control de velocidad crucero', 'Encendido del motor', 'Apple Carplay / Android Auto', 'CÃ¡mara de visiÃ³n', 'Asistencia en frenada de emergencia', 'Sensor de lluvia', 'ConexiÃ³n USB', 'ReproducciÃ³n de audio vÃ\xada bluetooth', 'Sistema de navegaciÃ³n', 'Wi', 'MirrorLink', 'Recarga inalÃ¡mbrica del celular', 'Limitador de velocidad', 'Limpialuneta', 'Sistema de control por voz para dispositivos', 'Encendido automÃ¡tico de balizas', 'Luz de freno variable', 'Sistema de estacionamiento asistido', 'Cantidad de celdas', 'Cantidad de mÃ³dulos', 'Potencia', 'Tipo', 'Voltaje', 'UbicaciÃ³n', 'Potencia', 'Torque', 'Voltaje', 'Palanca de cambios', 'NeumÃ¡ticos delanteros', 'NeumÃ¡ticos traseros', 'Potencia total sistema hÃ\xadbrido', 'Cabeceras delanteras activas', 'PreinstalaciÃ³n telÃ©fono', 'Disco rÃ\xadgido', 'Puertas']

# %%
keep_var = [ 'CodigoOC',  'Ancho sin espejos',  'Largo', 'Alto',  'Cilindrada', 'Rendimiento en ciudad', 'SuspensiÃ³n trasera' , 
            'Aire acondicionado', 'Tapizados', 'Cierre de puertas', 'Vidrios (del.', 'Espejos exteriores',  
            'Faros delanteros', 'Faros antiniebla', 'Computadora de a bordo', 'DirecciÃ³n asistida', 'Llantas', 
            'Sensores de estacionamiento',  'Airbags', 'Alarma e inmovilizador de motor']

car_df = car_df[keep_var]
show(car_df)
# Out:
# PandasGUI INFO — pandasgui.gui — Opening PandasGUI

# %%
# 3. merge the two datasets
#transac_df = transac_df.drop(columns=['Marca_x'])

transac_df['Index'] = transac_df.index + 1

# Merge on 'exact_merge_var'
merged_df = transac_df.merge(car_df, on='CodigoOC', how='left', indicator=True)

# 1. Calculate the share of observations in auction_21 that are merged
share_merged = merged_df['_merge'].value_counts(normalize=True).get('both', 0)
print(f"Share of transactions that are merged: {share_merged:.2%}")

# 2. Create a variable that counts how many matches are found in the other file
match_counts = car_df.groupby('CodigoOC').size()
merged_df['match_count'] = merged_df['CodigoOC'].map(match_counts).fillna(0).astype(int)
merged_df = merged_df.drop_duplicates(subset='CodigoOC', keep='first')
# Out:
# Share of transactions that are merged: 23.78%

# %%
show(merged_df)
print(merged_df.shape, transac_df.shape) # there was a problem because some CodigoOC were repeated.
# Out:
# PandasGUI INFO — pandasgui.gui — Opening PandasGUI
# PandasGUI WARNING — pandasgui.utility — In merged_df, renamed duplicate columns: ['Modelo']
# (3850, 53) (4282, 32)

# %% [markdown]
# The share of matched observations is so low that there are two possible ways of continuing 1. estimate demand using car_data or 2. estimate demand without using product characteristics.
