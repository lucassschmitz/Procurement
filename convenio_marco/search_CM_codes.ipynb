# %%
import pandas as pd
from pandasgui import show
import os

# create the root path 
current_dir = os.getcwd()
base_path = os.path.join('raw_data', 'OrdenesCompra')

#joint the files for a single year. 
def join_data(base_path, year): 
    # Create an empty list to store DataFrames
    dfs = []

    for year in range(year, year+1 ):
        for month in range(1, 13):
            # Construct the file path
            file_path = os.path.join(base_path, str(year), f"{year}-{month}.csv")
            
            # Check if the file exists before trying to read it
            if os.path.exists(file_path):
                try:
                    df = pd.read_csv(file_path, encoding='ISO-8859-1', sep=';')
                    
                    # Add year and month columns for reference
                    df['Year'] = year
                    df['Month'] = month
                    
                    # Append the DataFrame to the list
                    dfs.append(df)
                    print(f"Successfully read file: {file_path}")
                except Exception as e:
                    print(f"Error reading file {file_path}: {str(e)}")
            else:
                print(f"File not found: {file_path}")

    # Concatenate all DataFrames in the list
    combined_df = pd.concat(dfs, ignore_index=True)

    # Display basic information about the combined DataFrame
    print(combined_df.info())
    return combined_df

#describe the data
def descriptive_stats(df): 
    print('This is the descriptive statistics function')
    print(df.columns) 

    # Create a pivot table to tabulate the data by year and month
    pivot_table = df.pivot_table(index='Year', columns='Month', aggfunc='size', fill_value=0)

    # Display the pivot table
    print(pivot_table)

    df['ProcedenciaOC'].unique()
    df['precioNeto'] = pd.to_numeric(df['precioNeto'], errors='coerce')
    df = df.dropna(subset=['precioNeto'])
    total_weight = df['precioNeto'].sum()

    convenio_marco_weight = df[df['ProcedenciaOC'] == 'Proveniente de convenio marco']['precioNeto'].sum()
    share_convenio_marco = convenio_marco_weight / total_weight
    print('share of total expenditure in FAs:', share_convenio_marco)

#drop purchases that do not come from FAs or that are not from vehicles. 
def keep_FA_vehicles(df): 
    #remove purchases that are not trough FA
    df = df[df['ProcedenciaOC'] == 'Proveniente de convenio marco']


    ## see which variables are give you information of the type of product being bougth 
    varlist = [ 'Categoria',  'NombreroductoGenerico', 'RubroN1', 'RubroN2', 'RubroN3']
    #for var in varlist:
        #print('The var is: ', var)
        #print(df[var].unique())


    # create a df with the rows that could car purchases 
    columns_to_check = ['Categoria', 'NombreroductoGenerico', 'RubroN1', 'RubroN2', 'RubroN3']
    mask = df[columns_to_check].apply(lambda x: x.str.contains('Vehículos|vehículos', case=False, na=False)).any(axis=1)
    df = df[mask]

    return df

# show the columns that have relevant information 
def show_df(df): 

    # List of columns we care about 
    columns_to_check = ['ID', 'Codigo', 'Link', 'Nombre', 'Descripcion/Obervaciones', 'MontoTotalOC', 'MontoTotalOC_PesosChilenos', 'Impuestos','TotalNetoOC', 'CodigoProveedor',   'RegionProveedor',  'IDItem', 'codigoCategoria', 'Categoria', 'codigoProductoONU', 'NombreroductoGenerico', 'RubroN1', 'RubroN2', 'RubroN3', 'EspecificacionComprador', 'EspecificacionProveedor', 'cantidad',  'precioNeto', 'totalCargos','totalDescuentos', 'totalImpuestos', 'totalLineaNeto']

    df_show = df[columns_to_check]
    show(df_show)

#save the dataframe, otherwise one would have to use the join_data function each time
def save_df(df_light, year):    
    try:
        os.makedirs('interm_data', exist_ok=True)
        save_path = os.path.join('interm_data', 'search_CM', f'OC_{year}.csv')
        
        # If successful, now try to save your DataFrame
        df_light.to_csv(save_path, index=False)
        print(f"Successfully saved DataFrame to: {save_path}")

    except PermissionError as e:
        print(f"Permission error: {e}")
        print("You don't have permission to write to this location.")
    except FileNotFoundError as e:
        print(f"File not found error: {e}")
        print("The specified path doesn't exist and couldn't be created.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# summarize the amounts of the purchases and transforms amount variables to int, input: dictionary with dataframes
def summarize_amounts(df_dict): 
    for year, df in df_dict.items():
        print(f"Year: {year}")
        
        #get sense of price and its dispersion 
        df['MontoTotalOC'] = pd.to_numeric(df['MontoTotalOC'], errors='coerce')
        summary = df['MontoTotalOC'].describe()
        print(summary)

        df['precioNeto'] = pd.to_numeric(df['precioNeto'], errors='coerce')
        summary = df['precioNeto'].describe()
        print(summary)

        df_dict[year] = df
    return df_dict

# Find the values of 'Codigo' that are repeated more than N times
def repeated_codes(df_dict, N = 3): 
    for year, df in df_dict.items():
        print(f"Year: {year}")
        repeated_codigos = df['Codigo'].value_counts()
        repeated_codigos = repeated_codigos[repeated_codigos > N]
        print(repeated_codigos)
       
    return 


years = range(2016, 2024)
df_dict = {}  # Initialize an empty dictionary



for year in years:
    exists = False 

    combined_file_path = os.path.join(current_dir,'interm_data', 'search_CM', f'OC_{year}.csv')
    if os.path.exists(combined_file_path):
        print(f"Combined file for {year} already exists: {combined_file_path}")
        exists = True 

        df_light = pd.read_csv(combined_file_path)
        print(f'read df {year}, path {combined_file_path}')
    
    if exists == False: 

        df = join_data(base_path, year)

        descriptive_stats(df)
        df_light = keep_FA_vehicles(df)
        print(df_light.info())

        # Save the dataframe
        save_df(df_light, year)
    
    # Store the dataframe in the dictionary with the year as the key
    df_dict[year] = df_light
# Out:
# Combined file for 2016 already exists: c:\Users\lucas\OneDrive - Yale University\Documents\GitHub\2nd-year-paper\interm_data\search_CM\OC_2016.csv
# C:\Users\lucas\AppData\Local\Temp\ipykernel_18828\1157791491.py:152: DtypeWarning: Columns (2,32,58,69) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_light = pd.read_csv(combined_file_path)
# read df 2016, path c:\Users\lucas\OneDrive - Yale University\Documents\GitHub\2nd-year-paper\interm_data\search_CM\OC_2016.csv
# Combined file for 2017 already exists: c:\Users\lucas\OneDrive - Yale University\Documents\GitHub\2nd-year-paper\interm_data\search_CM\OC_2017.csv
# read df 2017, path c:\Users\lucas\OneDrive - Yale University\Documents\GitHub\2nd-year-paper\interm_data\search_CM\OC_2017.csv
# Combined file for 2018 already exists: c:\Users\lucas\OneDrive - Yale University\Documents\GitHub\2nd-year-paper\interm_data\search_CM\OC_2018.csv
# C:\Users\lucas\AppData\Local\Temp\ipykernel_18828\1157791491.py:152: DtypeWarning: Columns (22,31,69) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_light = pd.read_csv(combined_file_path)
# read df 2018, path c:\Users\lucas\OneDrive - Yale University\Documents\GitHub\2nd-year-paper\interm_data\search_CM\OC_2018.csv
# Combined file for 2019 already exists: c:\Users\lucas\OneDrive - Yale University\Documents\GitHub\2nd-year-paper\interm_data\search_CM\OC_2019.csv
# C:\Users\lucas\AppData\Local\Temp\ipykernel_18828\1157791491.py:152: DtypeWarning: Columns (22,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_light = pd.read_csv(combined_file_path)
# read df 2019, path c:\Users\lucas\OneDrive - Yale University\Documents\GitHub\2nd-year-paper\interm_data\search_CM\OC_2019.csv
# Combined file for 2020 already exists: c:\Users\lucas\OneDrive - Yale University\Documents\GitHub\2nd-year-paper\interm_data\search_CM\OC_2020.csv
# read df 2020, path c:\Users\lucas\OneDrive - Yale University\Documents\GitHub\2nd-year-paper\interm_data\search_CM\OC_2020.csv
# Combined file for 2021 already exists: c:\Users\lucas\OneDrive - Yale University\Documents\GitHub\2nd-year-paper\interm_data\search_CM\OC_2021.csv
# read df 2021, path c:\Users\lucas\OneDrive - Yale University\Documents\GitHub\2nd-year-paper\interm_data\search_CM\OC_2021.csv
# Combined file for 2022 already exists: c:\Users\lucas\OneDrive - Yale University\Documents\GitHub\2nd-year-paper\interm_data\search_CM\OC_2022.csv
# read df 2022, path c:\Users\lucas\OneDrive - Yale University\Documents\GitHub\2nd-year-paper\interm_data\search_CM\OC_2022.csv
# Combined file for 2023 already exists: c:\Users\lucas\OneDrive - Yale University\Documents\GitHub\2nd-year-paper\interm_data\search_CM\OC_2023.csv
# read df 2023, path c:\Users\lucas\OneDrive - Yale University\Documents\GitHub\2nd-year-paper\interm_data\search_CM\OC_2023.csv
# C:\Users\lucas\AppData\Local\Temp\ipykernel_18828\1157791491.py:152: DtypeWarning: Columns (69,73,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_light = pd.read_csv(combined_file_path)

# %%
## see which variables give you information of the type of product being bougth 
varlist = [ 'Categoria',  'NombreroductoGenerico', 'RubroN1', 'RubroN2', 'RubroN3']
    
for year, df in df_dict.items():
    print(f"Year: {year}")
    
    for var in varlist:
        print('The var is: ', var)
        print(df_light[var].unique())

    df = df[(df['RubroN2'] == 'Vehículos motorizados')& (df['NombreroductoGenerico'] != 'Camiones de transporte')]
    print(df.info())

    df_dict[year] = df
# Out:
# Year: 2016
# The var is:  Categoria
# ['Vehículos y equipamiento en general / Vehículos motorizados / Vehículos para pasajeros'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos de emergencia'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos para turismo'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos especiales y de recreación'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Bicicletas con motor']
# The var is:  NombreroductoGenerico
# ['SUV o todo terrenos'
#  'Camiones ligeros o vehículos de deporte de utilida' 'Ambulancias'
#  'Automóviles' 'Trineos motorizados o motos de nieve'
#  'Escuters o motos pequeñas']
# The var is:  RubroN1
# ['Vehículos y equipamiento en general']
# The var is:  RubroN2
# ['Vehículos motorizados']
# The var is:  RubroN3
# ['Vehículos para pasajeros' 'Vehículos de emergencia'
#  'Vehículos para turismo' 'Vehículos especiales y de recreación'
#  'Bicicletas con motor']
# <class 'pandas.core.frame.DataFrame'>
# Index: 904 entries, 12 to 29784
# Data columns (total 80 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          904 non-null    int64
#  1   Codigo                      904 non-null    object
#  2   Link                        579 non-null    object
#  3   Nombre                      904 non-null    object
#  4   Descripcion/Obervaciones    895 non-null    object
#  5   Tipo                        904 non-null    object
#  6   ProcedenciaOC               904 non-null    object
#  7   EsTratoDirecto              904 non-null    object
#  8   EsCompraAgil                904 non-null    object
#  9   CodigoTipo                  904 non-null    int64
#  10  CodigoAbreviadoTipoOC       904 non-null    object
#  11  DescripcionTipoOC           904 non-null    object
#  12  idPlanDeCompra              165 non-null    float64
#  13  codigoEstado                904 non-null    int64
#  14  Estado                      904 non-null    object
#  15  codigoEstadoProveedor       904 non-null    int64
#  16  EstadoProveedor             904 non-null    object
#  17  FechaCreacion               904 non-null    object
#  18  FechaEnvio                  904 non-null    object
#  19  FechaSolicitudCancelacion   904 non-null    object
#  20  fechaUltimaModificacion     904 non-null    object
#  21  FechaAceptacion             887 non-null    object
#  22  FechaCancelacion            0 non-null      float64
#  23  tieneItems                  904 non-null    int64
#  24  PromedioCalificacion        904 non-null    object
#  25  CantidadEvaluacion          904 non-null    int64
#  26  MontoTotalOC                904 non-null    object
#  27  TipoMonedaOC                904 non-null    object
#  28  MontoTotalOC_PesosChilenos  904 non-null    object
#  29  Impuestos                   904 non-null    object
#  30  TipoImpuesto                904 non-null    object
#  31  Descuentos                  904 non-null    object
#  32  Cargos                      904 non-null    object
#  33  TotalNetoOC                 904 non-null    object
#  34  CodigoUnidadCompra          904 non-null    int64
#  35  RutUnidadCompra             904 non-null    object
#  36  UnidadCompra                904 non-null    object
#  37  CodigoOrganismoPublico      904 non-null    int64
#  38  OrganismoPublico            904 non-null    object
#  39  sector                      904 non-null    object
#  40  ActividadComprador          646 non-null    object
#  41  CiudadUnidadCompra          904 non-null    object
#  42  RegionUnidadCompra          904 non-null    object
#  43  PaisUnidadCompra            893 non-null    object
#  44  CodigoSucursal              904 non-null    float64
#  45  RutSucursal                 904 non-null    object
#  46  Sucursal                    904 non-null    object
#  47  CodigoProveedor             904 non-null    float64
#  48  NombreProveedor             904 non-null    object
#  49  ActividadProveedor          897 non-null    object
#  50  ComunaProveedor             612 non-null    object
#  51  RegionProveedor             613 non-null    object
#  52  PaisProveedor               589 non-null    object
#  53  Financiamiento              530 non-null    object
#  54  PorcentajeIva               904 non-null    int64
#  55  Pais                        893 non-null    object
#  56  TipoDespacho                904 non-null    int64
#  57  FormaPago                   904 non-null    int64
#  58  CodigoLicitacion            30 non-null     object
#  59  IDItem                      904 non-null    float64
#  60  codigoCategoria             904 non-null    float64
#  61  Categoria                   904 non-null    object
#  62  codigoProductoONU           904 non-null    float64
#  63  NombreroductoGenerico       904 non-null    object
#  64  RubroN1                     904 non-null    object
#  65  RubroN2                     904 non-null    object
#  66  RubroN3                     904 non-null    object
#  67  EspecificacionComprador     894 non-null    object
#  68  EspecificacionProveedor     896 non-null    object
#  69  cantidad                    904 non-null    object
#  70  UnidadMedida                79 non-null     object
#  71  monedaItem                  904 non-null    object
#  72  precioNeto                  883 non-null    float64
#  73  totalCargos                 904 non-null    float64
#  74  totalDescuentos             904 non-null    float64
#  75  totalImpuestos              904 non-null    float64
#  76  totalLineaNeto              904 non-null    object
#  77  Forma de Pago               904 non-null    object
#  78  Year                        904 non-null    int64
#  79  Month                       904 non-null    int64
# dtypes: float64(11), int64(13), object(56)
# memory usage: 572.1+ KB
# None
# Year: 2017
# The var is:  Categoria
# ['Vehículos y equipamiento en general / Vehículos motorizados / Vehículos para pasajeros'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos de emergencia'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos para turismo'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos especiales y de recreación'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Bicicletas con motor']
# The var is:  NombreroductoGenerico
# ['SUV o todo terrenos'
#  'Camiones ligeros o vehículos de deporte de utilida' 'Ambulancias'
#  'Automóviles' 'Trineos motorizados o motos de nieve'
#  'Escuters o motos pequeñas']
# The var is:  RubroN1
# ['Vehículos y equipamiento en general']
# The var is:  RubroN2
# ['Vehículos motorizados']
# The var is:  RubroN3
# ['Vehículos para pasajeros' 'Vehículos de emergencia'
#  'Vehículos para turismo' 'Vehículos especiales y de recreación'
#  'Bicicletas con motor']
# <class 'pandas.core.frame.DataFrame'>
# Index: 1162 entries, 0 to 48134
# Data columns (total 80 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          1162 non-null   int64
#  1   Codigo                      1162 non-null   object
#  2   Link                        1162 non-null   object
#  3   Nombre                      1162 non-null   object
#  4   Descripcion/Obervaciones    1145 non-null   object
#  5   Tipo                        1162 non-null   object
#  6   ProcedenciaOC               1162 non-null   object
#  7   EsTratoDirecto              1162 non-null   object
#  8   EsCompraAgil                1162 non-null   object
#  9   CodigoTipo                  1162 non-null   int64
#  10  CodigoAbreviadoTipoOC       1162 non-null   object
#  11  DescripcionTipoOC           1162 non-null   object
#  12  codigoEstado                1162 non-null   int64
#  13  Estado                      1162 non-null   object
#  14  codigoEstadoProveedor       1162 non-null   int64
#  15  EstadoProveedor             1162 non-null   object
#  16  FechaCreacion               1162 non-null   object
#  17  FechaEnvio                  1162 non-null   object
#  18  FechaSolicitudCancelacion   1162 non-null   object
#  19  fechaUltimaModificacion     1162 non-null   object
#  20  FechaAceptacion             1151 non-null   object
#  21  FechaCancelacion            0 non-null      float64
#  22  tieneItems                  1162 non-null   int64
#  23  PromedioCalificacion        1162 non-null   object
#  24  CantidadEvaluacion          1162 non-null   int64
#  25  MontoTotalOC                1162 non-null   object
#  26  TipoMonedaOC                1162 non-null   object
#  27  MontoTotalOC_PesosChilenos  1162 non-null   object
#  28  Impuestos                   1162 non-null   object
#  29  TipoImpuesto                1162 non-null   object
#  30  Descuentos                  1162 non-null   object
#  31  Cargos                      1162 non-null   float64
#  32  TotalNetoOC                 1162 non-null   object
#  33  CodigoUnidadCompra          1162 non-null   int64
#  34  RutUnidadCompra             1162 non-null   object
#  35  UnidadCompra                1162 non-null   object
#  36  CodigoOrganismoPublico      1162 non-null   int64
#  37  OrganismoPublico            1162 non-null   object
#  38  sector                      1162 non-null   object
#  39  ActividadComprador          802 non-null    object
#  40  CiudadUnidadCompra          1162 non-null   object
#  41  RegionUnidadCompra          1162 non-null   object
#  42  PaisUnidadCompra            1142 non-null   object
#  43  CodigoSucursal              1162 non-null   float64
#  44  RutSucursal                 1162 non-null   object
#  45  Sucursal                    1162 non-null   object
#  46  CodigoProveedor             1162 non-null   float64
#  47  NombreProveedor             1162 non-null   object
#  48  ActividadProveedor          1153 non-null   object
#  49  ComunaProveedor             744 non-null    object
#  50  RegionProveedor             745 non-null    object
#  51  PaisProveedor               707 non-null    object
#  52  Financiamiento              676 non-null    object
#  53  PorcentajeIva               1162 non-null   int64
#  54  Pais                        1142 non-null   object
#  55  TipoDespacho                1162 non-null   int64
#  56  FormaPago                   1162 non-null   int64
#  57  CodigoLicitacion            0 non-null      float64
#  58  IDItem                      1162 non-null   float64
#  59  codigoCategoria             1162 non-null   float64
#  60  Categoria                   1162 non-null   object
#  61  codigoProductoONU           1162 non-null   float64
#  62  NombreroductoGenerico       1162 non-null   object
#  63  RubroN1                     1162 non-null   object
#  64  RubroN2                     1162 non-null   object
#  65  RubroN3                     1162 non-null   object
#  66  EspecificacionComprador     1152 non-null   object
#  67  EspecificacionProveedor     1151 non-null   object
#  68  cantidad                    1162 non-null   float64
#  69  UnidadMedida                54 non-null     object
#  70  monedaItem                  1162 non-null   object
#  71  precioNeto                  1114 non-null   float64
#  72  totalCargos                 1162 non-null   float64
#  73  totalDescuentos             1162 non-null   float64
#  74  totalImpuestos              1162 non-null   float64
#  75  totalLineaNeto              1162 non-null   object
#  76  Forma de Pago               1158 non-null   object
#  77  Year                        1162 non-null   int64
#  78  Month                       1162 non-null   int64
#  79  idPlanDeCompra              108 non-null    float64
# dtypes: float64(14), int64(13), object(53)
# memory usage: 735.3+ KB
# None
# Year: 2018
# The var is:  Categoria
# ['Vehículos y equipamiento en general / Vehículos motorizados / Vehículos para pasajeros'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos de emergencia'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos para turismo'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos especiales y de recreación'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Bicicletas con motor']
# The var is:  NombreroductoGenerico
# ['SUV o todo terrenos'
#  'Camiones ligeros o vehículos de deporte de utilida' 'Ambulancias'
#  'Automóviles' 'Trineos motorizados o motos de nieve'
#  'Escuters o motos pequeñas']
# The var is:  RubroN1
# ['Vehículos y equipamiento en general']
# The var is:  RubroN2
# ['Vehículos motorizados']
# The var is:  RubroN3
# ['Vehículos para pasajeros' 'Vehículos de emergencia'
#  'Vehículos para turismo' 'Vehículos especiales y de recreación'
#  'Bicicletas con motor']
# <class 'pandas.core.frame.DataFrame'>
# Index: 1011 entries, 1 to 56630
# Data columns (total 80 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          1011 non-null   int64
#  1   Codigo                      1011 non-null   object
#  2   Link                        1011 non-null   object
#  3   Nombre                      1011 non-null   object
#  4   Descripcion/Obervaciones    999 non-null    object
#  5   Tipo                        1011 non-null   object
#  6   ProcedenciaOC               1011 non-null   object
#  7   EsTratoDirecto              1011 non-null   object
#  8   EsCompraAgil                1011 non-null   object
#  9   CodigoTipo                  1011 non-null   int64
#  10  CodigoAbreviadoTipoOC       1011 non-null   object
#  11  DescripcionTipoOC           1011 non-null   object
#  12  idPlanDeCompra              144 non-null    float64
#  13  codigoEstado                1011 non-null   int64
#  14  Estado                      1011 non-null   object
#  15  codigoEstadoProveedor       1011 non-null   int64
#  16  EstadoProveedor             1011 non-null   object
#  17  FechaCreacion               1011 non-null   object
#  18  FechaEnvio                  1011 non-null   object
#  19  FechaSolicitudCancelacion   1011 non-null   object
#  20  fechaUltimaModificacion     1011 non-null   object
#  21  FechaAceptacion             980 non-null    object
#  22  FechaCancelacion            1 non-null      object
#  23  tieneItems                  1011 non-null   int64
#  24  PromedioCalificacion        1011 non-null   object
#  25  CantidadEvaluacion          1011 non-null   int64
#  26  MontoTotalOC                1011 non-null   object
#  27  TipoMonedaOC                1011 non-null   object
#  28  MontoTotalOC_PesosChilenos  1011 non-null   object
#  29  Impuestos                   1011 non-null   object
#  30  TipoImpuesto                1011 non-null   object
#  31  Descuentos                  1011 non-null   object
#  32  Cargos                      1011 non-null   float64
#  33  TotalNetoOC                 1011 non-null   object
#  34  CodigoUnidadCompra          1011 non-null   int64
#  35  RutUnidadCompra             1011 non-null   object
#  36  UnidadCompra                1011 non-null   object
#  37  CodigoOrganismoPublico      1011 non-null   int64
#  38  OrganismoPublico            1011 non-null   object
#  39  sector                      1011 non-null   object
#  40  ActividadComprador          730 non-null    object
#  41  CiudadUnidadCompra          1000 non-null   object
#  42  RegionUnidadCompra          1000 non-null   object
#  43  PaisUnidadCompra            993 non-null    object
#  44  CodigoSucursal              1011 non-null   float64
#  45  RutSucursal                 1011 non-null   object
#  46  Sucursal                    1011 non-null   object
#  47  CodigoProveedor             1011 non-null   float64
#  48  NombreProveedor             1011 non-null   object
#  49  ActividadProveedor          1004 non-null   object
#  50  ComunaProveedor             847 non-null    object
#  51  RegionProveedor             846 non-null    object
#  52  PaisProveedor               820 non-null    object
#  53  Financiamiento              604 non-null    object
#  54  PorcentajeIva               1011 non-null   int64
#  55  Pais                        993 non-null    object
#  56  TipoDespacho                1011 non-null   int64
#  57  FormaPago                   1011 non-null   float64
#  58  CodigoLicitacion            0 non-null      float64
#  59  IDItem                      1011 non-null   float64
#  60  codigoCategoria             1011 non-null   float64
#  61  Categoria                   1011 non-null   object
#  62  codigoProductoONU           1011 non-null   float64
#  63  NombreroductoGenerico       1011 non-null   object
#  64  RubroN1                     1011 non-null   object
#  65  RubroN2                     1011 non-null   object
#  66  RubroN3                     1011 non-null   object
#  67  EspecificacionComprador     1002 non-null   object
#  68  EspecificacionProveedor     1002 non-null   object
#  69  cantidad                    1011 non-null   object
#  70  UnidadMedida                48 non-null     object
#  71  monedaItem                  1011 non-null   object
#  72  precioNeto                  981 non-null    float64
#  73  totalCargos                 1011 non-null   float64
#  74  totalDescuentos             1011 non-null   float64
#  75  totalImpuestos              1011 non-null   float64
#  76  totalLineaNeto              1011 non-null   object
#  77  Forma de Pago               997 non-null    object
#  78  Year                        1011 non-null   int64
#  79  Month                       1011 non-null   int64
# dtypes: float64(13), int64(12), object(55)
# memory usage: 639.8+ KB
# None
# Year: 2019
# The var is:  Categoria
# ['Vehículos y equipamiento en general / Vehículos motorizados / Vehículos para pasajeros'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos de emergencia'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos para turismo'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos especiales y de recreación'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Bicicletas con motor']
# The var is:  NombreroductoGenerico
# ['SUV o todo terrenos'
#  'Camiones ligeros o vehículos de deporte de utilida' 'Ambulancias'
#  'Automóviles' 'Trineos motorizados o motos de nieve'
#  'Escuters o motos pequeñas']
# The var is:  RubroN1
# ['Vehículos y equipamiento en general']
# The var is:  RubroN2
# ['Vehículos motorizados']
# The var is:  RubroN3
# ['Vehículos para pasajeros' 'Vehículos de emergencia'
#  'Vehículos para turismo' 'Vehículos especiales y de recreación'
#  'Bicicletas con motor']
# <class 'pandas.core.frame.DataFrame'>
# Index: 1166 entries, 5 to 59173
# Data columns (total 80 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          1166 non-null   int64
#  1   Codigo                      1166 non-null   object
#  2   Link                        1166 non-null   object
#  3   Nombre                      1166 non-null   object
#  4   Descripcion/Obervaciones    1141 non-null   object
#  5   Tipo                        1166 non-null   object
#  6   ProcedenciaOC               1166 non-null   object
#  7   EsTratoDirecto              1166 non-null   object
#  8   EsCompraAgil                1166 non-null   object
#  9   CodigoTipo                  1166 non-null   int64
#  10  CodigoAbreviadoTipoOC       1166 non-null   object
#  11  DescripcionTipoOC           1166 non-null   object
#  12  idPlanDeCompra              198 non-null    float64
#  13  codigoEstado                1166 non-null   int64
#  14  Estado                      1166 non-null   object
#  15  codigoEstadoProveedor       1166 non-null   int64
#  16  EstadoProveedor             1166 non-null   object
#  17  FechaCreacion               1166 non-null   object
#  18  FechaEnvio                  1166 non-null   object
#  19  FechaSolicitudCancelacion   1166 non-null   object
#  20  fechaUltimaModificacion     1166 non-null   object
#  21  FechaAceptacion             1136 non-null   object
#  22  FechaCancelacion            0 non-null      object
#  23  tieneItems                  1166 non-null   int64
#  24  PromedioCalificacion        1166 non-null   object
#  25  CantidadEvaluacion          1166 non-null   int64
#  26  MontoTotalOC                1166 non-null   object
#  27  TipoMonedaOC                1166 non-null   object
#  28  MontoTotalOC_PesosChilenos  1166 non-null   object
#  29  Impuestos                   1166 non-null   object
#  30  TipoImpuesto                1166 non-null   object
#  31  Descuentos                  1166 non-null   float64
#  32  Cargos                      1166 non-null   float64
#  33  TotalNetoOC                 1166 non-null   object
#  34  CodigoUnidadCompra          1166 non-null   int64
#  35  RutUnidadCompra             1166 non-null   object
#  36  UnidadCompra                1166 non-null   object
#  37  CodigoOrganismoPublico      1166 non-null   int64
#  38  OrganismoPublico            1166 non-null   object
#  39  sector                      1166 non-null   object
#  40  ActividadComprador          841 non-null    object
#  41  CiudadUnidadCompra          1149 non-null   object
#  42  RegionUnidadCompra          1149 non-null   object
#  43  PaisUnidadCompra            1110 non-null   object
#  44  CodigoSucursal              1166 non-null   float64
#  45  RutSucursal                 1166 non-null   object
#  46  Sucursal                    1166 non-null   object
#  47  CodigoProveedor             1166 non-null   float64
#  48  NombreProveedor             1166 non-null   object
#  49  ActividadProveedor          1164 non-null   object
#  50  ComunaProveedor             1079 non-null   object
#  51  RegionProveedor             1079 non-null   object
#  52  PaisProveedor               1068 non-null   object
#  53  Financiamiento              571 non-null    object
#  54  PorcentajeIva               1166 non-null   int64
#  55  Pais                        1110 non-null   object
#  56  TipoDespacho                1166 non-null   int64
#  57  FormaPago                   1166 non-null   float64
#  58  CodigoLicitacion            0 non-null      float64
#  59  IDItem                      1166 non-null   float64
#  60  codigoCategoria             1166 non-null   float64
#  61  Categoria                   1166 non-null   object
#  62  codigoProductoONU           1166 non-null   float64
#  63  NombreroductoGenerico       1166 non-null   object
#  64  RubroN1                     1166 non-null   object
#  65  RubroN2                     1166 non-null   object
#  66  RubroN3                     1166 non-null   object
#  67  EspecificacionComprador     1152 non-null   object
#  68  EspecificacionProveedor     1138 non-null   object
#  69  cantidad                    1166 non-null   float64
#  70  UnidadMedida                151 non-null    object
#  71  monedaItem                  1166 non-null   object
#  72  precioNeto                  1119 non-null   float64
#  73  totalCargos                 1166 non-null   object
#  74  totalDescuentos             1166 non-null   float64
#  75  totalImpuestos              1166 non-null   float64
#  76  totalLineaNeto              1166 non-null   object
#  77  Forma de Pago               1126 non-null   object
#  78  Year                        1166 non-null   int64
#  79  Month                       1166 non-null   int64
# dtypes: float64(14), int64(12), object(54)
# memory usage: 737.9+ KB
# None
# Year: 2020
# The var is:  Categoria
# ['Vehículos y equipamiento en general / Vehículos motorizados / Vehículos para pasajeros'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos de emergencia'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos para turismo'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos especiales y de recreación'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Bicicletas con motor']
# The var is:  NombreroductoGenerico
# ['SUV o todo terrenos'
#  'Camiones ligeros o vehículos de deporte de utilida' 'Ambulancias'
#  'Automóviles' 'Trineos motorizados o motos de nieve'
#  'Escuters o motos pequeñas']
# The var is:  RubroN1
# ['Vehículos y equipamiento en general']
# The var is:  RubroN2
# ['Vehículos motorizados']
# The var is:  RubroN3
# ['Vehículos para pasajeros' 'Vehículos de emergencia'
#  'Vehículos para turismo' 'Vehículos especiales y de recreación'
#  'Bicicletas con motor']
# <class 'pandas.core.frame.DataFrame'>
# Index: 675 entries, 3 to 19223
# Data columns (total 81 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          675 non-null    int64
#  1   Codigo                      675 non-null    object
#  2   Link                        675 non-null    object
#  3   Nombre                      675 non-null    object
#  4   Descripcion/Obervaciones    669 non-null    object
#  5   Tipo                        675 non-null    object
#  6   ProcedenciaOC               675 non-null    object
#  7   EsTratoDirecto              675 non-null    object
#  8   EsCompraAgil                675 non-null    object
#  9   CodigoTipo                  675 non-null    int64
#  10  CodigoAbreviadoTipoOC       675 non-null    object
#  11  DescripcionTipoOC           675 non-null    object
#  12  idPlanDeCompra              71 non-null     float64
#  13  codigoEstado                675 non-null    int64
#  14  Estado                      675 non-null    object
#  15  codigoEstadoProveedor       675 non-null    int64
#  16  EstadoProveedor             675 non-null    object
#  17  FechaCreacion               675 non-null    object
#  18  FechaEnvio                  675 non-null    object
#  19  FechaSolicitudCancelacion   675 non-null    object
#  20  fechaUltimaModificacion     675 non-null    object
#  21  FechaAceptacion             668 non-null    object
#  22  FechaCancelacion            0 non-null      float64
#  23  tieneItems                  675 non-null    int64
#  24  PromedioCalificacion        675 non-null    object
#  25  CantidadEvaluacion          675 non-null    int64
#  26  MontoTotalOC                675 non-null    object
#  27  TipoMonedaOC                675 non-null    object
#  28  MontoTotalOC_PesosChilenos  675 non-null    object
#  29  Impuestos                   675 non-null    object
#  30  TipoImpuesto                675 non-null    object
#  31  Descuentos                  675 non-null    int64
#  32  Cargos                      675 non-null    float64
#  33  TotalNetoOC                 675 non-null    object
#  34  CodigoUnidadCompra          675 non-null    int64
#  35  RutUnidadCompra             675 non-null    object
#  36  UnidadCompra                675 non-null    object
#  37  CodigoOrganismoPublico      675 non-null    int64
#  38  OrganismoPublico            675 non-null    object
#  39  sector                      675 non-null    object
#  40  ActividadComprador          491 non-null    object
#  41  CiudadUnidadCompra          665 non-null    object
#  42  RegionUnidadCompra          665 non-null    object
#  43  PaisUnidadCompra            641 non-null    object
#  44  CodigoSucursal              675 non-null    int64
#  45  RutSucursal                 675 non-null    object
#  46  Sucursal                    675 non-null    object
#  47  CodigoProveedor             675 non-null    int64
#  48  NombreProveedor             675 non-null    object
#  49  ActividadProveedor          674 non-null    object
#  50  ComunaProveedor             644 non-null    object
#  51  RegionProveedor             644 non-null    object
#  52  PaisProveedor               644 non-null    object
#  53  Financiamiento              353 non-null    object
#  54  PorcentajeIva               675 non-null    int64
#  55  Pais                        641 non-null    object
#  56  TipoDespacho                675 non-null    int64
#  57  FormaPago                   675 non-null    float64
#  58  CodigoLicitacion            0 non-null      float64
#  59  IDItem                      675 non-null    float64
#  60  codigoCategoria             675 non-null    float64
#  61  Categoria                   675 non-null    object
#  62  codigoProductoONU           675 non-null    float64
#  63  NombreroductoGenerico       675 non-null    object
#  64  RubroN1                     675 non-null    object
#  65  RubroN2                     675 non-null    object
#  66  RubroN3                     675 non-null    object
#  67  EspecificacionComprador     668 non-null    object
#  68  EspecificacionProveedor     667 non-null    object
#  69  cantidad                    675 non-null    object
#  70  UnidadMedida                64 non-null     object
#  71  monedaItem                  675 non-null    object
#  72  precioNeto                  655 non-null    float64
#  73  totalCargos                 675 non-null    object
#  74  totalDescuentos             675 non-null    float64
#  75  totalImpuestos              675 non-null    float64
#  76  totalLineaNeto              675 non-null    object
#  77  Forma de Pago               670 non-null    object
#  78  Year                        675 non-null    int64
#  79  Month                       675 non-null    int64
#  80  Codigo_ConvenioMarco        174 non-null    object
# dtypes: float64(11), int64(15), object(55)
# memory usage: 432.4+ KB
# None
# Year: 2021
# The var is:  Categoria
# ['Vehículos y equipamiento en general / Vehículos motorizados / Vehículos para pasajeros'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos de emergencia'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos para turismo'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos especiales y de recreación'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Bicicletas con motor']
# The var is:  NombreroductoGenerico
# ['SUV o todo terrenos'
#  'Camiones ligeros o vehículos de deporte de utilida' 'Ambulancias'
#  'Automóviles' 'Trineos motorizados o motos de nieve'
#  'Escuters o motos pequeñas']
# The var is:  RubroN1
# ['Vehículos y equipamiento en general']
# The var is:  RubroN2
# ['Vehículos motorizados']
# The var is:  RubroN3
# ['Vehículos para pasajeros' 'Vehículos de emergencia'
#  'Vehículos para turismo' 'Vehículos especiales y de recreación'
#  'Bicicletas con motor']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580 entries, 0 to 579
# Data columns (total 80 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          580 non-null    int64
#  1   Codigo                      580 non-null    object
#  2   Link                        580 non-null    object
#  3   Nombre                      580 non-null    object
#  4   Descripcion/Obervaciones    576 non-null    object
#  5   Tipo                        580 non-null    object
#  6   ProcedenciaOC               580 non-null    object
#  7   EsTratoDirecto              580 non-null    object
#  8   EsCompraAgil                580 non-null    object
#  9   CodigoTipo                  580 non-null    int64
#  10  CodigoAbreviadoTipoOC       580 non-null    object
#  11  DescripcionTipoOC           580 non-null    object
#  12  codigoEstado                580 non-null    int64
#  13  Estado                      580 non-null    object
#  14  codigoEstadoProveedor       580 non-null    int64
#  15  EstadoProveedor             580 non-null    object
#  16  FechaCreacion               580 non-null    object
#  17  FechaEnvio                  580 non-null    object
#  18  FechaSolicitudCancelacion   580 non-null    object
#  19  fechaUltimaModificacion     580 non-null    object
#  20  FechaAceptacion             574 non-null    object
#  21  FechaCancelacion            0 non-null      float64
#  22  tieneItems                  580 non-null    int64
#  23  PromedioCalificacion        580 non-null    object
#  24  CantidadEvaluacion          580 non-null    int64
#  25  MontoTotalOC                580 non-null    object
#  26  TipoMonedaOC                580 non-null    object
#  27  MontoTotalOC_PesosChilenos  580 non-null    object
#  28  Impuestos                   580 non-null    object
#  29  TipoImpuesto                580 non-null    object
#  30  Descuentos                  580 non-null    int64
#  31  Cargos                      580 non-null    int64
#  32  TotalNetoOC                 580 non-null    object
#  33  CodigoUnidadCompra          580 non-null    int64
#  34  RutUnidadCompra             580 non-null    object
#  35  UnidadCompra                580 non-null    object
#  36  CodigoOrganismoPublico      580 non-null    int64
#  37  OrganismoPublico            580 non-null    object
#  38  sector                      580 non-null    object
#  39  ActividadComprador          424 non-null    object
#  40  CiudadUnidadCompra          574 non-null    object
#  41  RegionUnidadCompra          574 non-null    object
#  42  PaisUnidadCompra            555 non-null    object
#  43  CodigoSucursal              580 non-null    float64
#  44  RutSucursal                 580 non-null    object
#  45  Sucursal                    580 non-null    object
#  46  CodigoProveedor             580 non-null    float64
#  47  NombreProveedor             580 non-null    object
#  48  ActividadProveedor          579 non-null    object
#  49  ComunaProveedor             577 non-null    object
#  50  RegionProveedor             577 non-null    object
#  51  PaisProveedor               575 non-null    object
#  52  Financiamiento              339 non-null    object
#  53  PorcentajeIva               580 non-null    int64
#  54  Pais                        555 non-null    object
#  55  TipoDespacho                580 non-null    int64
#  56  FormaPago                   580 non-null    float64
#  57  CodigoLicitacion            0 non-null      float64
#  58  Codigo_ConvenioMarco        434 non-null    object
#  59  IDItem                      580 non-null    float64
#  60  codigoCategoria             580 non-null    float64
#  61  Categoria                   580 non-null    object
#  62  codigoProductoONU           580 non-null    float64
#  63  NombreroductoGenerico       580 non-null    object
#  64  RubroN1                     580 non-null    object
#  65  RubroN2                     580 non-null    object
#  66  RubroN3                     580 non-null    object
#  67  EspecificacionComprador     570 non-null    object
#  68  EspecificacionProveedor     574 non-null    object
#  69  cantidad                    580 non-null    int64
#  70  UnidadMedida                50 non-null     object
#  71  monedaItem                  580 non-null    object
#  72  precioNeto                  568 non-null    float64
#  73  totalCargos                 580 non-null    object
#  74  totalDescuentos             580 non-null    float64
#  75  totalImpuestos              580 non-null    float64
#  76  totalLineaNeto              580 non-null    object
#  77  Forma de Pago               566 non-null    object
#  78  Year                        580 non-null    int64
#  79  Month                       580 non-null    int64
# dtypes: float64(11), int64(15), object(54)
# memory usage: 362.6+ KB
# None
# Year: 2022
# The var is:  Categoria
# ['Vehículos y equipamiento en general / Vehículos motorizados / Vehículos para pasajeros'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos de emergencia'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos para turismo'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos especiales y de recreación'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Bicicletas con motor']
# The var is:  NombreroductoGenerico
# ['SUV o todo terrenos'
#  'Camiones ligeros o vehículos de deporte de utilida' 'Ambulancias'
#  'Automóviles' 'Trineos motorizados o motos de nieve'
#  'Escuters o motos pequeñas']
# The var is:  RubroN1
# ['Vehículos y equipamiento en general']
# The var is:  RubroN2
# ['Vehículos motorizados']
# The var is:  RubroN3
# ['Vehículos para pasajeros' 'Vehículos de emergencia'
#  'Vehículos para turismo' 'Vehículos especiales y de recreación'
#  'Bicicletas con motor']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 80 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          14 non-null     int64
#  1   Codigo                      14 non-null     object
#  2   Link                        14 non-null     object
#  3   Nombre                      14 non-null     object
#  4   Descripcion/Obervaciones    14 non-null     object
#  5   Tipo                        14 non-null     object
#  6   ProcedenciaOC               14 non-null     object
#  7   EsTratoDirecto              14 non-null     object
#  8   EsCompraAgil                14 non-null     object
#  9   CodigoTipo                  14 non-null     int64
#  10  CodigoAbreviadoTipoOC       14 non-null     object
#  11  DescripcionTipoOC           14 non-null     object
#  12  codigoEstado                14 non-null     int64
#  13  Estado                      14 non-null     object
#  14  codigoEstadoProveedor       14 non-null     int64
#  15  EstadoProveedor             14 non-null     object
#  16  FechaCreacion               14 non-null     object
#  17  FechaEnvio                  14 non-null     object
#  18  FechaSolicitudCancelacion   14 non-null     object
#  19  fechaUltimaModificacion     14 non-null     object
#  20  FechaAceptacion             12 non-null     object
#  21  FechaCancelacion            0 non-null      float64
#  22  tieneItems                  14 non-null     int64
#  23  PromedioCalificacion        14 non-null     object
#  24  CantidadEvaluacion          14 non-null     int64
#  25  MontoTotalOC                14 non-null     object
#  26  TipoMonedaOC                14 non-null     object
#  27  MontoTotalOC_PesosChilenos  14 non-null     object
#  28  Impuestos                   14 non-null     object
#  29  TipoImpuesto                14 non-null     object
#  30  Descuentos                  14 non-null     int64
#  31  Cargos                      14 non-null     int64
#  32  TotalNetoOC                 14 non-null     int64
#  33  CodigoUnidadCompra          14 non-null     int64
#  34  RutUnidadCompra             14 non-null     object
#  35  UnidadCompra                14 non-null     object
#  36  CodigoOrganismoPublico      14 non-null     int64
#  37  OrganismoPublico            14 non-null     object
#  38  sector                      14 non-null     object
#  39  ActividadComprador          8 non-null      object
#  40  CiudadUnidadCompra          14 non-null     object
#  41  RegionUnidadCompra          14 non-null     object
#  42  PaisUnidadCompra            13 non-null     object
#  43  CodigoSucursal              14 non-null     int64
#  44  RutSucursal                 14 non-null     object
#  45  Sucursal                    14 non-null     object
#  46  CodigoProveedor             14 non-null     int64
#  47  NombreProveedor             14 non-null     object
#  48  ActividadProveedor          14 non-null     object
#  49  ComunaProveedor             14 non-null     object
#  50  RegionProveedor             14 non-null     object
#  51  PaisProveedor               13 non-null     object
#  52  Financiamiento              9 non-null      object
#  53  PorcentajeIva               14 non-null     int64
#  54  Pais                        13 non-null     object
#  55  TipoDespacho                14 non-null     int64
#  56  FormaPago                   14 non-null     float64
#  57  CodigoLicitacion            0 non-null      float64
#  58  Codigo_ConvenioMarco        3 non-null      object
#  59  IDItem                      14 non-null     int64
#  60  codigoCategoria             14 non-null     float64
#  61  Categoria                   14 non-null     object
#  62  codigoProductoONU           14 non-null     float64
#  63  NombreroductoGenerico       14 non-null     object
#  64  RubroN1                     14 non-null     object
#  65  RubroN2                     14 non-null     object
#  66  RubroN3                     14 non-null     object
#  67  EspecificacionComprador     12 non-null     object
#  68  EspecificacionProveedor     8 non-null      object
#  69  cantidad                    14 non-null     int64
#  70  UnidadMedida                11 non-null     object
#  71  monedaItem                  14 non-null     object
#  72  precioNeto                  14 non-null     float64
#  73  totalCargos                 14 non-null     float64
#  74  totalDescuentos             14 non-null     int64
#  75  totalImpuestos              14 non-null     float64
#  76  totalLineaNeto              14 non-null     int64
#  77  Forma de Pago               14 non-null     object
#  78  Year                        14 non-null     int64
#  79  Month                       14 non-null     int64
# dtypes: float64(8), int64(21), object(51)
# memory usage: 8.9+ KB
# None
# Year: 2023
# The var is:  Categoria
# ['Vehículos y equipamiento en general / Vehículos motorizados / Vehículos para pasajeros'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos de emergencia'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos para turismo'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Vehículos especiales y de recreación'
#  'Vehículos y equipamiento en general / Vehículos motorizados / Bicicletas con motor']
# The var is:  NombreroductoGenerico
# ['SUV o todo terrenos'
#  'Camiones ligeros o vehículos de deporte de utilida' 'Ambulancias'
#  'Automóviles' 'Trineos motorizados o motos de nieve'
#  'Escuters o motos pequeñas']
# The var is:  RubroN1
# ['Vehículos y equipamiento en general']
# The var is:  RubroN2
# ['Vehículos motorizados']
# The var is:  RubroN3
# ['Vehículos para pasajeros' 'Vehículos de emergencia'
#  'Vehículos para turismo' 'Vehículos especiales y de recreación'
#  'Bicicletas con motor']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 80 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          61 non-null     int64
#  1   Codigo                      61 non-null     object
#  2   Link                        61 non-null     object
#  3   Nombre                      61 non-null     object
#  4   Descripcion/Obervaciones    61 non-null     object
#  5   Tipo                        61 non-null     object
#  6   ProcedenciaOC               61 non-null     object
#  7   EsTratoDirecto              61 non-null     object
#  8   EsCompraAgil                61 non-null     object
#  9   CodigoTipo                  61 non-null     int64
#  10  CodigoAbreviadoTipoOC       61 non-null     object
#  11  DescripcionTipoOC           61 non-null     object
#  12  codigoEstado                61 non-null     int64
#  13  Estado                      61 non-null     object
#  14  codigoEstadoProveedor       61 non-null     int64
#  15  EstadoProveedor             61 non-null     object
#  16  FechaCreacion               61 non-null     object
#  17  FechaEnvio                  61 non-null     object
#  18  FechaSolicitudCancelacion   61 non-null     object
#  19  fechaUltimaModificacion     61 non-null     object
#  20  FechaAceptacion             61 non-null     object
#  21  FechaCancelacion            0 non-null      float64
#  22  tieneItems                  61 non-null     int64
#  23  PromedioCalificacion        61 non-null     object
#  24  CantidadEvaluacion          61 non-null     int64
#  25  MontoTotalOC                61 non-null     object
#  26  TipoMonedaOC                61 non-null     object
#  27  MontoTotalOC_PesosChilenos  61 non-null     object
#  28  Impuestos                   61 non-null     object
#  29  TipoImpuesto                61 non-null     object
#  30  Descuentos                  61 non-null     int64
#  31  Cargos                      61 non-null     float64
#  32  TotalNetoOC                 61 non-null     object
#  33  CodigoUnidadCompra          61 non-null     int64
#  34  RutUnidadCompra             61 non-null     object
#  35  UnidadCompra                61 non-null     object
#  36  CodigoOrganismoPublico      61 non-null     int64
#  37  OrganismoPublico            61 non-null     object
#  38  sector                      61 non-null     object
#  39  ActividadComprador          44 non-null     object
#  40  CiudadUnidadCompra          61 non-null     object
#  41  RegionUnidadCompra          61 non-null     object
#  42  PaisUnidadCompra            58 non-null     object
#  43  CodigoSucursal              61 non-null     float64
#  44  RutSucursal                 61 non-null     object
#  45  Sucursal                    61 non-null     object
#  46  CodigoProveedor             61 non-null     float64
#  47  NombreProveedor             61 non-null     object
#  48  ActividadProveedor          60 non-null     object
#  49  ComunaProveedor             58 non-null     object
#  50  RegionProveedor             59 non-null     object
#  51  PaisProveedor               58 non-null     object
#  52  Financiamiento              56 non-null     object
#  53  PorcentajeIva               61 non-null     int64
#  54  Pais                        58 non-null     object
#  55  TipoDespacho                61 non-null     int64
#  56  FormaPago                   61 non-null     float64
#  57  CodigoLicitacion            0 non-null      float64
#  58  Codigo_ConvenioMarco        51 non-null     object
#  59  IDItem                      61 non-null     int64
#  60  codigoCategoria             61 non-null     float64
#  61  Categoria                   61 non-null     object
#  62  codigoProductoONU           61 non-null     float64
#  63  NombreroductoGenerico       61 non-null     object
#  64  RubroN1                     61 non-null     object
#  65  RubroN2                     61 non-null     object
#  66  RubroN3                     61 non-null     object
#  67  EspecificacionComprador     59 non-null     object
#  68  EspecificacionProveedor     58 non-null     object
#  69  cantidad                    61 non-null     int64
#  70  UnidadMedida                10 non-null     object
#  71  monedaItem                  61 non-null     object
#  72  precioNeto                  60 non-null     float64
#  73  totalCargos                 61 non-null     float64
#  74  totalDescuentos             61 non-null     int64
#  75  totalImpuestos              61 non-null     float64
#  76  totalLineaNeto              61 non-null     object
#  77  Forma de Pago               61 non-null     object
#  78  Year                        61 non-null     int64
#  79  Month                       61 non-null     int64
# dtypes: float64(11), int64(16), object(53)
# memory usage: 38.3+ KB
# None

# %%
df_dict = summarize_amounts(df_dict)
# Out:
# Year: 2016
# count    1.550000e+02
# mean     1.002289e+08
# std      1.553469e+08
# min      1.249500e+04
# 25%      5.715570e+05
# 50%      5.399000e+07
# 75%      1.406164e+08
# max      9.930134e+08
# Name: MontoTotalOC, dtype: float64
# count    8.830000e+02
# mean     1.525781e+07
# std      1.293838e+07
# min      2.883000e+03
# 25%      7.146430e+06
# 50%      1.405134e+07
# 75%      1.802861e+07
# max      9.431842e+07
# Name: precioNeto, dtype: float64
# Year: 2017
# count    2.270000e+02
# mean     1.085645e+08
# std      1.711052e+08
# min      7.000000e+03
# 25%      3.302190e+06
# 50%      3.705017e+07
# 75%      1.344164e+08
# max      1.057077e+09
# Name: MontoTotalOC, dtype: float64
# count    1.114000e+03
# mean     1.420325e+07
# std      1.138950e+07
# min      2.479000e+03
# 25%      8.649521e+06
# 50%      1.419249e+07
# 75%      1.789000e+07
# max      1.182000e+08
# Name: precioNeto, dtype: float64
# Year: 2018
# count    5.560000e+02
# mean     4.325683e+07
# std      1.129131e+08
# min      4.498200e+04
# 25%      1.549772e+07
# 50%      2.027397e+07
# 75%      3.047704e+07
# max      1.336477e+09
# Name: MontoTotalOC, dtype: float64
# count    9.810000e+02
# mean     1.410379e+07
# std      9.113468e+06
# min      5.308000e+03
# 25%      9.866050e+06
# 50%      1.444000e+07
# 75%      1.738500e+07
# max      1.265966e+08
# Name: precioNeto, dtype: float64
# Year: 2019
# count    9.210000e+02
# mean     4.808638e+07
# std      1.339362e+08
# min      5.057500e+04
# 25%      1.529460e+07
# 50%      2.000000e+07
# 75%      3.134944e+07
# max      1.247001e+09
# Name: MontoTotalOC, dtype: float64
# count    1.119000e+03
# mean     1.579142e+07
# std      1.234877e+07
# min      1.608100e+04
# 25%      1.040882e+07
# 50%      1.391092e+07
# 75%      1.790807e+07
# max      1.590750e+08
# Name: precioNeto, dtype: float64
# Year: 2020
# count    5.620000e+02
# mean     4.134141e+07
# std      1.105366e+08
# min      2.380000e+04
# 25%      1.585180e+07
# 50%      2.050216e+07
# 75%      2.925516e+07
# max      1.809526e+09
# Name: MontoTotalOC, dtype: float64
# count    6.550000e+02
# mean     1.768523e+07
# std      1.377731e+07
# min      1.630000e+03
# 25%      1.058456e+07
# 50%      1.500050e+07
# 75%      1.905630e+07
# max      8.436000e+07
# Name: precioNeto, dtype: float64
# Year: 2021
# count    4.910000e+02
# mean     9.991038e+07
# std      5.348781e+08
# min      1.819500e+04
# 25%      1.915430e+07
# 50%      2.531420e+07
# 75%      4.347688e+07
# max      9.997071e+09
# Name: MontoTotalOC, dtype: float64
# count    5.680000e+02
# mean     2.038851e+07
# std      1.485981e+07
# min      0.000000e+00
# 25%      1.319780e+07
# 50%      1.807652e+07
# 75%      2.350735e+07
# max      1.240800e+08
# Name: precioNeto, dtype: float64
# Year: 2022
# count         2.000000
# mean      90967.500000
# std       34429.736283
# min       66622.000000
# 25%       78794.750000
# 50%       90967.500000
# 75%      103140.250000
# max      115313.000000
# Name: MontoTotalOC, dtype: float64
# count    1.400000e+01
# mean     7.725718e+06
# std      8.817265e+06
# min      4.311500e+04
# 25%      3.008365e+05
# 50%      2.631256e+06
# 75%      1.421994e+07
# max      2.475652e+07
# Name: precioNeto, dtype: float64
# Year: 2023
# count    2.700000e+01
# mean     2.111077e+08
# std      1.510018e+08
# min      2.142000e+04
# 25%      9.999808e+07
# 50%      1.551462e+08
# 75%      3.297837e+08
# max      6.193165e+08
# Name: MontoTotalOC, dtype: float64
# count    6.000000e+01
# mean     2.028881e+07
# std      7.914151e+06
# min      1.800000e+04
# 25%      1.753695e+07
# 50%      2.100800e+07
# 75%      2.620591e+07
# max      3.508950e+07
# Name: precioNeto, dtype: float64

# %%
repeated_codes(df_dict, N = 3)
# Out:
# Year: 2016
# Codigo
# 3959-7-SE16       23
# 586-497-CM16       7
# 612-2317-CM16      4
# 4728-1743-CM16     4
# 586-1423-CM16      4
# 3959-15-SE16       4
# Name: count, dtype: int64
# Year: 2017
# Codigo
# 918434-343-CM17    15
# 701-1622-CM17      12
# 612-14-CM17        11
# 904268-119-SE17     9
# 587-1843-CM17       7
# 1596-275-CM17       4
# 612-2817-SE17       4
# 1591-380-CM17       4
# Name: count, dtype: int64
# Year: 2018
# Codigo
# 612-72-CM18       27
# 587-2780-CM18      6
# 4629-1271-CM18     6
# 5186-285-CM18      5
# 731-1559-CM18      4
# 5693-267-SE18      4
# 708-1011-CM18      4
# Name: count, dtype: int64
# Year: 2019
# Codigo
# 612-153-SE19       26
# 4629-1204-CM19     12
# 585-211-CM19        7
# 587-1745-CM19       6
# 1080094-7-SE19      5
# 587-2528-CM19       5
# 593951-549-CM19     4
# 3686-3-CM19         4
# 1080094-61-SE19     4
# 1080095-10-SE19     4
# 587-2950-CM19       4
# 3422-109-SE19       4
# 731-1265-CM19       4
# 2084-453-SE19       4
# 1591-319-CM19       4
# Name: count, dtype: int64
# Year: 2020
# Codigo
# 593951-231-CM20     8
# 1098710-128-CM20    5
# 5418-419-SE20       4
# 2511-122-SE20       4
# Name: count, dtype: int64
# Year: 2021
# Series([], Name: count, dtype: int64)
# Year: 2022
# Series([], Name: count, dtype: int64)
# Year: 2023
# Codigo
# 603663-563-CM23    4
# Name: count, dtype: int64
